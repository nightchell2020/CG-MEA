# %% [markdown]
# # EEG Data Curation Part 2
#
# `01_Data_Curation1` 노트북에서 생성한 메타데이터를 불러들여, 이후 학습이 가능하도록 정리하는 노트북.

# %% [markdown]
# -----
#
# ## 파일 수작업 정리 2
#
# 이 노트북을 작성하는 동안, 일부 데이터를 보완 및 수정하였다.
#
# 1. 데이터 추가 수집
#
#     나이와 진단명 정보를 더 수집하였다.
#     수집된 나이 정보는 `210429_metadata_나이작업.xlsx`에, 진단명은 `210504_many-to-one_Diagnosis_추가수정.xlsx`에 기록되어 있다.
#
# 2. 파일 수정
#
#     일부 파일은 오류가 있어서 수정하였다.
#     - `00324958_271118.xlsx`: Sheet48 첫 세 행을 제거, 그 외의 Sheets 제거.
#     - `00988278_210915.xlsx`: Sheet56 첫 세 행을 제거, 그 외의 Sheets 제거.
#     - `00507286_010915.xlsx`: Sheet72 외의 Sheets 제거.
#     - `00414635_240414.xlsx`: Sheet15 외의 Sheets 제거.
#     - `00418981_060116.xlsx`: Sheet33 외의 Sheets 제거.
#     - `00418981_090316.xlsx`: Sheet34 외의 Sheets 제거.
#     - `00421094_140519.xlsx`: Sheet55 외의 Sheets 제거.
#     - `00680066_151014.xlsx`: Sheet91 외의 Sheets 제거.
#     - `00697249_090414.xlsx`: Sheet5 외의 Sheets 제거.
#     - `00700004_270619.xlsx`: Sheet53 외의 Sheets 제거.
#     - `00783510_281015.xlsx`: Sheet27 외의 Sheets 제거.
#     - `00783510_301115.xlsx`: Sheet28 외의 Sheets 제거.
#     - `00783696_220414.xlsx`: Sheet6 외의 Sheets 제거.
#     - `00796775_281015.xlsx`: Sheet25 외의 Sheets 제거.
#     - `00796775_301115.xlsx`: Sheet26 외의 Sheets 제거.
#     - `00823206_130514.xlsx`: Sheet7 외의 Sheets 제거.
#     - `00824216_080416.xlsx`: Sheet35 외의 Sheets 제거.
#     - `00824216_110516.xlsx`: Sheet36 외의 Sheets 제거.
#     - `00875350_140514.xlsx`: Sheet8 외의 Sheets 제거.
#     - `00883719_030912.xlsx`: Sheet40 외의 Sheets 제거.
#     - `00883719_240812.xlsx`: Sheet41 외의 Sheets 제거.
#     - `00957827_230317.xlsx`: Sheet54 외의 Sheets 제거.
#     - `00986061_130716.xlsx`: Sheet56 외의 Sheets 제거.
#     - `00986061_240215.xlsx`: Sheet57 외의 Sheets 제거.
#     - `00986061_270116.xlsx`: Sheet58 외의 Sheets 제거.
#     - `00988278_020819.xlsx`: Sheet41 외의 Sheets 제거.
#     - `00988278_071119.xlsx`: Sheet40 외의 Sheets 제거.
#     - `00988278_160819.xlsx`: Sheet42 외의 Sheets 제거.
#     - `00988278_210915.xlsx`: Sheet39 외의 Sheets 제거.
#     - `01011922_270815.xlsx`: Sheet23 외의 Sheets 제거.
#     - `01011922_290715.xlsx`: Sheet24 외의 Sheets 제거.
#     - `01025734_250815.xlsx`: Sheet21 외의 Sheets 제거.
#     - `01025734_280715.xlsx`: Sheet22 외의 Sheets 제거.
#     - `01026841_101215.xlsx`: Sheet31 외의 Sheets 제거.
#     - `01026841_270116.xlsx`: Sheet32 외의 Sheets 제거.
#     - `01027623_040416.xlsx`: Sheet45 외의 Sheets 제거.
#     - `01027623_060317.xlsx`: Sheet43 외의 Sheets 제거.
#     - `01027623_260916.xlsx`: Sheet44 외의 Sheets 제거.
#     - `01073369_130514.xlsx`: Sheet9 외의 Sheets 제거.
#     - `01080162_120815.xlsx`: Sheet19 외의 Sheets 제거.
#     - `01080162_160715.xlsx`: Sheet20 외의 Sheets 제거.
#     - `01081922_051115.xlsx`: Sheet29 외의 Sheets 제거.
#     - `01081922_071215.xlsx`: Sheet30 외의 Sheets 제거.
#     - `01086373_020615.xlsx`: Sheet10 외의 Sheets 제거.
#     - `01086373_290415.xlsx`: Sheet11 외의 Sheets 제거.
#     - `01126091_140415.xlsx`: Sheet13 외의 Sheets 제거.
#     - `01126091_200515.xlsx`: Sheet12 외의 Sheets 제거.
#     - `01127836_221116.xlsx`: Sheet46 외의 Sheets 제거.
#     - `01139924_060417.xlsx`: Sheet47 외의 Sheets 제거.
#     - `01139924_140717.xlsx`: Sheet48 외의 Sheets 제거.
#     - `01139924_291214.xlsx`: Sheet49 외의 Sheets 제거.
#     - `01139924_300315.xlsx`: Sheet50 외의 Sheets 제거.
#     - `01191314_020317.xlsx`: Sheet37 외의 Sheets 제거.
#     - `01195277_291215.xlsx`: Sheet4 외의 Sheets 제거.
#     - `01207886_270515.xlsx`: Sheet14 외의 Sheets 제거.
#     - `01211467_070415.xlsx`: Sheet18 외의 Sheets 제거.
#     - `01211467_120515.xlsx`: Sheet17 외의 Sheets 제거.
#     - `01243157_141215.xlsx`: Sheet51 외의 Sheets 제거.
#     - `01243158_301115.xlsx`: Sheet52 외의 Sheets 제거.
#     - `01271175_270416.xlsx`: Sheet37 외의 Sheets 제거.
#     - `01271175_300516.xlsx`: Sheet38 외의 Sheets 제거.
#     - `01345366_010917.xlsx`: Sheet39 외의 Sheets 제거.
#     - `01348720_280917.xlsx`: Sheet38 외의 Sheets 제거.
#
# 이전 노트북인 `01_Data_Curation1`에서 생성한 `metadata.xlsx`를 토대로, 위 내용을 보완하여 `210531_metadata.xlsx`로 저장해두었다.
# 앞으로 수정할 필요가 있을지도 모르는 파일들은 `210531_metadata.xlsx`의 Column D `anomaly`에 표시해두었다.

# %% [markdown]
# -----
#
# ## 환경 구성

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# Load some packages
import os
import re
import copy
import glob
from openpyxl import load_workbook, Workbook, styles
import json

import numpy as np
import pyedflib
import datetime
from dateutil.relativedelta import relativedelta

import pprint
import warnings
import ctypes
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# custom package
from utils.eeg_dataset import MultiLabel

# %%
# Other settings
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # cleaner text

plt.style.use('default') 
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 
#  'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 
#  'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 
#  'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 
#  'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams["font.family"] = 'NanumGothic' # for Hangul in Windows

# %% [markdown]
# -----
#
# ## 메타데이터 불러오기

# %%
# Data file path
root_path = r'H:\Lab Database\2020 EEG\201020'
original_folder = r'01_Original_Data'
curated_folder = r'02_Curated_Data'

# %%
meta_file = os.path.join(root_path, r'00_Data_Information/210531_DB_list.xlsx')
ws = load_workbook(meta_file, data_only=True)['metadata']

metadata = []

num = 2
while True:
    m = dict()
    m['edfname'] = ws.cell(row=num, column=1).value
    m['dx1'] = ws.cell(row=num, column=2).value
    m['birth'] = ws.cell(row=num, column=3).value
    m['anomaly'] = True if ws.cell(row=num, column=4).value is not None else False
    num += 1
    
    
    # check whether the row is empty (which is EOF condition)
    if m['edfname'] is None:
        break
    elif m['anomaly']:
        continue
        
    # move the pivot row
    metadata.append(m)
    
print('Size:', len(metadata))
print()
print('Loaded metadata (only 3 displayed):')
print(json.dumps(metadata[:3], indent=4))
# Out:
# Size: 1387
#
# Loaded metadata (only 3 displayed):
# [
#     {
#         "edfname": "00001809_261018",
#         "dx1": "mci_rf",
#         "birth": 400602,
#         "anomaly": false
#     },
#     {
#         "edfname": "00029426_020817",
#         "dx1": "smi",
#         "birth": 601204,
#         "anomaly": false
#     },
#     {
#         "edfname": "00047327_090718",
#         "dx1": "vascular mci",
#         "birth": 241019,
#         "anomaly": false
#     }
# ]

# %% [markdown]
# -----
#
# ## EDF 파일 구성 확인 및 정리

# %% [markdown]
# ### EDF Header Label 구조 확인

# %%
m = metadata[0]
edf_file = os.path.join(root_path, original_folder, m['edfname'] + '.edf')
signals, signal_headers, edf_header  = pyedflib.highlevel.read_edf(edf_file)

refer_headers = signal_headers

pprint.pp(m)
print()
pprint.pp(edf_header)
print()
pprint.pp(signal_headers)
# Out:
# {'edfname': '00001809_261018',
#  'dx1': 'mci_rf',
#  'birth': 400602,
#  'anomaly': False}
#
# {'technician': '',
#  'recording_additional': '',
#  'patientname': '',
#  'patient_additional': '',
#  'patientcode': '',
#  'equipment': '',
#  'admincode': '',
#  'gender': '',
#  'startdate': datetime.datetime(2018, 10, 26, 15, 46, 26),
#  'birthdate': '',
#  'annotations': []}
#
# [{'label': 'Fp1-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'F3-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'C3-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'P3-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'O1-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'Fp2-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'F4-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'C4-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'P4-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'O2-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'F7-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'T3-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'T5-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'F8-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'T4-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'T6-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'FZ-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'CZ-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'PZ-AVG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'EKG',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'},
#  {'label': 'Photic',
#   'dimension': 'uV',
#   'sample_rate': 200.0,
#   'physical_max': 32767.0,
#   'physical_min': -32768.0,
#   'digital_max': 32767,
#   'digital_min': -32768,
#   'prefilter': '',
#   'transducer': 'E'}]

# %%
signal_headers = [s_h['label'] for s_h in signal_headers]
print(signal_headers)
# Out:
# ['Fp1-AVG', 'F3-AVG', 'C3-AVG', 'P3-AVG', 'O1-AVG', 'Fp2-AVG', 'F4-AVG', 'C4-AVG', 'P4-AVG', 'O2-AVG', 'F7-AVG', 'T3-AVG', 'T5-AVG', 'F8-AVG', 'T4-AVG', 'T6-AVG', 'FZ-AVG', 'CZ-AVG', 'PZ-AVG', 'EKG', 'Photic']

# %% [markdown]
# ### EDF 신호열의 Trailing Zero Columns 제거 테스트

# %%
def trim_zero_columns(a):
    assert type(a) == np.ndarray
    trim = 0
    for i in range(a.shape[-1]):
        if np.any(a[..., -1 - i] != 0):
            trim = i
            break
    a = a[..., :-trim]
    return a

# %%
for (i, m) in enumerate(metadata):
    edf_file = os.path.join(root_path, original_folder, m['edfname'] + '.edf')
    signals, signal_headers, edf_header  = pyedflib.highlevel.read_edf(edf_file)
    signals = trim_zero_columns(signals)
    print(m['edfname'], end='\t\t')
    print(edf_header['startdate'], end='\t')
    print(edf_header['startdate'] + datetime.timedelta(seconds = signals.shape[1] / 200), end='\t')
    print()
    
    if i > 10:
        break
# Out:
# 00001809_261018		2018-10-26 15:46:26	2018-10-26 15:58:31
# 00029426_020817		2017-08-02 16:14:56	2017-08-02 16:32:14
# 00047327_090718		2018-07-09 15:29:10	2018-07-09 15:40:00
# 00048377_070819		2019-08-07 13:55:25	2019-08-07 14:09:26
# 00048377_070916		2016-09-07 10:36:01	2016-09-07 10:51:16
# 00048377_250719		2019-07-25 09:58:07	2019-07-25 10:12:04
# 00050941_130116		2016-01-13 13:45:54	2016-01-13 14:00:54
# 00055757_170414		2014-04-17 13:33:15	2014-04-17 13:41:33
# 00056270_260219		2019-02-26 10:38:59	2019-02-26 10:56:33
# 00062072_080319		2019-03-08 13:38:26	2019-03-08 13:55:08
# 00088513_120717		2017-07-12 14:15:27	2017-07-12 14:30:43
# 00110793_210917		2017-09-21 14:25:09	2017-09-21 14:37:51

# %% [markdown]
# -----
#
# ## EDF 측정시 발생하는 이벤트 확인 & 메타데이터 기록 시간과 비교

# %%
warnings.filterwarnings(action='ignore')

event_dict = dict()

for m in tqdm(metadata):
    edf_file = os.path.join(root_path, original_folder, m['edfname'] + '.edf')
    edf_header = pyedflib.highlevel.read_edf_header(edf_file)

    event_file = os.path.join(root_path, original_folder, m['edfname'] + '.xlsx')
    wb = load_workbook(event_file, data_only=True)
    ws = wb[wb.sheetnames[0]]
        
    num = 2
    events = []
    while True:
        t = ws.cell(row=num, column=3).value
        e = ws.cell(row=num, column=4).value

        if t is None:
            break
        
        try:
            t = edf_header['startdate'].strftime('%Y%m%d') + t
            t = datetime.datetime.strptime(t, '%Y%m%d %H:%M:%S.%f')
            event_dict[e] = event_dict.get(e, 0) + 1
        except Exception as ec:
            print(edf_header['startdate'], m['edfname'], ec)
        
        if num == 2:
            startTime = t
            diff = abs(edf_header['startdate'] - t).total_seconds()
            if diff > 0.0:
                print(f'- EDF and XLSX files have different starting time: \
                {diff:>10.2f}s in {m["edfname"]} ({edf_header["startdate"].strftime("%H:%M:%S")} vs {t.strftime("%H:%M:%S")})')
        
        t = int(np.floor((t - startTime).total_seconds() * 200))
        events.append((t, e))
        num += 1
        
print('Done.')
print()

pprint.pprint(sorted(event_dict.items(), key=lambda x: x[1], reverse=True))
warnings.filterwarnings(action='default')
# Out:
#   0%|          | 0/1387 [00:00<?, ?it/s]
# [('Eyes Closed', 16870),
#  ('Eyes Open', 16818),
#  ('Photic Off', 10442),
#  ('Paused', 1874),
#  ('Move', 1777),
#  ('Start Recording', 1387),
#  ('New Montage - Montage 002', 1099),
#  ('Photic On - 3.0 Hz', 1070),
#  ('Photic On - 6.0 Hz', 1062),
#  ('Photic On - 9.0 Hz', 1060),
#  ('Photic On - 12.0 Hz', 1057),
#  ('Photic On - 15.0 Hz', 1051),
#  ('Photic On - 21.0 Hz', 1048),
#  ('Photic On - 18.0 Hz', 1045),
#  ('Photic On - 24.0 Hz', 1032),
#  ('Photic On - 27.0 Hz', 1020),
#  ('Photic On - 30.0 Hz', 977),
#  ('Recording Resumed', 492),
#  ('artifact', 367),
#  ('swallowing', 232),
#  ('New Montage - Pz Montage', 164),
#  ('New Montage - Montage 005', 147),
#  ('HV - Off', 97),
#  ('cough', 53),
#  ('Talk', 51),
#  ('HV fair', 49),
#  ('chewing', 47),
#  ('passive eye close', 36),
#  ('A1 recheck', 24),
#  ('HV Fair', 23),
#  ('Artifact', 23),
#  ('eye blinking -->>', 21),
#  ('sleep Try', 20),
#  ('A2 recheck', 18),
#  ('eye blinking', 17),
#  ('T3 check', 15),
#  ('T4 recheck', 13),
#  ('Couch', 13),
#  ('F4 recheck', 12),
#  ('A2 Recheck', 12),
#  ('sweating', 11),
#  ('F7 check', 10),
#  ('F8 check', 10),
#  ('Fp2 recheck', 10),
#  ('New Low Filters  1.0Hz Notch  ', 10),
#  ('F8 recheck', 10),
#  ('Passive eye close', 10),
#  ('A2 check', 9),
#  ('passive eye open', 9),
#  ('sleep', 9),
#  ('couch', 9),
#  ('T4 check', 8),
#  ('A1 check', 8),
#  ('F4 check', 7),
#  ('COUGH', 7),
#  ('F3 check', 7),
#  ('Chewing', 7),
#  ('F7 Recheck', 7),
#  ('F8 Recheck', 6),
#  ('O1 recheck', 6),
#  ('talk', 6),
#  ('P3 check', 6),
#  ('check', 6),
#  ('O1 check', 6),
#  ('snoring', 6),
#  ('FP1 Recheck', 5),
#  ('Sleep Try', 5),
#  ('C3 check', 5),
#  ('HV - Dur: 160.0 sec. - On', 5),
#  ('F3 recheck', 5),
#  ('P3 Recheck', 5),
#  ('C4 recheck', 5),
#  ('T3 recheck', 5),
#  ('A1,A2 recheck', 5),
#  ('jerking', 5),
#  ('CZ check', 4),
#  ('F4 Recheck', 4),
#  ('C4 check', 4),
#  ('Cz check', 4),
#  ('P4 check', 4),
#  ('A1 Recheck', 4),
#  ('Fp1 recheck', 4),
#  ('T3 Recheck', 4),
#  ('T5 check', 4),
#  ('O1 Recheck', 4),
#  ('drowsy', 4),
#  ('mouth movement', 4),
#  ('HV GOOD', 4),
#  ('Passive eye open', 4),
#  ('Cough', 4),
#  ('P4 Recheck', 3),
#  ('F7 recheck', 3),
#  ('Power failure recovery', 3),
#  ('Fp1 Recheck', 3),
#  ('T5 recheck', 3),
#  ('P3 recheck', 3),
#  ('T6 check', 3),
#  ('O2 recheck', 3),
#  ('EKG Recheck', 3),
#  ('HV - Dur: 156.0 sec. - On', 3),
#  ('PZ check', 2),
#  (' Recheck', 2),
#  ('test refuse', 2),
#  ('Cz Recheck', 2),
#  ('muscle +++++++', 2),
#  ('FZ check', 2),
#  ('T4 Recheck', 2),
#  ('pain', 2),
#  ('Cz recheck', 2),
#  ('New Sensitivity 100킮 ', 2),
#  ('T5, T4 check', 2),
#  ('Pz recheck', 2),
#  ('HV - Dur: 160.6 sec. - On', 2),
#  ('T6 recheck', 2),
#  ('mouse open', 2),
#  ('check electrode A1', 2),
#  ('HV - Dur: 164.9 sec. - On', 2),
#  ('P4 recheck', 2),
#  ('HV - Dur: 153.7 sec. - On', 2),
#  ('Fz check', 2),
#  ('O2 check', 2),
#  ('obey ok', 2),
#  ('O2 Recheck', 2),
#  ('HV - Dur: 191.9 sec. - On', 2),
#  ('HV - Dur: 167.2 sec. - On', 2),
#  ('HV - Dur: 154.8 sec. - On', 2),
#  ('Fp2  recheck', 2),
#  ('HV - Dur: 182.1 sec. - On', 2),
#  ('HV - Dur: 159.6 sec. - On', 1),
#  ('eyelid move', 1),
#  ('F3, F8 check', 1),
#  ('HV - Dur: 189.0 sec. - On', 1),
#  ('recheck', 1),
#  ('o1 Recheck', 1),
#  ('HV - Dur: 163.1 sec. - On', 1),
#  ('Seizure', 1),
#  ('HV - Dur: 172.4 sec. - On', 1),
#  ('Drowsy ++', 1),
#  ('HV - Dur: 161.9 sec. - On', 1),
#  ('F7 , O1 check', 1),
#  ('HV - Dur: 182.6 sec. - On', 1),
#  ('C4 Recheck', 1),
#  ('HV - Dur: 157.3 sec. - On', 1),
#  ('HV - Dur: 166.3 sec. - On', 1),
#  ('FP2  Recheck', 1),
#  ('A2 reckeck', 1),
#  ('A1 reckeck', 1),
#  ('machine touch', 1),
#  ('F7, A2 check', 1),
#  ('F7, F8 check', 1),
#  ('T6check', 1),
#  ('F7  Recheck', 1),
#  ('FZ Recheck', 1),
#  ('Fz recheck', 1),
#  ('F4 , Fp1 check', 1),
#  (' Drowsy ++++++++++', 1),
#  ('HV - Dur: 174.7 sec. - On', 1),
#  ('HV - Dur: 160.2 sec. - On', 1),
#  ('FP1, FP2 Recheck', 1),
#  ('HV - Dur: 173.5 sec. - On', 1),
#  ('O1,O2 recheck', 1),
#  ('New Low Filters  0.3Hz Notch  ', 1),
#  ('HV - Dur: 178.1 sec. - On', 1),
#  ('eye blinking  --->>', 1),
#  ('eye blinking  -', 1),
#  ('T6, O1 check', 1),
#  ('T6 Recheck', 1),
#  ('HV - Dur: 171.4 sec. - On', 1),
#  ('HV - Dur: 119.1 sec. - On', 1),
#  ('HV - Dur: 160.7 sec. - On', 1),
#  ('C3 Recheck', 1),
#  ('F8recheck', 1),
#  ('F3 Recheck', 1),
#  ('New Low Filters  3.0Hz Notch  ', 1),
#  ('lip smacking', 1),
#  ('HV - Dur: 182.5 sec. - On', 1),
#  ('Mouth open', 1),
#  ('HV - Dur: 181.1 sec. - On', 1),
#  ('HV - Dur: 162.1 sec. - On', 1),
#  ('HV - Dur: 168.2 sec. - On', 1),
#  ('O1, P4 check', 1),
#  ('FP2 rechech', 1),
#  ('HV - Dur: 218.4 sec. - On', 1),
#  ('C3 recheck', 1),
#  ('HV - Dur: 159.0 sec. - On', 1),
#  ('eye movement', 1),
#  ('EKG check', 1),
#  ('T4, O2 check', 1),
#  ('HV - Dur: 182.8 sec. - On', 1),
#  ('o1 RECHECK', 1),
#  ('refuse', 1),
#  ('fp1 Recheck', 1),
#  ('New Sensitivity 150킮 ', 1),
#  ('T3 re check', 1),
#  ('T3 electrode change', 1),
#  ('New Sensitivity 200킮 ', 1),
#  ('Fp1, Fp2 check', 1),
#  ('Sleep', 1),
#  ('F8, T5 check', 1),
#  ('HV - Dur: 180.2 sec. - On', 1),
#  ('Continuous chewing', 1),
#  ('HV - Dur: 167.4 sec. - On', 1),
#  ('HV - Dur: 149.5 sec. - On', 1),
#  ('HV - Dur: 168.9 sec. - On', 1),
#  ('HV - Dur: 166.7 sec. - On', 1),
#  ('HV - Dur: 171.9 sec. - On', 1),
#  ('HV - Dur: 165.5 sec. - On', 1),
#  ('A1, F8 Recheck', 1),
#  ('HV - Dur: 159.2 sec. - On', 1),
#  ('Fp1 Fp2 check', 1),
#  ('HV - Dur: 173.7 sec. - On', 1),
#  ('HV - Dur: 163.2 sec. - On', 1),
#  ('Open eyes', 1),
#  ('A1, A2 recheck', 1),
#  ('A1, recheck', 1),
#  ('HV - Dur: 185.9 sec. - On', 1),
#  ('HV - Dur: 193.7 sec. - On', 1),
#  ('HV - Dur: 157.9 sec. - On', 1),
#  ('C3, T5 recheck', 1),
#  ('HV - Dur: 160.5 sec. - On', 1),
#  ('C4,P4 check', 1),
#  ('P3, F4 check', 1),
#  ('HV - Dur: 147.8 sec. - On', 1),
#  ('F7,F8,T4 check', 1),
#  ('name - obey ok', 1),
#  ('p4 Recheck', 1),
#  ('HV - Dur: 163.4 sec. - On', 1),
#  ('HV - Dur: 185.2 sec. - On', 1),
#  ('HV - Dur: 142.8 sec. - On', 1),
#  ('FP1 check', 1),
#  ('HV - Dur: 172.8 sec. - On', 1),
#  ('F4, 8 rechech', 1),
#  ('New Sensitivity 750킮 EKG ', 1),
#  ('HV - On', 1),
#  ('Post HV - On', 1),
#  ('HV - Dur: 141.3 sec. - On', 1),
#  ('HV - Dur: 182.3 sec. - On', 1),
#  ('HV - Dur: 183.2 sec. - On', 1),
#  ('HV - Dur: 176.9 sec. - On', 1),
#  ('HV - Dur: 151.8 sec. - On', 1),
#  ('PZ  check', 1),
#  ('Fp1, P3 recheck', 1),
#  ('HV - Dur: 231.0 sec. - On', 1),
#  ('eye blinking -------->>>', 1),
#  ('A1, 2 recheck', 1),
#  ('A2 RECHECK', 1),
#  ('Recheck', 1),
#  ('HV - Dur: 176.0 sec. - On', 1),
#  ('HV - Dur: 155.0 sec. - On', 1),
#  ('electrode touch', 1),
#  ('machine touch artifact', 1),
#  ('blink', 1),
#  ('emg', 1),
#  ('Patient Disconnected', 1),
#  ('Patient Connected', 1),
#  ('HV - Dur: 139.4 sec. - On', 1),
#  ('HV - Dur: 160.3 sec. - On', 1),
#  ('F4Recheck', 1),
#  ('Fp2 Recheck', 1),
#  ('HV - Dur: 162.3 sec. - On', 1),
#  ('HV - Dur:  2.9 sec. - On', 1),
#  ('HV - Dur:  1.0 sec. - On', 1),
#  ('HV - Dur: 162.5 sec. - On', 1),
#  ('HV - Dur: 163.6 sec. - On', 1),
#  ('HV - Dur: 154.4 sec. - On', 1),
#  ('HV - Dur: 177.5 sec. - On', 1),
#  ('HV - Dur: 162.2 sec. - On', 1),
#  ('HV - Dur: 157.2 sec. - On', 1),
#  ('HV - Dur: 160.8 sec. - On', 1),
#  ('TA2Recheck', 1),
#  ('HV - Dur: 140.5 sec. - On', 1),
#  ('Fz Recheck', 1),
#  ('HV - Dur: 161.3 sec. - On', 1),
#  ('HV - Dur: 163.5 sec. - On', 1),
#  ('HV - Dur: 164.2 sec. - On', 1),
#  ('HV - Dur: 154.2 sec. - On', 1),
#  ('FP2 Recheck', 1),
#  ('Head move', 1),
#  ('HV - Dur: 159.9 sec. - On', 1),
#  ('CZ recheck', 1),
#  ('Fp1 , Fp2 check', 1),
#  ('HV - Dur: 132.5 sec. - On', 1),
#  ('O1,T5 check', 1),
#  ('Fp1,F7 check', 1),
#  ('P3,T5 check', 1),
#  ('P3,T5,A2 check', 1),
#  ('C3\\\\F7 recheck', 1),
#  ('PZ Recheck', 1),
#  ('Awake', 1),
#  ('F8  check', 1),
#  ('F8 Check', 1),
#  ('New Low Filters  1.0Hz Notch  T4-A2 ', 1),
#  ('New Low Filters  0.3Hz Notch  T4-A2 ', 1),
#  ('New Montage - Montage 003', 1),
#  ('Fp1 check', 1),
#  ('HV - Dur: 179.2 sec. - On', 1),
#  ('Drowsy', 1),
#  ('HV - Dur: 181.7 sec. - On', 1),
#  ('sweat +++++++++', 1),
#  ('HV - Dur: 173.3 sec. - On', 1),
#  ('A1, A2 Recheck', 1),
#  ('Fp2 check', 1),
#  ('HV - Dur: 180.9 sec. - On', 1),
#  ('eye blink', 1),
#  (' check', 1),
#  ('HV - Dur: 180.7 sec. - On', 1),
#  ('F8,T3,C3 check', 1),
#  ('HV - Dur: 181.5 sec. - On', 1),
#  ('HV - Dur: 175.4 sec. - On', 1)]

# %% [markdown]
# ## 데이터셋 구성 및 저장
#
# 1. EDF / Signal Header Label 불일치 데이터 제거
# 2. EDF $\rightarrow$ NumPy Pickle 변환하여 저장
# 3. Metadata 정리 후 저장
#     - `metadata_debug`: 디버깅을 위해 모든 정보를 총망라한 버전
#     - `metadata_public`: 익명화까지 수행하여 향후 공개가 가능한 버전

# %%
def birth_to_datetime(b):
    if b is None:
        return None
    try:
        if type(b) is int:
            y = (b // 10000) + 1900
            m = (b % 10000) // 100
            d = b % 100
            return datetime.date(y, m, d)
        elif type(b) is str:
            b = int(b)
            y = (b // 10000) + 1900
            m = (b % 10000) // 100
            d = b % 100
            return datetime.date(y, m, d)
    except:
        print(f'WARNING - Input to birth_to_datetime() is uninterpretable: {type(b)}, {b}')
    return None


def calculate_age(birth, record):
    if birth is None:
        return None
    try:
        age = (record - relativedelta(years=birth.year, months=birth.month, days=birth.day)).year
        if age < 40 or 100 < age:
            print(f'WARNING - calculate_age() generated an unordinary age: {age}')
        return age
    except Exception as e:
        print(f'WARNING - calculate_age() has an exception: {e}')
    return None


def serialize_json(obj):
    """JSON serializer for objects not serializable by default json code"""

    if isinstance(obj, datetime.datetime) or isinstance(obj, datetime.date):
        serial = obj.isoformat()
        return serial

    if isinstance(obj, MultiLabel):
        serial = obj.get_true_keys()
        return serial

    return obj.__dict__

# %%
warnings.filterwarnings(action='ignore')

text = f'Delete ALL files in {os.path.join(root_path, curated_folder)}?'
if ctypes.windll.user32.MessageBoxExW(0, text, 'Question', 4) == 6: # Yes
    for f in glob.glob(os.path.join(root_path, curated_folder, '*.*')):
        os.remove(f)

metadata_debug = []
metadata_public = []

for m in tqdm(metadata):
    # EDF file check
    edf_file = os.path.join(root_path, original_folder, m['edfname'] + '.edf')
    signals, signal_headers, edf_header = pyedflib.highlevel.read_edf(edf_file)
        
    if refer_headers != signal_headers:
        print('- Signal header differs from the majority:', m['edfname'])
        continue
        
    # calculate age
    age = calculate_age(birth_to_datetime(m['birth']), 
                        edf_header['startdate'])
    
    # EDF recoding events
    event_file = os.path.join(root_path, original_folder, m['edfname'] + '.xlsx')
    wb = load_workbook(event_file, data_only=True)
    ws = wb[wb.sheetnames[0]]
    
    num = 2
    events = [] 
    
    while True:
        t = ws.cell(row=num, column=3).value
        e = ws.cell(row=num, column=4).value
        
        if t is None:
            break
        
        t = edf_header['startdate'].strftime('%Y%m%d') + t
        t = datetime.datetime.strptime(t, '%Y%m%d %H:%M:%S.%f')
        
        if num == 2: 
            startTime = t
            
        t = int(np.floor((t - startTime).total_seconds() * 200))
        events.append((t, e))
        num += 1
    
    # metadata_debug
    m2 = {}
    m2['serial'] = f'{len(metadata_debug) + 1:05}'
    m2['edfname'] = m['edfname']
    m2['birth'] = birth_to_datetime(m['birth'])
    m2['record'] = edf_header['startdate']
    m2['age'] = age
    m2['dx1'] = m['dx1']
    m2['label'] = MultiLabel.load_from_string(m['dx1'])
    m2['events'] = events
    metadata_debug.append(m2)
    
    # metadata_public
    m3 = {}
    m3['serial'] = m2['serial']
    m3['age'] = age
    m3['label'] = m2['label']
    metadata_public.append(m3)
    
    # EDF signal
    signals = trim_zero_columns(signals)
    fname = os.path.join(root_path, curated_folder, m2['serial'])
    np.save(fname, signals.astype('float32'))
    
print('Done.')
print()
print(f'Among {len(metadata)}, {len(metadata_public)} data were saved.')

warnings.filterwarnings(action='default')
# Out:
#   0%|          | 0/1387 [00:00<?, ?it/s]
# WARNING - calculate_age() generated an unordinary age: 39
# WARNING - calculate_age() generated an unordinary age: 39
# Among 1387, 1387 data were saved.

# %%
pprint.pp(metadata_debug[:5])
# Out:
# [{'serial': '00001',
#   'edfname': '00001809_261018',
#   'birth': datetime.date(1940, 6, 2),
#   'record': datetime.datetime(2018, 10, 26, 15, 46, 26),
#   'age': 78,
#   'dx1': 'mci_rf',
#   'label': MultiLabel{'mci': True, 'mci_amnestic': True, 'mci_amnestic_rf': True},
#   'events': [(0, 'Start Recording'),
#              (0, 'New Montage - Montage 002'),
#              (36396, 'Eyes Open'),
#              (72518, 'Eyes Closed'),
#              (73862, 'Eyes Open'),
#              (75248, 'Eyes Closed'),
#              (76728, 'swallowing'),
#              (77978, 'Eyes Open'),
#              (79406, 'Eyes Closed'),
#              (79996, 'Photic On - 3.0 Hz'),
#              (80288, 'Eyes Open'),
#              (81296, 'Eyes Closed'),
#              (82054, 'Photic Off'),
#              (84070, 'Photic On - 6.0 Hz'),
#              (84488, 'Eyes Open'),
#              (85538, 'Eyes Closed'),
#              (86086, 'Photic Off'),
#              (88144, 'Photic On - 9.0 Hz'),
#              (90160, 'Photic Off'),
#              (91458, 'Eyes Open'),
#              (92218, 'Photic On - 12.0 Hz'),
#              (92762, 'Eyes Closed'),
#              (94198, 'Photic Off'),
#              (94742, 'Eyes Open'),
#              (95708, 'Eyes Closed'),
#              (96256, 'Photic On - 15.0 Hz'),
#              (98272, 'Photic Off'),
#              (100330, 'Photic On - 18.0 Hz'),
#              (102346, 'Photic Off'),
#              (102596, 'Eyes Open'),
#              (103856, 'Eyes Closed'),
#              (104361, 'Photic On - 21.0 Hz'),
#              (106420, 'Photic Off'),
#              (106880, 'Eyes Open'),
#              (107804, 'Eyes Closed'),
#              (108435, 'Photic On - 24.0 Hz'),
#              (110452, 'Photic Off'),
#              (111080, 'Eyes Open'),
#              (112004, 'Eyes Closed'),
#              (112509, 'Photic On - 27.0 Hz'),
#              (114528, 'Photic Off'),
#              (114864, 'Eyes Open'),
#              (116124, 'Eyes Closed'),
#              (116544, 'Photic On - 30.0 Hz'),
#              (118602, 'Photic Off'),
#              (126672, 'artifact'),
#              (134030, 'Move'),
#              (135584, 'Eyes Open'),
#              (136668, 'Eyes Closed'),
#              (139818, 'Eyes Open'),
#              (141414, 'Eyes Closed'),
#              (145000, 'Paused')]},
#  {'serial': '00002',
#   'edfname': '00029426_020817',
#   'birth': datetime.date(1960, 12, 4),
#   'record': datetime.datetime(2017, 8, 2, 16, 14, 56),
#   'age': 56,
#   'dx1': 'smi',
#   'label': MultiLabel{'normal': True, 'smi': True},
#   'events': [(0, 'Start Recording'),
#              (0, 'New Montage - Montage 002'),
#              (1252, 'Eyes Open'),
#              (6124, 'Eyes Closed'),
#              (12514, 'Eyes Open'),
#              (19300, 'Move'),
#              (20746, 'Eyes Closed'),
#              (20802, 'Move'),
#              (24400, 'Eyes Open'),
#              (30112, 'Eyes Closed'),
#              (36286, 'Eyes Open'),
#              (38806, 'Move'),
#              (42292, 'Eyes Closed'),
#              (48256, 'Eyes Open'),
#              (54346, 'Eyes Closed'),
#              (60058, 'Eyes Open'),
#              (66736, 'Eyes Closed'),
#              (72196, 'Eyes Open'),
#              (78370, 'Eyes Closed'),
#              (84208, 'Eyes Open'),
#              (90130, 'Eyes Closed'),
#              (108064, 'Eyes Open'),
#              (108652, 'Move'),
#              (113944, 'Eyes Closed'),
#              (123226, 'Eyes Open'),
#              (124233, 'HV - Dur: 159.6 sec. - On'),
#              (128644, 'Eyes Closed'),
#              (138980, 'Eyes Open'),
#              (142550, 'Eyes Closed'),
#              (155486, 'Eyes Open'),
#              (156158, 'HV - Off'),
#              (157460, 'Eyes Closed'),
#              (158930, 'HV fair'),
#              (159980, 'Eyes Open'),
#              (162374, 'Eyes Closed'),
#              (163844, 'Photic On - 3.0 Hz'),
#              (164432, 'Eyes Open'),
#              (165104, 'Eyes Closed'),
#              (165860, 'Photic Off'),
#              (167918, 'Photic On - 6.0 Hz'),
#              (168632, 'Eyes Open'),
#              (169430, 'Eyes Closed'),
#              (169934, 'Photic Off'),
#              (171992, 'Photic On - 9.0 Hz'),
#              (174008, 'Photic Off'),
#              (176024, 'Photic On - 12.0 Hz'),
#              (176570, 'Eyes Open'),
#              (177368, 'Eyes Closed'),
#              (178040, 'Photic Off'),
#              (180098, 'Photic On - 15.0 Hz'),
#              (182114, 'Photic Off'),
#              (184172, 'Photic On - 18.0 Hz'),
#              (184928, 'Eyes Open'),
#              (185516, 'Eyes Closed'),
#              (186188, 'Photic Off'),
#              (188204, 'Photic On - 21.0 Hz'),
#              (190262, 'Photic Off'),
#              (192278, 'Photic On - 24.0 Hz'),
#              (194294, 'Photic Off'),
#              (196352, 'Photic On - 27.0 Hz'),
#              (198368, 'Photic Off'),
#              (200384, 'Photic On - 30.0 Hz'),
#              (202446, 'Photic Off'),
#              (203620, 'Eyes Open'),
#              (205300, 'Eyes Closed'),
#              (207600, 'Paused')]},
#  {'serial': '00003',
#   'edfname': '00047327_090718',
#   'birth': datetime.date(1924, 10, 19),
#   'record': datetime.datetime(2018, 7, 9, 15, 29, 10),
#   'age': 93,
#   'dx1': 'vascular mci',
#   'label': MultiLabel{'mci': True, 'mci_vascular': True},
#   'events': [(0, 'Start Recording'),
#              (0, 'New Montage - Montage 002'),
#              (2050, 'Eyes Closed'),
#              (11390, 'artifact'),
#              (13534, 'artifact'),
#              (18698, 'Move'),
#              (25536, 'Move'),
#              (35902, 'Eyes Open'),
#              (38880, 'Move'),
#              (72576, 'Eyes Closed'),
#              (77154, 'Eyes Open'),
#              (78960, 'Eyes Closed'),
#              (85136, 'Photic On - 3.0 Hz'),
#              (85778, 'Eyes Open'),
#              (86562, 'Eyes Closed'),
#              (87152, 'Photic Off'),
#              (89180, 'Photic On - 6.0 Hz'),
#              (91198, 'Photic Off'),
#              (93256, 'Photic On - 9.0 Hz'),
#              (95272, 'Photic Off'),
#              (95818, 'Eyes Open'),
#              (96784, 'Eyes Closed'),
#              (97330, 'Photic On - 12.0 Hz'),
#              (99346, 'Photic Off'),
#              (101362, 'Photic On - 15.0 Hz'),
#              (103378, 'Photic Off'),
#              (105435, 'Photic On - 18.0 Hz'),
#              (107452, 'Photic Off'),
#              (109509, 'Photic On - 21.0 Hz'),
#              (111526, 'Photic Off'),
#              (113542, 'Photic On - 24.0 Hz'),
#              (115600, 'Photic Off'),
#              (117616, 'Photic On - 27.0 Hz'),
#              (119632, 'Photic Off'),
#              (121690, 'Photic On - 30.0 Hz'),
#              (123706, 'Photic Off'),
#              (124335, 'Eyes Open'),
#              (125974, 'Eyes Closed'),
#              (130000, 'Paused')]},
#  {'serial': '00004',
#   'edfname': '00048377_070819',
#   'birth': datetime.date(1941, 3, 16),
#   'record': datetime.datetime(2019, 8, 7, 13, 55, 25),
#   'age': 78,
#   'dx1': 'load',
#   'label': MultiLabel{'dementia': True, 'ad': True, 'load': True},
#   'events': [(0, 'Start Recording'),
#              (0, 'New Montage - Montage 005'),
#              (1178, 'Eyes Closed'),
#              (5168, 'Eyes Open'),
#              (12098, 'Eyes Closed'),
#              (18440, 'Eyes Open'),
#              (23690, 'Eyes Closed'),
#              (29738, 'Eyes Open'),
#              (34736, 'Eyes Closed'),
#              (42044, 'Eyes Open'),
#              (47468, 'Eyes Closed'),
#              (54524, 'Eyes Open'),
#              (61370, 'Eyes Closed'),
#              (66582, 'Eyes Open'),
#              (72546, 'Eyes Closed'),
#              (81786, 'Eyes Open'),
#              (82794, 'Eyes Closed'),
#              (84222, 'Photic On - 3.0 Hz'),
#              (84642, 'Eyes Open'),
#              (85652, 'Eyes Closed'),
#              (86242, 'Photic Off'),
#              (88258, 'Photic On - 6.0 Hz'),
#              (88844, 'Eyes Open'),
#              (89852, 'Eyes Closed'),
#              (90274, 'Photic Off'),
#              (92332, 'Photic On - 9.0 Hz'),
#              (94350, 'Photic Off'),
#              (94602, 'Eyes Open'),
#              (95946, 'Eyes Closed'),
#              (96408, 'Photic On - 12.0 Hz'),
#              (98424, 'Photic Off'),
#              (100440, 'Photic On - 15.0 Hz'),
#              (100860, 'Eyes Open'),
#              (101700, 'Eyes Closed'),
#              (102456, 'Photic Off'),
#              (104514, 'Photic On - 18.0 Hz'),
#              (106530, 'Photic Off'),
#              (108588, 'Photic On - 21.0 Hz'),
#              (110604, 'Photic Off'),
#              (112620, 'Photic On - 24.0 Hz'),
#              (114678, 'Photic Off'),
#              (115476, 'Eyes Open'),
#              (116274, 'Eyes Closed'),
#              (116694, 'Photic On - 27.0 Hz'),
#              (118709, 'Photic Off'),
#              (120096, 'Eyes Open'),
#              (120768, 'Photic On - 30.0 Hz'),
#              (121009, 'Eyes Closed'),
#              (122783, 'Photic Off'),
#              (123992, 'Eyes Open'),
#              (127724, 'Eyes Closed'),
#              (133662, 'Eyes Open'),
#              (134502, 'Eyes Closed'),
#              (138366, 'Eyes Open'),
#              (139374, 'Eyes Closed'),
#              (143994, 'Eyes Open'),
#              (145842, 'Eyes Closed'),
#              (153716, 'Eyes Open'),
#              (155462, 'Eyes Closed'),
#              (157272, 'Eyes Open'),
#              (158364, 'Eyes Closed'),
#              (168200, 'Paused')]},
#  {'serial': '00005',
#   'edfname': '00048377_070916',
#   'birth': datetime.date(1941, 3, 16),
#   'record': datetime.datetime(2016, 9, 7, 10, 36, 1),
#   'age': 75,
#   'dx1': 'load',
#   'label': MultiLabel{'dementia': True, 'ad': True, 'load': True},
#   'events': [(0, 'Start Recording'),
#              (0, 'New Montage - Montage 002'),
#              (2166, 'Eyes Open'),
#              (3594, 'Eyes Closed'),
#              (8173, 'Eyes Open'),
#              (10190, 'Eyes Closed'),
#              (14558, 'Eyes Open'),
#              (15691, 'Eyes Closed'),
#              (17750, 'Eyes Open'),
#              (18884, 'Eyes Closed'),
#              (25522, 'Photic On - 3.0 Hz'),
#              (25939, 'Eyes Closed'),
#              (27538, 'Photic Off'),
#              (29595, 'Photic On - 6.0 Hz'),
#              (30182, 'Eyes Open'),
#              (30854, 'Eyes Closed'),
#              (31612, 'Photic Off'),
#              (33628, 'Photic On - 9.0 Hz'),
#              (34172, 'Eyes Open'),
#              (34802, 'Eyes Closed'),
#              (35644, 'Photic Off'),
#              (37702, 'Photic On - 12.0 Hz'),
#              (38246, 'Eyes Open'),
#              (38960, 'Eyes Closed'),
#              (39718, 'Photic Off'),
#              (41776, 'Photic On - 15.0 Hz'),
#              (42320, 'Eyes Open'),
#              (43118, 'Eyes Closed'),
#              (43792, 'Photic Off'),
#              (45808, 'Photic On - 18.0 Hz'),
#              (47824, 'Photic Off'),
#              (49884, 'Photic On - 21.0 Hz'),
#              (50808, 'Eyes Open'),
#              (51522, 'Eyes Closed'),
#              (51900, 'Photic Off'),
#              (53967, 'Photic On - 24.0 Hz'),
#              (55984, 'Photic Off'),
#              (58000, 'Photic On - 27.0 Hz'),
#              (60016, 'Photic Off'),
#              (62074, 'Photic On - 30.0 Hz'),
#              (64090, 'Photic Off'),
#              (65138, 'Eyes Open'),
#              (66146, 'Eyes Closed'),
#              (77906, 'Eyes Open'),
#              (78180, 'Move'),
#              (79292, 'Eyes Closed'),
#              (81266, 'Eyes Open'),
#              (82610, 'Eyes Closed'),
#              (87398, 'Eyes Open'),
#              (89582, 'Eyes Closed'),
#              (95084, 'Eyes Open'),
#              (96680, 'Eyes Closed'),
#              (105122, 'Eyes Open'),
#              (106382, 'Eyes Closed'),
#              (108314, 'Eyes Open'),
#              (109448, 'Eyes Closed'),
#              (110796, 'Move'),
#              (111548, 'Eyes Open'),
#              (113396, 'Eyes Closed'),
#              (116126, 'Eyes Open'),
#              (117470, 'Eyes Closed'),
#              (129272, 'Eyes Open'),
#              (130909, 'Eyes Closed'),
#              (132422, 'Eyes Open'),
#              (133556, 'Eyes Closed'),
#              (135446, 'Eyes Open'),
#              (136962, 'Eyes Closed'),
#              (144564, 'Eyes Open'),
#              (145740, 'Eyes Closed'),
#              (147168, 'Eyes Open'),
#              (148428, 'Eyes Closed'),
#              (150402, 'Eyes Open'),
#              (151956, 'Eyes Closed'),
#              (165320, 'Eyes Open'),
#              (165734, 'Move'),
#              (166328, 'Eyes Closed'),
#              (167672, 'Eyes Open'),
#              (168848, 'Eyes Closed'),
#              (170318, 'Eyes Open'),
#              (171578, 'Eyes Closed'),
#              (178976, 'Eyes Open'),
#              (180404, 'Eyes Closed'),
#              (183000, 'Paused')]}]

# %%
pprint.pp(metadata_public[:5])
# Out:
# [{'serial': '00001',
#   'age': 78,
#   'label': MultiLabel{'mci': True, 'mci_amnestic': True, 'mci_amnestic_rf': True}},
#  {'serial': '00002',
#   'age': 56,
#   'label': MultiLabel{'normal': True, 'smi': True}},
#  {'serial': '00003',
#   'age': 93,
#   'label': MultiLabel{'mci': True, 'mci_vascular': True}},
#  {'serial': '00004',
#   'age': 78,
#   'label': MultiLabel{'dementia': True, 'ad': True, 'load': True}},
#  {'serial': '00005',
#   'age': 75,
#   'label': MultiLabel{'dementia': True, 'ad': True, 'load': True}}]

# %%
# save metadata_public as JSON
path = os.path.join(root_path, curated_folder, 'metadata_public.json')
with open(path, 'w') as json_file:
    json.dump(metadata_public, json_file, indent=4, default=serialize_json)
    
# save metadata_public as XLSX
wb = Workbook()
ws = wb.active
ws.title = 'metadata'
ws.cell(row=1, column=1).value = 'serial'
ws.cell(row=1, column=2).value = 'age'
for (i, label) in enumerate(metadata_debug[0]['label'].get_label_types()):
    ws.cell(row=1, column=3 + i).value = label

for (i, m) in enumerate(metadata_debug):
    ws.cell(row=2 + i, column=1).value = m['serial']
    ws.cell(row=2 + i, column=2).value = m['age']
    for (k, label) in enumerate(m['label'].get_label_values()):
        ws.cell(row=2 + i, column=3 + k).value = label if label is not False else None
    
    # coloring
    color = 'FDFDD0' if i % 2 == 0 else 'D9E5FF'
    for rows in ws.iter_rows(min_row=2 + i, max_row=2 + i, min_col=1, max_col=2 + m['label'].get_size()):
        for cell in rows:
            cell.fill = styles.PatternFill(start_color=color, end_color=color, fill_type="solid")

path = os.path.join(root_path, curated_folder, 'metadata_public.xlsx')
wb.save(path)

# %%
# save metadata_debug as JSON
path = os.path.join(root_path, curated_folder, 'metadata_debug.json')
with open(path, 'w') as json_file:
    json.dump(metadata_debug, json_file, indent=4, default=serialize_json)

# save metadata_debug as XLSX
wb = Workbook()
ws = wb.active
ws.title = 'metadata'
ws.cell(row=1, column=1).value = 'serial'
ws.cell(row=1, column=2).value = 'EDF file'
ws.cell(row=1, column=3).value = 'birth'
ws.cell(row=1, column=4).value = 'record'
ws.cell(row=1, column=5).value = 'age'
ws.cell(row=1, column=6).value = 'dx1'
for (i, label) in enumerate(metadata_debug[0]['label'].get_label_types()):
    ws.cell(row=1, column=7 + i).value = label

for (i, m) in enumerate(metadata_debug):
    ws.cell(row=2 + i, column=1).value = m['serial']
    ws.cell(row=2 + i, column=2).value = m['edfname']
    ws.cell(row=2 + i, column=3).value = m['birth']
    ws.cell(row=2 + i, column=4).value = m['record']
    ws.cell(row=2 + i, column=5).value = m['age']
    ws.cell(row=2 + i, column=6).value = m['dx1']
    for (k, label) in enumerate(m['label'].get_label_values()):
        ws.cell(row=2 + i, column=7 + k).value = label if label is not False else None
    
    # coloring
    color = 'FDFDD0' if i % 2 == 0 else 'D9E5FF'
    for rows in ws.iter_rows(min_row=2 + i, max_row=2 + i, min_col=1, max_col=6 + m['label'].get_size()):
        for cell in rows:
            cell.fill = styles.PatternFill(start_color=color, end_color=color, fill_type="solid")

path = os.path.join(root_path, curated_folder, 'metadata_debug.xlsx')
wb.save(path)
