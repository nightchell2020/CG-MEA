# %% [markdown]
# # Evaluate
#
# This notebook evaluates the network trained previous notebooks and analyzes the results.

# %% [markdown]
# -----
#
# ## Load Packages

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# C:\Users\Minjae\Desktop\EEG_Project

# %%
# Load some packages
import os
import sys
import pickle
from copy import deepcopy
import hydra
from omegaconf import OmegaConf
from collections import OrderedDict

import numpy as np
from sklearn.metrics import classification_report
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd

import pprint
import wandb
import matplotlib
import matplotlib.pyplot as plt

# custom package
from datasets.caueeg_script import build_dataset_for_train
import models
from train.evaluate import check_accuracy
from train.evaluate import check_accuracy_extended
from train.evaluate import check_accuracy_extended_debug
from train.evaluate import check_accuracy_multicrop
from train.evaluate import check_accuracy_multicrop_extended
from train.evaluate import calculate_class_wise_metrics
from train.visualize import draw_roc_curve
from train.visualize import draw_confusion
from train.visualize import draw_class_wise_metrics
from train.visualize import draw_error_table
from train.visualize import annotate_heatmap

# %%
print('PyTorch version:', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available(): print('cuda is available.')
else: print('cuda is unavailable.')
# Out:
# PyTorch version: 1.11.0+cu113
# cuda is available.

# %% [markdown]
# -----
#
# ## List up the models to check accuracy

# %%
model_names = [*set([
    '22pj8bg1',
    # '1663fxhy',
    # '3td60j3k',
    # 'umtq5iu6',
    # 'f9g4k64e',
    # 'kxyux4lz',
    # '03iz3rso',
    # '9d9rnxrx',
    # '3smz5tul',
    # '34oksw2q',
    # 'pz76l4fq',
    # 'ocf38th1',
    # 'nd1ss8ci',
    # 'nkrh4pji',
])]

model_pool = []

for model_name in model_names:
    path = os.path.join(r'E:\CAUEEG\checkpoint', model_name, 'checkpoint.pt')
    try:
        ckpt = torch.load(path, map_location=device)
        model_pool.append({'name': model_name, 'path': path})
    except Exception as e:
        print(e)
        print(f'- checkpoint cannot be opened: {path}')
        
pprint.pprint([model_dict['name'] for model_dict in model_pool])
# Out:
# ['22pj8bg1']

# %%
# model_pool = []

# api = wandb.Api()
# runs = api.runs('ipis-mjkim/caueeg-task2-ablation')

# for run in runs:
#     path = os.path.join(r'E:\CAUEEG\checkpoint', run.name, 'checkpoint.pt')
#     try:
#         ckpt = torch.load(path, map_location=device)
#         model_pool.append({'name': run.name, 'path': path})
#     except Exception as e:
#         print(e)
#         print(f'- {run.name}\'s checkpoint cannot be opened: {path}')
        
# pprint.pprint([model_dict['name'] for model_dict in model_pool])

# %% [markdown]
# ---
#
# ## Configurations

# %%
base_repeat = 32
verbose = False
dataset_path = r'local\dataset\02_Curated_Data_220715_seg_30s'

# %% [markdown]
# -----
#
# ## Load and check accuracy

# %%
for model_dict in model_pool:
    # load and parse the checkpoint
    ckpt = torch.load(model_dict['path'], map_location=device)
    model_state = ckpt['model_state']
    config = ckpt['config']
    config['dataset_path'] = dataset_path
    
    model_dict['model'] = config['model']
    model_dict['num_params'] = config.get('num_params', '???')
    model_dict['model size (MiB)'] = sys.getsizeof(pickle.dumps(model_state)) / (1024 * 1024)
    # torch.save(model_state, 'temptemptemp.pt')
    
    model_dict['seq_length'] = config['seq_length']
    model_dict['use_age'] = config['use_age']
    model_dict['photic'] = config['photic']
    model_dict['EKG'] = config['EKG']

    model_dict['awgn'] = config.get('awgn', 0)
    model_dict['awgn_age'] = config.get('awgn_age', 0)
    model_dict['mgn'] = config.get('mgn', 0)
    model_dict['mixup'] = config.get('mixup', 0)
    model_dict['dropout'] = config.get('dropout', 0)
    model_dict['weight_decay'] = config.get('weight_decay', '???')
    model_dict['fc_stages'] = config.get('fc_stages', 1)
    
    model_dict['minibatch'] = round(config['minibatch'])
    model_dict['total_samples'] = round(config.get('total_samples', config['iterations'] * config['minibatch']))
    model_dict['base_lr'] = config.get('base_lr', config.get('LR', '???'))
    model_dict['lr_scheduler_type'] = config.get('lr_scheduler_type', 'constant_with_decay')
    model_dict['warmup_steps'] = config.get('warmup_steps', '???')
    model_dict['seed'] = config.get('seed', '???')
    
    print('- checking for', model_dict['name'], config['model'], '...')
    
    # initiate the model
    if '_target_' in config:
        model = hydra.utils.instantiate(config).to(device)
    elif type(config['generator']) is str:
        config['generator'] = getattr(models, config['generator'].split('.')[-1])
        if 'block' in config:
            config['block'] = getattr(models, config['block'].split('.')[-1])
        model = config['generator'](**config).to(device)
    else:
        if 'block' in config:
            if config['block'] == models.resnet_1d.BottleneckBlock1D:
                config['block'] = 'bottleneck'
            elif config['block'] == models.resnet_2d.Bottleneck2D:
                config['block'] = 'bottleneck'
            elif config['block'] == models.resnet_1d.BasicBlock1D:
                config['block'] = 'basic'
            elif config['block'] == models.resnet_2d.BasicBlock2D:
                config['block'] = 'basic'
                
        model = config['generator'](**config).to(device)
    
    if config.get('ddp', False):
        model_state_ddp = deepcopy(model_state)
        model_state = OrderedDict()
        for k, v in model_state_ddp.items():
            name = k[7:]  # remove 'module.' of DataParallel/DistributedDataParallel
            model_state[name] = v
    
    model.load_state_dict(model_state)
    
    # reconfigure and update
    config.pop('cwd', 0)
    config['ddp'] = False
    config['crop_timing_analysis'] = False
    config['eval'] = True
    config['device'] = device
    
    repeat = round(base_repeat / config['crop_multiple'])
    model_dict['repeat'] = repeat
    model_dict['crop_multiple'] = config['crop_multiple']
    model_dict['test_crop_multiple'] = config['test_crop_multiple']
    
    # build dataset
    _ = build_dataset_for_train(config, verbose=verbose)
    train_loader = _[0]
    val_loader = _[1]
    test_loader = _[2]
    multicrop_test_loader = _[3]
# Out:
# - checking for 22pj8bg1 1D-Linear-SVM ...
# 47
# 6
# 6

# %%
print(len(train_loader.dataset))
print(len(val_loader.dataset))
print(len(test_loader.dataset))
# Out:
# 24417
# 3052
# 3052

# %%
for model_dict in model_pool:
    # load and parse the checkpoint
    ckpt = torch.load(model_dict['path'], map_location=device)
    model_state = ckpt['model_state']
    config = ckpt['config']
    config['dataset_path'] = dataset_path
    
    model_dict['model'] = config['model']
    model_dict['num_params'] = config.get('num_params', '???')
    model_dict['model size (MiB)'] = sys.getsizeof(pickle.dumps(model_state)) / (1024 * 1024)
    # torch.save(model_state, 'temptemptemp.pt')
    
    model_dict['seq_length'] = config['seq_length']
    model_dict['use_age'] = config['use_age']
    model_dict['photic'] = config['photic']
    model_dict['EKG'] = config['EKG']

    model_dict['awgn'] = config.get('awgn', 0)
    model_dict['awgn_age'] = config.get('awgn_age', 0)
    model_dict['mgn'] = config.get('mgn', 0)
    model_dict['mixup'] = config.get('mixup', 0)
    model_dict['dropout'] = config.get('dropout', 0)
    model_dict['weight_decay'] = config.get('weight_decay', '???')
    model_dict['fc_stages'] = config.get('fc_stages', 1)
    model_dict['activation'] = config.get('activation', 0)
    
    model_dict['minibatch'] = round(config['minibatch'])
    model_dict['total_samples'] = round(config.get('total_samples', config['iterations'] * config['minibatch']))
    model_dict['base_lr'] = config.get('base_lr', config.get('LR', '???'))
    model_dict['lr_scheduler_type'] = config.get('lr_scheduler_type', 'constant_with_decay')
    model_dict['warmup_steps'] = config.get('warmup_steps', '???')
    model_dict['seed'] = config.get('seed', '???')
    
    print('- checking for', model_dict['name'], config['model'], '...')
    
    # initiate the model
    if '_target_' in config:
        model = hydra.utils.instantiate(config).to(device)
    elif type(config['generator']) is str:
        config['generator'] = getattr(models, config['generator'].split('.')[-1])
        if 'block' in config:
            config['block'] = getattr(models, config['block'].split('.')[-1])
        model = config['generator'](**config).to(device)
    else:
        if 'block' in config:
            if config['block'] == models.resnet_1d.BottleneckBlock1D:
                config['block'] = 'bottleneck'
            elif config['block'] == models.resnet_2d.Bottleneck2D:
                config['block'] = 'bottleneck'
            elif config['block'] == models.resnet_1d.BasicBlock1D:
                config['block'] = 'basic'
            elif config['block'] == models.resnet_2d.BasicBlock2D:
                config['block'] = 'basic'
                
        model = config['generator'](**config).to(device)
    
    if config.get('ddp', False):
        model_state_ddp = deepcopy(model_state)
        model_state = OrderedDict()
        for k, v in model_state_ddp.items():
            name = k[7:]  # remove 'module.' of DataParallel/DistributedDataParallel
            model_state[name] = v
    
    model.load_state_dict(model_state)
    
    # reconfigure and update
    config.pop('cwd', 0)
    config['ddp'] = False
    config['crop_timing_analysis'] = False
    config['eval'] = True
    config['device'] = device
    
    repeat = round(base_repeat / config['crop_multiple'])
    model_dict['repeat'] = repeat
    model_dict['crop_multiple'] = config['crop_multiple']
    model_dict['test_crop_multiple'] = config['test_crop_multiple']
    
    # build dataset
    _ = build_dataset_for_train(config, verbose=verbose)
    train_loader = _[0]
    val_loader = _[1]
    test_loader = _[2]
    multicrop_test_loader = _[3]
    
    # train accuracy
    train_acc = check_accuracy(model, train_loader, 
                               config['preprocess_test'], config, repeat=repeat)
    model_dict['Train Accuracy'] = train_acc
    
    # val accuracy
    val_acc = check_accuracy(model, val_loader, 
                             config['preprocess_test'], config, repeat=repeat)
    model_dict['Validation Accuracy'] = val_acc
    
    # Test accuracy
    _ = check_accuracy_extended(model, test_loader, 
                                config['preprocess_test'], config, repeat=repeat)
    model_dict['Test Throughput'] = _[4]
    model_dict['Test Accuracy'] = _[0]
    test_class_wise_metrics = calculate_class_wise_metrics(_[3])
    
    for k, v in test_class_wise_metrics.items():
        for c in range(config['out_dims']):
            c_name = config['class_label_to_name'][c]
            model_dict[f'{k} ({c_name})'] = test_class_wise_metrics[k][c]
    
    # Multi-crop test accuracy
    _ = check_accuracy_multicrop_extended(model, multicrop_test_loader, 
                                          config['preprocess_test'], config, repeat=repeat)
    model_dict['Multi-Crop Test Throughput'] = _[4]
    model_dict['Multi-Crop Test Accuracy'] = _[0]
    multi_test_class_wise_metrics = calculate_class_wise_metrics(_[3])
    
    for k, v in multi_test_class_wise_metrics.items():
        for c in range(config['out_dims']):
            c_name = config['class_label_to_name'][c]
            model_dict[f'Multi-Crop {k} ({c_name})'] = multi_test_class_wise_metrics[k][c]
            
print('==== Finished ====')
# Out:
# - checking for 3smz5tul Ieracitano-CNN ...
# - checking for 9d9rnxrx 2D-ResNet-18 ...
# - checking for umtq5iu6 2D-ResNeXt-50 ...
# - checking for kxyux4lz 1D-ResNet-101 ...
# - checking for 3td60j3k 2D-ViT-B-16 ...
# - checking for 22pj8bg1 1D-Linear-SVM ...
# - checking for ocf38th1 1D-ResNet-50 ...
# - checking for pz76l4fq 2D-VGG-19 ...
# - checking for nd1ss8ci 1D-ResNet-18 ...
# - checking for nkrh4pji 1D-VGG-19 ...
# - checking for f9g4k64e 1D-ResNeXt-50 ...
# - checking for 03iz3rso 2D-ResNet-50 ...
# - checking for 1663fxhy 2D-ViT-B-16 ...
# - checking for 34oksw2q Ieracitano-CNN ...
# ==== Finished ====

# %%
pprint.pprint(model_pool)
# Out:
# [{'Accuracy (Dementia)': 0.864474115334207,
#   'Accuracy (MCI)': 0.7742566349934469,
#   'Accuracy (Normal)': 0.8196162352555701,
#   'EKG': 'X',
#   'F1-score (Dementia)': 0.74906154021158,
#   'F1-score (MCI)': 0.6952097877929081,
#   'F1-score (Normal)': 0.7492134895440374,
#   'Multi-Crop Accuracy (Dementia)': 0.8632044560943644,
#   'Multi-Crop Accuracy (MCI)': 0.7747276376146789,
#   'Multi-Crop Accuracy (Normal)': 0.8201486730013107,
#   'Multi-Crop F1-score (Dementia)': 0.7474098162292975,
#   'Multi-Crop F1-score (MCI)': 0.6956016436764116,
#   'Multi-Crop F1-score (Normal)': 0.7496401031941734,
#   'Multi-Crop Precision (Dementia)': 0.7770875923887404,
#   'Multi-Crop Precision (MCI)': 0.6978706865439605,
#   'Multi-Crop Precision (Normal)': 0.7262960201066092,
#   'Multi-Crop Recall (Dementia)': 0.7199155011655012,
#   'Multi-Crop Recall (MCI)': 0.693347308031774,
#   'Multi-Crop Recall (Normal)': 0.7745346371347785,
#   'Multi-Crop Sensitivity (Dementia)': 0.7199155011655012,
#   'Multi-Crop Sensitivity (MCI)': 0.693347308031774,
#   'Multi-Crop Sensitivity (Normal)': 0.7745346371347785,
#   'Multi-Crop Specificity (Dementia)': 0.9192399726526892,
#   'Multi-Crop Specificity (MCI)': 0.8227755341323606,
#   'Multi-Crop Specificity (Normal)': 0.8444563033651431,
#   'Multi-Crop Test Accuracy': 72.9040383355177,
#   'Multi-Crop Test Throughput': 4869.2773928999695,
#   'Precision (Dementia)': 0.7811387900355872,
#   'Precision (MCI)': 0.6969151029684858,
#   'Precision (Normal)': 0.7250309960049593,
#   'Recall (Dementia)': 0.7195148601398601,
#   'Recall (MCI)': 0.6935127978817299,
#   'Recall (Normal)': 0.7750647973609802,
#   'Sensitivity (Dementia)': 0.7195148601398601,
#   'Sensitivity (MCI)': 0.6935127978817299,
#   'Sensitivity (Normal)': 0.7750647973609802,
#   'Specificity (Dementia)': 0.9211628304466728,
#   'Specificity (MCI)': 0.8219287389265242,
#   'Specificity (Normal)': 0.8433576092415871,
#   'Test Accuracy': 72.9173492791612,
#   'Test Throughput': 9884.828225983185,
#   'Train Accuracy': 100.0,
#   'Validation Accuracy': 72.40129423328965,
#   'awgn': 0,
#   'awgn_age': 0,
#   'base_lr': 0.0006686096096470754,
#   'crop_multiple': 1,
#   'dropout': 0,
#   'fc_stages': 1,
#   'lr_scheduler_type': 'constant_with_decay',
#   'mgn': 0,
#   'minibatch': 512,
#   'mixup': 0.0,
#   'model': 'Ieracitano-CNN',
#   'model size (MiB)': 13.198659896850586,
#   'name': '3smz5tul',
#   'num_params': 3457995,
#   'path': 'E:\\CAUEEG\\checkpoint\\3smz5tul\\checkpoint.pt',
#   'photic': 'X',
#   'repeat': 32,
#   'seed': 0,
#   'seq_length': 1000,
#   'test_crop_multiple': 1,
#   'total_samples': 100000000,
#   'use_age': 'no',
#   'warmup_steps': 9766,
#   'weight_decay': 0.01},
#  {'Accuracy (Dementia)': 0.9992320609436435,
#   'Accuracy (MCI)': 0.9981876638269986,
#   'Accuracy (Normal)': 0.9988941677588467,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9986341534483073,
#   'F1-score (MCI)': 0.9975604041183685,
#   'F1-score (Normal)': 0.9984085818696216,
#   'Multi-Crop Accuracy (Dementia)': 0.9999590432503277,
#   'Multi-Crop Accuracy (MCI)': 0.999877129750983,
#   'Multi-Crop Accuracy (Normal)': 0.9999180865006553,
#   'Multi-Crop F1-score (Dementia)': 0.9999271508705472,
#   'Multi-Crop F1-score (MCI)': 0.999834537532403,
#   'Multi-Crop F1-score (Normal)': 0.9998821727347708,
#   'Multi-Crop Precision (Dementia)': 1.0,
#   'Multi-Crop Precision (MCI)': 0.999669129811404,
#   'Multi-Crop Precision (Normal)': 1.0,
#   'Multi-Crop Recall (Dementia)': 0.9998543123543123,
#   'Multi-Crop Recall (MCI)': 1.0,
#   'Multi-Crop Recall (Normal)': 0.9997643732327992,
#   'Multi-Crop Sensitivity (Dementia)': 0.9998543123543123,
#   'Multi-Crop Sensitivity (MCI)': 1.0,
#   'Multi-Crop Sensitivity (Normal)': 0.9997643732327992,
#   'Multi-Crop Specificity (Dementia)': 1.0,
#   'Multi-Crop Specificity (MCI)': 0.99980458572173,
#   'Multi-Crop Specificity (Normal)': 1.0,
#   'Multi-Crop Test Accuracy': 99.9877129750983,
#   'Multi-Crop Test Throughput': 387.8431962412184,
#   'Precision (Dementia)': 0.9986523401930432,
#   'Precision (MCI)': 0.996996996996997,
#   'Precision (Normal)': 0.9989974050483604,
#   'Recall (Dementia)': 0.9986159673659674,
#   'Recall (MCI)': 0.9981244483671668,
#   'Recall (Normal)': 0.997820452403393,
#   'Sensitivity (Dementia)': 0.9986159673659674,
#   'Sensitivity (MCI)': 0.9981244483671668,
#   'Sensitivity (Normal)': 0.997820452403393,
#   'Specificity (Dementia)': 0.9994729945305378,
#   'Specificity (MCI)': 0.9982249869723815,
#   'Specificity (Normal)': 0.9994663485685585,
#   'Test Accuracy': 99.81569462647444,
#   'Test Throughput': 3264.549564166187,
#   'Train Accuracy': 99.99333579396325,
#   'Validation Accuracy': 99.82900557011796,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.0001290506491335074,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 384,
#   'mixup': 0.1,
#   'model': '2D-ResNet-18',
#   'model size (MiB)': 43.826613426208496,
#   'name': '9d9rnxrx',
#   'num_params': 11466947,
#   'path': 'E:\\CAUEEG\\checkpoint\\9d9rnxrx\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 13021,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9992423001310616,
#   'Accuracy (MCI)': 0.9990579947575361,
#   'Accuracy (Normal)': 0.9996928243774574,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9986538111697291,
#   'F1-score (MCI)': 0.9987299133027776,
#   'F1-score (Normal)': 0.9995583168929065,
#   'Multi-Crop Accuracy (Dementia)': 0.9996313892529489,
#   'Multi-Crop Accuracy (MCI)': 0.9993856487549148,
#   'Multi-Crop Accuracy (Normal)': 0.999754259501966,
#   'Multi-Crop F1-score (Dementia)': 0.9993448351168377,
#   'Multi-Crop F1-score (MCI)': 0.9991718655109589,
#   'Multi-Crop F1-score (Normal)': 0.999646684725003,
#   'Multi-Crop Precision (Dementia)': 0.9986905281536447,
#   'Multi-Crop Precision (MCI)': 1.0,
#   'Multi-Crop Precision (Normal)': 0.9992936190251942,
#   'Multi-Crop Recall (Dementia)': 1.0,
#   'Multi-Crop Recall (MCI)': 0.9983451015004413,
#   'Multi-Crop Recall (Normal)': 1.0,
#   'Multi-Crop Sensitivity (Dementia)': 1.0,
#   'Multi-Crop Sensitivity (MCI)': 0.9983451015004413,
#   'Multi-Crop Sensitivity (Normal)': 1.0,
#   'Multi-Crop Specificity (Dementia)': 0.9994872379216043,
#   'Multi-Crop Specificity (MCI)': 1.0,
#   'Multi-Crop Specificity (Normal)': 0.9996233048719236,
#   'Multi-Crop Test Accuracy': 99.93856487549148,
#   'Multi-Crop Test Throughput': 130.59021249569938,
#   'Precision (Dementia)': 0.9976012211964818,
#   'Precision (MCI)': 0.9997788833609729,
#   'Precision (Normal)': 0.9992934942596409,
#   'Recall (Dementia)': 0.9997086247086248,
#   'Recall (MCI)': 0.9976831421006178,
#   'Recall (Normal)': 0.9998232799245994,
#   'Sensitivity (Dementia)': 0.9997086247086248,
#   'Sensitivity (MCI)': 0.9976831421006178,
#   'Sensitivity (Normal)': 0.9998232799245994,
#   'Specificity (Dementia)': 0.999059936189608,
#   'Specificity (MCI)': 0.9998697238144867,
#   'Specificity (Normal)': 0.9996233048719236,
#   'Test Accuracy': 99.89965596330275,
#   'Test Throughput': 1109.502514846683,
#   'Train Accuracy': 99.99577633519004,
#   'Validation Accuracy': 99.90579947575361,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.001280333618639906,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 128,
#   'mixup': 0.1,
#   'model': '2D-ResNeXt-50',
#   'model size (MiB)': 98.53836345672607,
#   'name': 'umtq5iu6',
#   'num_params': 25731395,
#   'path': 'E:\\CAUEEG\\checkpoint\\umtq5iu6\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 39062,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9981262287024901,
#   'Accuracy (MCI)': 0.9972149410222805,
#   'Accuracy (Normal)': 0.9983105340760158,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9966715774540296,
#   'F1-score (MCI)': 0.9962465156073192,
#   'F1-score (Normal)': 0.9975692756441421,
#   'Multi-Crop Accuracy (Dementia)': 0.998935124508519,
#   'Multi-Crop Accuracy (MCI)': 0.9986893840104849,
#   'Multi-Crop Accuracy (Normal)': 0.9993446920052425,
#   'Multi-Crop F1-score (Dementia)': 0.9981082654249126,
#   'Multi-Crop F1-score (MCI)': 0.9982336056524619,
#   'Multi-Crop F1-score (Normal)': 0.999057270798963,
#   'Multi-Crop Precision (Dementia)': 0.9969476744186047,
#   'Multi-Crop Precision (MCI)': 0.9988952717631463,
#   'Multi-Crop Precision (Normal)': 0.9992927864214993,
#   'Multi-Crop Recall (Dementia)': 0.9992715617715617,
#   'Multi-Crop Recall (MCI)': 0.9975728155339806,
#   'Multi-Crop Recall (Normal)': 0.9988218661639963,
#   'Multi-Crop Sensitivity (Dementia)': 0.9992715617715617,
#   'Multi-Crop Sensitivity (MCI)': 0.9975728155339806,
#   'Multi-Crop Sensitivity (Normal)': 0.9988218661639963,
#   'Multi-Crop Specificity (Dementia)': 0.9988035551504102,
#   'Multi-Crop Specificity (MCI)': 0.9993486190724336,
#   'Multi-Crop Specificity (Normal)': 0.9996233048719236,
#   'Multi-Crop Test Accuracy': 99.84846002621232,
#   'Multi-Crop Test Throughput': 666.6918381542243,
#   'Precision (Dementia)': 0.9954223433242507,
#   'Precision (MCI)': 0.9968793151063242,
#   'Precision (Normal)': 0.9979073948539597,
#   'Recall (Dementia)': 0.997923951048951,
#   'Recall (MCI)': 0.9956145189761695,
#   'Recall (Normal)': 0.9972313854853911,
#   'Sensitivity (Dementia)': 0.997923951048951,
#   'Sensitivity (MCI)': 0.9956145189761695,
#   'Sensitivity (Normal)': 0.9972313854853911,
#   'Specificity (Dementia)': 0.9982053327256153,
#   'Specificity (MCI)': 0.9981598488796248,
#   'Specificity (Normal)': 0.9988856102461074,
#   'Test Accuracy': 99.68258519003932,
#   'Test Throughput': 5781.022441900499,
#   'Train Accuracy': 99.96157786885246,
#   'Validation Accuracy': 99.72968545216251,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.001623776739188721,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 320,
#   'mixup': 0.1,
#   'model': '1D-ResNet-101',
#   'model size (MiB)': 172.94957065582275,
#   'name': 'kxyux4lz',
#   'num_params': 45174531,
#   'path': 'E:\\CAUEEG\\checkpoint\\kxyux4lz\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 15625,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9799619102228048,
#   'Accuracy (MCI)': 0.9798595183486238,
#   'Accuracy (Normal)': 0.9836173001310616,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9645887994209716,
#   'F1-score (MCI)': 0.9726360892005063,
#   'F1-score (Normal)': 0.9765327075388678,
#   'Multi-Crop Accuracy (Dementia)': 0.9882044560943644,
#   'Multi-Crop Accuracy (MCI)': 0.989228374836173,
#   'Multi-Crop Accuracy (Normal)': 0.990293250327654,
#   'Multi-Crop F1-score (Dementia)': 0.9790819291109819,
#   'Multi-Crop F1-score (MCI)': 0.9854414613894271,
#   'Multi-Crop F1-score (Normal)': 0.9860580034119654,
#   'Multi-Crop Precision (Dementia)': 0.9762456546929317,
#   'Multi-Crop Precision (MCI)': 0.9888901233196311,
#   'Multi-Crop Precision (Normal)': 0.9847256491599107,
#   'Multi-Crop Recall (Dementia)': 0.9819347319347319,
#   'Multi-Crop Recall (MCI)': 0.9820167696381289,
#   'Multi-Crop Recall (Normal)': 0.9873939679547596,
#   'Multi-Crop Sensitivity (Dementia)': 0.9819347319347319,
#   'Multi-Crop Sensitivity (MCI)': 0.9820167696381289,
#   'Multi-Crop Sensitivity (Normal)': 0.9873939679547596,
#   'Multi-Crop Specificity (Dementia)': 0.9906563354603464,
#   'Multi-Crop Specificity (MCI)': 0.9934861907243356,
#   'Multi-Crop Specificity (Normal)': 0.9918382722250125,
#   'Multi-Crop Test Accuracy': 98.38630406290957,
#   'Multi-Crop Test Throughput': 53.02779194910297,
#   'Precision (Dementia)': 0.9584666834478046,
#   'Precision (MCI)': 0.9812221068290903,
#   'Precision (Normal)': 0.972595535818628,
#   'Recall (Dementia)': 0.970789627039627,
#   'Recall (MCI)': 0.9641990291262136,
#   'Recall (Normal)': 0.9805018850141376,
#   'Sensitivity (Dementia)': 0.970789627039627,
#   'Sensitivity (MCI)': 0.9641990291262136,
#   'Sensitivity (Normal)': 0.9805018850141376,
#   'Specificity (Dementia)': 0.9835488833181404,
#   'Specificity (MCI)': 0.9891056539864512,
#   'Specificity (Normal)': 0.9852774987443496,
#   'Test Accuracy': 97.17193643512451,
#   'Test Throughput': 432.32950339889885,
#   'Train Accuracy': 98.1202372173058,
#   'Validation Accuracy': 97.02653997378768,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 2.264845740927631e-05,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 48,
#   'mixup': 0.1,
#   'model': '2D-ViT-B-16',
#   'model size (MiB)': 329.16417503356934,
#   'name': '3td60j3k',
#   'num_params': 86272899,
#   'path': 'E:\\CAUEEG\\checkpoint\\3td60j3k\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 104167,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.6457855504587156,
#   'Accuracy (MCI)': 0.5608207732634338,
#   'Accuracy (Normal)': 0.674946756225426,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.348904614921328,
#   'F1-score (MCI)': 0.4087939352170917,
#   'F1-score (Normal)': 0.5441805703127243,
#   'Multi-Crop Accuracy (Dementia)': 0.6470142529488859,
#   'Multi-Crop Accuracy (MCI)': 0.562254259501966,
#   'Multi-Crop Accuracy (Normal)': 0.6769945937090432,
#   'Multi-Crop F1-score (Dementia)': 0.34863772059101383,
#   'Multi-Crop F1-score (MCI)': 0.4137940490881667,
#   'Multi-Crop F1-score (Normal)': 0.5459177798249655,
#   'Multi-Crop Precision (Dementia)': 0.3622300745975658,
#   'Multi-Crop Precision (MCI)': 0.41143589463925395,
#   'Multi-Crop Precision (Normal)': 0.5338682432432432,
#   'Multi-Crop Recall (Dementia)': 0.33602855477855476,
#   'Multi-Crop Recall (MCI)': 0.4161793909973522,
#   'Multi-Crop Recall (Normal)': 0.5585237983034873,
#   'Multi-Crop Sensitivity (Dementia)': 0.33602855477855476,
#   'Multi-Crop Sensitivity (MCI)': 0.4161793909973522,
#   'Multi-Crop Sensitivity (Normal)': 0.5585237983034873,
#   'Multi-Crop Specificity (Dementia)': 0.768630355515041,
#   'Multi-Crop Specificity (MCI)': 0.6484985669619594,
#   'Multi-Crop Specificity (Normal)': 0.7401274485183325,
#   'Multi-Crop Test Accuracy': 44.313155307994755,
#   'Multi-Crop Test Throughput': 4736.832634141411,
#   'Precision (Dementia)': 0.3609985979124474,
#   'Precision (MCI)': 0.4085799305670359,
#   'Precision (Normal)': 0.5309015520815823,
#   'Recall (Dementia)': 0.33759469696969696,
#   'Recall (MCI)': 0.40900816416593117,
#   'Recall (Normal)': 0.558140904806786,
#   'Sensitivity (Dementia)': 0.33759469696969696,
#   'Sensitivity (MCI)': 0.40900816416593117,
#   'Sensitivity (Normal)': 0.558140904806786,
#   'Specificity (Dementia)': 0.7663086827711941,
#   'Specificity (MCI)': 0.6504527097446586,
#   'Specificity (Normal)': 0.7371923656454044,
#   'Test Accuracy': 44.07765399737877,
#   'Test Throughput': 18782.934654250308,
#   'Train Accuracy': 58.56972552360372,
#   'Validation Accuracy': 45.24696920052425,
#   'awgn': 0,
#   'awgn_age': 0,
#   'base_lr': 0.0013179819311313625,
#   'crop_multiple': 1,
#   'dropout': 0,
#   'fc_stages': 1,
#   'lr_scheduler_type': 'constant_with_decay',
#   'mgn': 0,
#   'minibatch': 512,
#   'mixup': 0.0,
#   'model': '1D-Linear-SVM',
#   'model size (MiB)': 0.24115467071533203,
#   'name': '22pj8bg1',
#   'num_params': 63006,
#   'path': 'E:\\CAUEEG\\checkpoint\\22pj8bg1\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 32,
#   'seed': 0,
#   'seq_length': 1000,
#   'test_crop_multiple': 1,
#   'total_samples': 100000000,
#   'use_age': 'fc',
#   'warmup_steps': 9766,
#   'weight_decay': 0.01},
#  {'Accuracy (Dementia)': 0.9963343709043251,
#   'Accuracy (MCI)': 0.9954026048492791,
#   'Accuracy (Normal)': 0.9954640399737876,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9934984745023971,
#   'F1-score (MCI)': 0.9937865851127132,
#   'F1-score (Normal)': 0.9934853899207364,
#   'Multi-Crop Accuracy (Dementia)': 0.9973787680209698,
#   'Multi-Crop Accuracy (MCI)': 0.9966005897771952,
#   'Multi-Crop Accuracy (Normal)': 0.9961091087811271,
#   'Multi-Crop F1-score (Dementia)': 0.9953454545454546,
#   'Multi-Crop F1-score (MCI)': 0.995409545932194,
#   'Multi-Crop F1-score (Normal)': 0.9944120934062702,
#   'Multi-Crop Precision (Dementia)': 0.9937554458321232,
#   'Multi-Crop Precision (MCI)': 0.9980037706554287,
#   'Multi-Crop Precision (Normal)': 0.9929519558322566,
#   'Multi-Crop Recall (Dementia)': 0.9969405594405595,
#   'Multi-Crop Recall (MCI)': 0.992828773168579,
#   'Multi-Crop Recall (Normal)': 0.9958765315739868,
#   'Multi-Crop Sensitivity (Dementia)': 0.9969405594405595,
#   'Multi-Crop Sensitivity (MCI)': 0.992828773168579,
#   'Multi-Crop Sensitivity (Normal)': 0.9958765315739868,
#   'Multi-Crop Specificity (Dementia)': 0.9975501367365542,
#   'Multi-Crop Specificity (MCI)': 0.9988275143303804,
#   'Multi-Crop Specificity (Normal)': 0.9962330487192366,
#   'Multi-Crop Test Accuracy': 99.5044233289646,
#   'Multi-Crop Test Throughput': 1203.5002221410837,
#   'Precision (Dementia)': 0.9907635467980296,
#   'Precision (MCI)': 0.9972227622406754,
#   'Precision (Normal)': 0.9920702516960851,
#   'Recall (Dementia)': 0.9962485431235432,
#   'Recall (MCI)': 0.9903740070609003,
#   'Recall (Normal)': 0.9949045711592837,
#   'Sensitivity (Dementia)': 0.9962485431235432,
#   'Sensitivity (MCI)': 0.9903740070609003,
#   'Sensitivity (Normal)': 0.9949045711592837,
#   'Specificity (Dementia)': 0.996367935278031,
#   'Specificity (MCI)': 0.9983715476810839,
#   'Specificity (Normal)': 0.9957621798091412,
#   'Test Accuracy': 99.3600507863696,
#   'Test Throughput': 9099.191285156925,
#   'Train Accuracy': 99.97476946721312,
#   'Validation Accuracy': 99.51261467889908,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.00041788100602942185,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 320,
#   'mixup': 0.1,
#   'model': '1D-ResNet-50',
#   'model size (MiB)': 100.20090103149414,
#   'name': 'ocf38th1',
#   'num_params': 26182403,
#   'path': 'E:\\CAUEEG\\checkpoint\\ocf38th1\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 15625,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9973173328964613,
#   'Accuracy (MCI)': 0.994440121231979,
#   'Accuracy (Normal)': 0.9956278669724771,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9952154857560263,
#   'F1-score (MCI)': 0.9925269401742338,
#   'F1-score (Normal)': 0.9937119884547985,
#   'Multi-Crop Accuracy (Dementia)': 0.9978292922673656,
#   'Multi-Crop Accuracy (MCI)': 0.995740498034076,
#   'Multi-Crop Accuracy (Normal)': 0.99668250327654,
#   'Multi-Crop F1-score (Dementia)': 0.9961282781795602,
#   'Multi-Crop F1-score (MCI)': 0.994271234989534,
#   'Multi-Crop F1-score (Normal)': 0.9952322090764613,
#   'Multi-Crop Precision (Dementia)': 0.9989743589743589,
#   'Multi-Crop Precision (MCI)': 0.9928492849284929,
#   'Multi-Crop Precision (Normal)': 0.9944712386778026,
#   'Multi-Crop Recall (Dementia)': 0.9932983682983683,
#   'Multi-Crop Recall (MCI)': 0.9956972639011474,
#   'Multi-Crop Recall (Normal)': 0.9959943449575872,
#   'Multi-Crop Sensitivity (Dementia)': 0.9932983682983683,
#   'Multi-Crop Sensitivity (MCI)': 0.9956972639011474,
#   'Multi-Crop Sensitivity (Normal)': 0.9959943449575872,
#   'Multi-Crop Specificity (Dementia)': 0.9996011850501367,
#   'Multi-Crop Specificity (MCI)': 0.9957660239708181,
#   'Multi-Crop Specificity (Normal)': 0.9970492214967354,
#   'Multi-Crop Test Accuracy': 99.51261467889908,
#   'Multi-Crop Test Throughput': 441.33488417027183,
#   'Precision (Dementia)': 0.9979856431292118,
#   'Precision (MCI)': 0.9904958110149704,
#   'Precision (Normal)': 0.9936680901192755,
#   'Recall (Dementia)': 0.9924606643356644,
#   'Recall (MCI)': 0.9945664165931156,
#   'Recall (Normal)': 0.99375589066918,
#   'Sensitivity (Dementia)': 0.9924606643356644,
#   'Sensitivity (MCI)': 0.9945664165931156,
#   'Sensitivity (Normal)': 0.99375589066918,
#   'Specificity (Dementia)': 0.99921661349134,
#   'Specificity (MCI)': 0.9943655549765503,
#   'Specificity (Normal)': 0.9966254394776495,
#   'Test Accuracy': 99.36926605504587,
#   'Test Throughput': 3746.6168242952444,
#   'Train Accuracy': 99.78379777723097,
#   'Validation Accuracy': 99.49213630406291,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.00016959216190796865,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 256,
#   'mixup': 0.1,
#   'model': '2D-VGG-19',
#   'model size (MiB)': 77.2055253982544,
#   'name': 'pz76l4fq',
#   'num_params': 20217923,
#   'path': 'E:\\CAUEEG\\checkpoint\\pz76l4fq\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 19531,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9971739842726082,
#   'Accuracy (MCI)': 0.9945425131061599,
#   'Accuracy (Normal)': 0.9959145642201835,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9949717617052286,
#   'F1-score (MCI)': 0.9926370028595506,
#   'F1-score (Normal)': 0.9941365780540493,
#   'Multi-Crop Accuracy (Dementia)': 0.997747378768021,
#   'Multi-Crop Accuracy (MCI)': 0.9959862385321101,
#   'Multi-Crop Accuracy (Normal)': 0.9975835517693316,
#   'Multi-Crop F1-score (Dementia)': 0.995995631598107,
#   'Multi-Crop F1-score (MCI)': 0.9945838399469438,
#   'Multi-Crop F1-score (Normal)': 0.9965300241133919,
#   'Multi-Crop Precision (Dementia)': 0.995488284092563,
#   'Multi-Crop Precision (MCI)': 0.9964562569213732,
#   'Multi-Crop Precision (Normal)': 0.9949500880798591,
#   'Multi-Crop Recall (Dementia)': 0.9965034965034965,
#   'Multi-Crop Recall (MCI)': 0.9927184466019418,
#   'Multi-Crop Recall (Normal)': 0.998114985862394,
#   'Multi-Crop Sensitivity (Dementia)': 0.9965034965034965,
#   'Multi-Crop Sensitivity (MCI)': 0.9927184466019418,
#   'Multi-Crop Sensitivity (Normal)': 0.998114985862394,
#   'Multi-Crop Specificity (Dementia)': 0.9982338195077484,
#   'Multi-Crop Specificity (MCI)': 0.9979155810317873,
#   'Multi-Crop Specificity (Normal)': 0.9973003515821195,
#   'Multi-Crop Test Accuracy': 99.56585845347313,
#   'Multi-Crop Test Throughput': 1480.7092665757812,
#   'Precision (Dementia)': 0.9953707078807319,
#   'Precision (MCI)': 0.9943265159272687,
#   'Precision (Normal)': 0.9920227586004634,
#   'Recall (Dementia)': 0.9945731351981352,
#   'Recall (MCI)': 0.9909532215357458,
#   'Recall (Normal)': 0.996259425070688,
#   'Sensitivity (Dementia)': 0.9945731351981352,
#   'Sensitivity (MCI)': 0.9909532215357458,
#   'Sensitivity (Normal)': 0.996259425070688,
#   'Specificity (Dementia)': 0.9981910893345488,
#   'Specificity (MCI)': 0.996661672746222,
#   'Specificity (Normal)': 0.9957307885484681,
#   'Test Accuracy': 99.38155307994757,
#   'Test Throughput': 11103.690434489232,
#   'Train Accuracy': 100.0,
#   'Validation Accuracy': 99.52694954128441,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.0006686096096470754,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 512,
#   'mixup': 0.1,
#   'model': '1D-ResNet-18',
#   'model size (MiB)': 43.55092239379883,
#   'name': 'nd1ss8ci',
#   'num_params': 11394051,
#   'path': 'E:\\CAUEEG\\checkpoint\\nd1ss8ci\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 9766,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.997399246395806,
#   'Accuracy (MCI)': 0.9954026048492791,
#   'Accuracy (Normal)': 0.9965084370904325,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9953757646373435,
#   'F1-score (MCI)': 0.9937980855560312,
#   'F1-score (Normal)': 0.9949855153449113,
#   'Multi-Crop Accuracy (Dementia)': 0.9978292922673656,
#   'Multi-Crop Accuracy (MCI)': 0.9964777195281782,
#   'Multi-Crop Accuracy (Normal)': 0.9972558977719528,
#   'Multi-Crop F1-score (Dementia)': 0.9961418067991555,
#   'Multi-Crop F1-score (MCI)': 0.9952454666076956,
#   'Multi-Crop F1-score (Normal)': 0.9960604456988299,
#   'Multi-Crop Precision (Dementia)': 0.995489596973665,
#   'Multi-Crop Precision (MCI)': 0.9974512411347518,
#   'Multi-Crop Precision (Normal)': 0.9942481511914544,
#   'Multi-Crop Recall (Dementia)': 0.9967948717948718,
#   'Multi-Crop Recall (MCI)': 0.9930494263018534,
#   'Multi-Crop Recall (Normal)': 0.9978793590951932,
#   'Multi-Crop Sensitivity (Dementia)': 0.9967948717948718,
#   'Multi-Crop Sensitivity (MCI)': 0.9930494263018534,
#   'Multi-Crop Sensitivity (Normal)': 0.9978793590951932,
#   'Multi-Crop Specificity (Dementia)': 0.9982338195077484,
#   'Multi-Crop Specificity (MCI)': 0.9985018238665971,
#   'Multi-Crop Specificity (Normal)': 0.9969236564540432,
#   'Multi-Crop Test Accuracy': 99.57814547837484,
#   'Multi-Crop Test Throughput': 1466.7352417920433,
#   'Precision (Dementia)': 0.9950859056493885,
#   'Precision (MCI)': 0.9953792092083783,
#   'Precision (Normal)': 0.9935391031100408,
#   'Recall (Dementia)': 0.9956657925407926,
#   'Recall (MCI)': 0.9922219770520742,
#   'Recall (Normal)': 0.9964361451460886,
#   'Sensitivity (Dementia)': 0.9956657925407926,
#   'Sensitivity (MCI)': 0.9922219770520742,
#   'Sensitivity (Normal)': 0.9964361451460886,
#   'Specificity (Dementia)': 0.9980771422060164,
#   'Specificity (MCI)': 0.9972804846274101,
#   'Specificity (Normal)': 0.9965469613259669,
#   'Test Accuracy': 99.46551441677587,
#   'Test Throughput': 9312.937830908248,
#   'Train Accuracy': 100.0,
#   'Validation Accuracy': 99.51363859764089,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.00012255485175602948,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 512,
#   'mixup': 0.1,
#   'model': '1D-VGG-19',
#   'model size (MiB)': 77.15930843353271,
#   'name': 'nkrh4pji',
#   'num_params': 20205827,
#   'path': 'E:\\CAUEEG\\checkpoint\\nkrh4pji\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 9766,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.99834125163827,
#   'Accuracy (MCI)': 0.9976859436435125,
#   'Accuracy (Normal)': 0.9989760812581914,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9970530451866404,
#   'F1-score (MCI)': 0.9968777630415562,
#   'F1-score (Normal)': 0.9985288059789325,
#   'Multi-Crop Accuracy (Dementia)': 0.9990989515072084,
#   'Multi-Crop Accuracy (MCI)': 0.9986484272608126,
#   'Multi-Crop Accuracy (Normal)': 0.9995494757536042,
#   'Multi-Crop F1-score (Dementia)': 0.9984,
#   'Multi-Crop F1-score (MCI)': 0.998176291793313,
#   'Multi-Crop F1-score (Normal)': 0.9993524459881086,
#   'Multi-Crop Precision (Dementia)': 0.9968051118210862,
#   'Multi-Crop Precision (MCI)': 1.0,
#   'Multi-Crop Precision (Normal)': 0.9987057300858925,
#   'Multi-Crop Recall (Dementia)': 1.0,
#   'Multi-Crop Recall (MCI)': 0.9963592233009708,
#   'Multi-Crop Recall (Normal)': 1.0,
#   'Multi-Crop Sensitivity (Dementia)': 1.0,
#   'Multi-Crop Sensitivity (MCI)': 0.9963592233009708,
#   'Multi-Crop Sensitivity (Normal)': 1.0,
#   'Multi-Crop Specificity (Dementia)': 0.998746581586144,
#   'Multi-Crop Specificity (MCI)': 1.0,
#   'Multi-Crop Specificity (Normal)': 0.9993093922651933,
#   'Multi-Crop Test Accuracy': 99.86484272608126,
#   'Multi-Crop Test Throughput': 1012.8853263136469,
#   'Precision (Dementia)': 0.9959659834278238,
#   'Precision (MCI)': 0.9986437112488928,
#   'Precision (Normal)': 0.9975308641975309,
#   'Recall (Dementia)': 0.9981424825174825,
#   'Recall (MCI)': 0.9951180494263019,
#   'Recall (Normal)': 0.9995287464655985,
#   'Sensitivity (Dementia)': 0.9981424825174825,
#   'Sensitivity (MCI)': 0.9951180494263019,
#   'Sensitivity (Normal)': 0.9995287464655985,
#   'Specificity (Dementia)': 0.9984189835916135,
#   'Specificity (MCI)': 0.9992020583637311,
#   'Specificity (Normal)': 0.9986815670517328,
#   'Test Accuracy': 99.7501638269987,
#   'Test Throughput': 7775.78542104873,
#   'Train Accuracy': 99.9976870888158,
#   'Validation Accuracy': 99.80545543905636,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.00047621623066101086,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 512,
#   'mixup': 0.1,
#   'model': '1D-ResNeXt-50',
#   'model size (MiB)': 98.24389362335205,
#   'name': 'f9g4k64e',
#   'num_params': 25654275,
#   'path': 'E:\\CAUEEG\\checkpoint\\f9g4k64e\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 9766,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9986484272608126,
#   'Accuracy (MCI)': 0.9984026867627785,
#   'Accuracy (Normal)': 0.9995085190039319,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9975971165398477,
#   'F1-score (MCI)': 0.9978474445303015,
#   'F1-score (Normal)': 0.9992933070286505,
#   'Multi-Crop Accuracy (Dementia)': 0.9992218217562254,
#   'Multi-Crop Accuracy (MCI)': 0.9992218217562254,
#   'Multi-Crop Accuracy (Normal)': 1.0,
#   'Multi-Crop F1-score (Dementia)': 0.9986168741355463,
#   'Multi-Crop F1-score (MCI)': 0.9989513770075611,
#   'Multi-Crop F1-score (Normal)': 1.0,
#   'Multi-Crop Precision (Dementia)': 0.9979630437945585,
#   'Multi-Crop Precision (MCI)': 0.9994478188845941,
#   'Multi-Crop Precision (Normal)': 1.0,
#   'Multi-Crop Recall (Dementia)': 0.9992715617715617,
#   'Multi-Crop Recall (MCI)': 0.9984554280670785,
#   'Multi-Crop Recall (Normal)': 1.0,
#   'Multi-Crop Sensitivity (Dementia)': 0.9992715617715617,
#   'Multi-Crop Sensitivity (MCI)': 0.9984554280670785,
#   'Multi-Crop Sensitivity (Normal)': 1.0,
#   'Multi-Crop Specificity (Dementia)': 0.9992023701002735,
#   'Multi-Crop Specificity (MCI)': 0.9996743095362168,
#   'Multi-Crop Specificity (Normal)': 1.0,
#   'Multi-Crop Test Accuracy': 99.92218217562254,
#   'Multi-Crop Test Throughput': 155.59614655417116,
#   'Precision (Dementia)': 0.9971977582065652,
#   'Precision (MCI)': 0.99839849790148,
#   'Precision (Normal)': 0.9990285546070062,
#   'Recall (Dementia)': 0.9979967948717948,
#   'Recall (MCI)': 0.9972969991173875,
#   'Recall (Normal)': 0.9995581998114986,
#   'Sensitivity (Dementia)': 0.9979967948717948,
#   'Sensitivity (MCI)': 0.9972969991173875,
#   'Sensitivity (Normal)': 0.9995581998114986,
#   'Specificity (Dementia)': 0.998903258887876,
#   'Specificity (MCI)': 0.9990554976550287,
#   'Specificity (Normal)': 0.9994820441988951,
#   'Test Accuracy': 99.82798165137615,
#   'Test Throughput': 1268.7696632628465,
#   'Train Accuracy': 99.99808015235911,
#   'Validation Accuracy': 99.88532110091744,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 0.0017975938362886667,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 128,
#   'mixup': 0.1,
#   'model': '2D-ResNet-50',
#   'model size (MiB)': 100.49537086486816,
#   'name': '03iz3rso',
#   'num_params': 26259523,
#   'path': 'E:\\CAUEEG\\checkpoint\\03iz3rso\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 39062,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9651150884665793,
#   'Accuracy (MCI)': 0.9675520150720839,
#   'Accuracy (Normal)': 0.9679308650065531,
#   'EKG': 'O',
#   'F1-score (Dementia)': 0.9395353789908958,
#   'F1-score (MCI)': 0.9559144721283196,
#   'F1-score (Normal)': 0.9533220066171868,
#   'Multi-Crop Accuracy (Dementia)': 0.9788253604193972,
#   'Multi-Crop Accuracy (MCI)': 0.9819380733944955,
#   'Multi-Crop Accuracy (Normal)': 0.9824705111402359,
#   'Multi-Crop F1-score (Dementia)': 0.9631792607364148,
#   'Multi-Crop F1-score (MCI)': 0.9754959159859976,
#   'Multi-Crop F1-score (Normal)': 0.9745147076336786,
#   'Multi-Crop Precision (Dementia)': 0.9421763968231852,
#   'Multi-Crop Precision (MCI)': 0.9826486062912795,
#   'Multi-Crop Precision (Normal)': 0.9851914278834577,
#   'Multi-Crop Recall (Dementia)': 0.9851398601398601,
#   'Multi-Crop Recall (MCI)': 0.9684466019417476,
#   'Multi-Crop Recall (Normal)': 0.964066918001885,
#   'Multi-Crop Sensitivity (Dementia)': 0.9851398601398601,
#   'Multi-Crop Sensitivity (MCI)': 0.9684466019417476,
#   'Multi-Crop Sensitivity (Normal)': 0.964066918001885,
#   'Multi-Crop Specificity (Dementia)': 0.9763559708295351,
#   'Multi-Crop Specificity (MCI)': 0.9899035956227201,
#   'Multi-Crop Specificity (Normal)': 0.992277749874435,
#   'Multi-Crop Test Accuracy': 97.16169724770643,
#   'Multi-Crop Test Throughput': 52.13075343778369,
#   'Precision (Dementia)': 0.9162022775258731,
#   'Precision (MCI)': 0.9643528784348949,
#   'Precision (Normal)': 0.9649128099921559,
#   'Recall (Dementia)': 0.9640879953379954,
#   'Recall (MCI)': 0.9476224624889673,
#   'Recall (Normal)': 0.9420063619227145,
#   'Sensitivity (Dementia)': 0.9640879953379954,
#   'Sensitivity (MCI)': 0.9476224624889673,
#   'Sensitivity (Normal)': 0.9420063619227145,
#   'Specificity (Dementia)': 0.9655167502278943,
#   'Specificity (MCI)': 0.9793186555497655,
#   'Specificity (Normal)': 0.9817459819186338,
#   'Test Accuracy': 95.02989842726082,
#   'Test Throughput': 435.26405671775103,
#   'Train Accuracy': 95.98620329400197,
#   'Validation Accuracy': 94.76675131061599,
#   'awgn': 0.05,
#   'awgn_age': 0.05,
#   'base_lr': 3.179853035774412e-05,
#   'crop_multiple': 4,
#   'dropout': 0.3,
#   'fc_stages': 3,
#   'lr_scheduler_type': 'linear_decay_with_warmup',
#   'mgn': 0.05,
#   'minibatch': 48,
#   'mixup': 0.1,
#   'model': '2D-ViT-B-16',
#   'model size (MiB)': 329.16417503356934,
#   'name': '1663fxhy',
#   'num_params': 86272899,
#   'path': 'E:\\CAUEEG\\checkpoint\\1663fxhy\\checkpoint.pt',
#   'photic': 'O',
#   'repeat': 8,
#   'seed': 1,
#   'seq_length': 2000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'conv',
#   'warmup_steps': 104167,
#   'weight_decay': 0.05},
#  {'Accuracy (Dementia)': 0.9414318479685452,
#   'Accuracy (MCI)': 0.8921915956749672,
#   'Accuracy (Normal)': 0.9161308158584535,
#   'EKG': 'X',
#   'F1-score (Dementia)': 0.8923881551717651,
#   'F1-score (MCI)': 0.8601039023158791,
#   'F1-score (Normal)': 0.8775836559011224,
#   'Multi-Crop Accuracy (Dementia)': 0.9812827653997379,
#   'Multi-Crop Accuracy (MCI)': 0.9638761467889908,
#   'Multi-Crop Accuracy (Normal)': 0.9729275884665793,
#   'Multi-Crop F1-score (Dementia)': 0.9661054661425498,
#   'Multi-Crop F1-score (MCI)': 0.9523963730569948,
#   'Multi-Crop F1-score (Normal)': 0.9607038820521966,
#   'Multi-Crop Precision (Dementia)': 0.9839854962985345,
#   'Multi-Crop Precision (MCI)': 0.9322696534234995,
#   'Multi-Crop Precision (Normal)': 0.969638785551422,
#   'Multi-Crop Recall (Dementia)': 0.9488636363636364,
#   'Multi-Crop Recall (MCI)': 0.9734112974404237,
#   'Multi-Crop Recall (Normal)': 0.9519321394910462,
#   'Multi-Crop Sensitivity (Dementia)': 0.9488636363636364,
#   'Multi-Crop Sensitivity (MCI)': 0.9734112974404237,
#   'Multi-Crop Sensitivity (Normal)': 0.9519321394910462,
#   'Multi-Crop Specificity (Dementia)': 0.9939608021877848,
#   'Multi-Crop Specificity (MCI)': 0.9582464825429912,
#   'Multi-Crop Specificity (Normal)': 0.9841160220994475,
#   'Multi-Crop Test Accuracy': 95.9043250327654,
#   'Multi-Crop Test Throughput': 1828.9260080216718,
#   'Precision (Dementia)': 0.9229122888940774,
#   'Precision (MCI)': 0.8297741431025201,
#   'Precision (Normal)': 0.8908037258411966,
#   'Recall (Dementia)': 0.8638184731934732,
#   'Recall (MCI)': 0.8927349955869374,
#   'Recall (Normal)': 0.8647502356267672,
#   'Sensitivity (Dementia)': 0.8638184731934732,
#   'Sensitivity (MCI)': 0.8927349955869374,
#   'Sensitivity (Normal)': 0.8647502356267672,
#   'Specificity (Dementia)': 0.9717838422971741,
#   'Specificity (MCI)': 0.8918707660239709,
#   'Specificity (Normal)': 0.943511426418885,
#   'Test Accuracy': 87.4877129750983,
#   'Test Throughput': 8789.864371089092,
#   'Train Accuracy': 99.71859580592105,
#   'Validation Accuracy': 87.34231651376147,
#   'awgn': 0,
#   'awgn_age': 0,
#   'base_lr': 0.0006686096096470754,
#   'crop_multiple': 4,
#   'dropout': 0,
#   'fc_stages': 1,
#   'lr_scheduler_type': 'constant_with_decay',
#   'mgn': 0,
#   'minibatch': 512,
#   'mixup': 0.0,
#   'model': 'Ieracitano-CNN',
#   'model size (MiB)': 13.198659896850586,
#   'name': '34oksw2q',
#   'num_params': 3457995,
#   'path': 'E:\\CAUEEG\\checkpoint\\34oksw2q\\checkpoint.pt',
#   'photic': 'X',
#   'repeat': 8,
#   'seed': 0,
#   'seq_length': 1000,
#   'test_crop_multiple': 8,
#   'total_samples': 100000000,
#   'use_age': 'no',
#   'warmup_steps': 9766,
#   'weight_decay': 0.01}]

# %%
pd.DataFrame(model_pool)
# Out:
#         name                                         path           model  \
# 0   3smz5tul  E:\CAUEEG\checkpoint\3smz5tul\checkpoint.pt  Ieracitano-CNN
# 1   9d9rnxrx  E:\CAUEEG\checkpoint\9d9rnxrx\checkpoint.pt    2D-ResNet-18
# 2   umtq5iu6  E:\CAUEEG\checkpoint\umtq5iu6\checkpoint.pt   2D-ResNeXt-50
# 3   kxyux4lz  E:\CAUEEG\checkpoint\kxyux4lz\checkpoint.pt   1D-ResNet-101
# 4   3td60j3k  E:\CAUEEG\checkpoint\3td60j3k\checkpoint.pt     2D-ViT-B-16
# 5   22pj8bg1  E:\CAUEEG\checkpoint\22pj8bg1\checkpoint.pt   1D-Linear-SVM
# 6   ocf38th1  E:\CAUEEG\checkpoint\ocf38th1\checkpoint.pt    1D-ResNet-50
# 7   pz76l4fq  E:\CAUEEG\checkpoint\pz76l4fq\checkpoint.pt       2D-VGG-19
# 8   nd1ss8ci  E:\CAUEEG\checkpoint\nd1ss8ci\checkpoint.pt    1D-ResNet-18
# 9   nkrh4pji  E:\CAUEEG\checkpoint\nkrh4pji\checkpoint.pt       1D-VGG-19
# 10  f9g4k64e  E:\CAUEEG\checkpoint\f9g4k64e\checkpoint.pt   1D-ResNeXt-50
# 11  03iz3rso  E:\CAUEEG\checkpoint\03iz3rso\checkpoint.pt    2D-ResNet-50
# 12  1663fxhy  E:\CAUEEG\checkpoint\1663fxhy\checkpoint.pt     2D-ViT-B-16
# 13  34oksw2q  E:\CAUEEG\checkpoint\34oksw2q\checkpoint.pt  Ieracitano-CNN
#
#     num_params  model size (MiB)  seq_length use_age photic EKG  awgn  ...  \
# 0      3457995         13.198660        1000      no      X   X  0.00  ...
# 1     11466947         43.826613        2000    conv      O   O  0.05  ...
# 2     25731395         98.538363        2000    conv      O   O  0.05  ...
# 3     45174531        172.949571        2000    conv      O   O  0.05  ...
# 4     86272899        329.164175        2000    conv      O   O  0.05  ...
# 5        63006          0.241155        1000      fc      O   O  0.00  ...
# 6     26182403        100.200901        2000    conv      O   O  0.05  ...
# 7     20217923         77.205525        2000    conv      O   O  0.05  ...
# 8     11394051         43.550922        2000    conv      O   O  0.05  ...
# 9     20205827         77.159308        2000    conv      O   O  0.05  ...
# 10    25654275         98.243894        2000    conv      O   O  0.05  ...
# 11    26259523        100.495371        2000    conv      O   O  0.05  ...
# 12    86272899        329.164175        2000    conv      O   O  0.05  ...
# 13     3457995         13.198660        1000      no      X   X  0.00  ...
#
#     Multi-Crop Specificity (Dementia)  Multi-Crop Precision (Normal)  \
# 0                            0.919240                       0.726296
# 1                            1.000000                       1.000000
# 2                            0.999487                       0.999294
# 3                            0.998804                       0.999293
# 4                            0.990656                       0.984726
# 5                            0.768630                       0.533868
# 6                            0.997550                       0.992952
# 7                            0.999601                       0.994471
# 8                            0.998234                       0.994950
# 9                            0.998234                       0.994248
# 10                           0.998747                       0.998706
# 11                           0.999202                       1.000000
# 12                           0.976356                       0.985191
# 13                           0.993961                       0.969639
#
#     Multi-Crop Precision (MCI)  Multi-Crop Precision (Dementia)  \
# 0                     0.697871                         0.777088
# 1                     0.999669                         1.000000
# 2                     1.000000                         0.998691
# 3                     0.998895                         0.996948
# 4                     0.988890                         0.976246
# 5                     0.411436                         0.362230
# 6                     0.998004                         0.993755
# 7                     0.992849                         0.998974
# 8                     0.996456                         0.995488
# 9                     0.997451                         0.995490
# 10                    1.000000                         0.996805
# 11                    0.999448                         0.997963
# 12                    0.982649                         0.942176
# 13                    0.932270                         0.983985
#
#     Multi-Crop Recall (Normal)  Multi-Crop Recall (MCI)  \
# 0                     0.774535                 0.693347
# 1                     0.999764                 1.000000
# 2                     1.000000                 0.998345
# 3                     0.998822                 0.997573
# 4                     0.987394                 0.982017
# 5                     0.558524                 0.416179
# 6                     0.995877                 0.992829
# 7                     0.995994                 0.995697
# 8                     0.998115                 0.992718
# 9                     0.997879                 0.993049
# 10                    1.000000                 0.996359
# 11                    1.000000                 0.998455
# 12                    0.964067                 0.968447
# 13                    0.951932                 0.973411
#
#     Multi-Crop Recall (Dementia)  Multi-Crop F1-score (Normal)  \
# 0                       0.719916                      0.749640
# 1                       0.999854                      0.999882
# 2                       1.000000                      0.999647
# 3                       0.999272                      0.999057
# 4                       0.981935                      0.986058
# 5                       0.336029                      0.545918
# 6                       0.996941                      0.994412
# 7                       0.993298                      0.995232
# 8                       0.996503                      0.996530
# 9                       0.996795                      0.996060
# 10                      1.000000                      0.999352
# 11                      0.999272                      1.000000
# 12                      0.985140                      0.974515
# 13                      0.948864                      0.960704
#
#     Multi-Crop F1-score (MCI) Multi-Crop F1-score (Dementia)
# 0                    0.695602                       0.747410
# 1                    0.999835                       0.999927
# 2                    0.999172                       0.999345
# 3                    0.998234                       0.998108
# 4                    0.985441                       0.979082
# 5                    0.413794                       0.348638
# 6                    0.995410                       0.995345
# 7                    0.994271                       0.996128
# 8                    0.994584                       0.995996
# 9                    0.995245                       0.996142
# 10                   0.998176                       0.998400
# 11                   0.998951                       0.998617
# 12                   0.975496                       0.963179
# 13                   0.952396                       0.966105
#
# [14 rows x 67 columns]

# %%
pd.DataFrame(model_pool).to_csv('local/output/caueeg-task2-segmented.csv')
