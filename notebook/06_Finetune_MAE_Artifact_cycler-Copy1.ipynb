# %% [markdown]
# # Finetune Masked-AutoEncoder
#
# - Finetune the deep network after pretraining the self-supervised learning framework.

# %% [markdown]
# -----
#
# ## Load Packages

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/imkbsz/workspace/eeg_analysis

# %%
# Load some packages
import os
import gc
from copy import deepcopy
import hydra
from omegaconf import OmegaConf
import wandb
import pprint
import numpy as np
import torch
from tqdm.auto import tqdm
from collections import OrderedDict
from cycler import cycler

import matplotlib
import matplotlib.pyplot as plt
import scienceplots

# custom package
from run_train import check_device_env
from run_train import set_seed
from run_train import compose_dataset
from run_train import generate_model
from train.ssl_train_script import ssl_train_script
from train.train_script import train_script
from models.utils import count_parameters

# %% [markdown]
# ---
#
# ## Specify the dataset, model, and train setting

# %%
pre_model_path = 'local/checkpoint/'
pre_model_name = 'r3db85gm'  # '5xlos421'
device = 'cuda:1'

############
# Artifact #
############
art_config = dict()
art_config['project'] = 'caueeg-mae-artifact'
art_config['use_wandb'] = False
art_config['pre_model'] = pre_model_name
art_config['device'] = device

# art_config["art_filter_list"] = [9, 9, 9, 9, 9]
art_config["art_dropout"] = 0.1
art_config["art_use_age"] = "no"  # "conv", "embedding", "no"

art_config['total_samples'] = 5.0e+6
art_config['search_lr'] = False
art_config['base_lr'] = 1e-4
art_config['lr_scheduler_type'] = 'cosine_decay_with_warmup_half'

art_config["warmup_min"] = 150
art_config["num_history"] = 50
art_config['save_model'] = False

##################
# Classification #
##################
finetune_config = dict()
finetune_config['project'] = 'caueeg-mae-artifact-finetune'
finetune_config['use_wandb'] = True
finetune_config['pre_model'] = pre_model_name
finetune_config['device'] = device
finetune_config["task"] = "dementia"
finetune_config["out_dims"] = 3

# finetune_config["mask_ratio"] = 0.25
finetune_config["descending"] = False  #######################################################
finetune_config["global_pool"] = True
finetune_config["fc_stages"] = 2
finetune_config["dropout"] = 0.1
finetune_config["use_age"] = "conv"  ##################################################
# finetune_config["mixup"] = 0.3 ###
# finetune_config["crop_length"] = 8192*4  #############################################################
# finetune_config["criterion"] = "multi-bce"  # "cross-entropy", "multi-bce"

finetune_config["tuning_type"] = "finetune"  # "finetune", "fc_stage"
finetune_config["layer_wise_lr"] = True

finetune_config['total_samples'] = 3.0e+6  ############################################################
# finetune_config['base_lr'] = 1e-3
finetune_config['search_lr'] = True
finetune_config['lr_search_steps'] = 100
finetune_config['lr_scheduler_type'] = 'cosine_decay_with_warmup_half'
finetune_config["warmup_min"] = 200
finetune_config["num_history"] = 50
finetune_config['save_model'] = True

# %%
finetune_cycler = cycler(mask_ratio=[0.2, 0.3, 0.4])
finetune_cycler *= cycler(crop_length=[6144*2]) + cycler(minibatch=[96])
finetune_cycler *= cycler(crop_multiple=[16])
finetune_cycler *= cycler(mixup=[0.1])
finetune_cycler *= cycler(descending=[False])
for cyc in finetune_cycler:
    print(cyc)
# Out:
# {'mask_ratio': 0.2, 'crop_length': 12288, 'minibatch': 96, 'crop_multiple': 16, 'mixup': 0.1, 'descending': False}
# {'mask_ratio': 0.3, 'crop_length': 12288, 'minibatch': 96, 'crop_multiple': 16, 'mixup': 0.1, 'descending': False}
# {'mask_ratio': 0.4, 'crop_length': 12288, 'minibatch': 96, 'crop_multiple': 16, 'mixup': 0.1, 'descending': False}

# %%
print('PyTorch version:', torch.__version__)
device = torch.device(device if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available(): print('cuda is available.')
else: print('cuda is unavailable.')
# Out:
# PyTorch version: 2.0.1
# cuda is available.

# %% [markdown]
# ---
# ## Uncertainty Pretraining

# %%
# load pretrained configurations
path = os.path.join(pre_model_path, pre_model_name.split(',')[-1], 'checkpoint.pt')
try:
    ckpt = torch.load(path, map_location="cpu")
    config = ckpt['config']
except Exception as e:
    print(e)
    print(f'- checkpoint cannot be opened: {path}')
config["cwd"] = ""

pprint.pprint(config)
# Out:
# {'EKG': 'O',
#  '_target_': 'models.ssl.mae_1d.mae_1d_pre_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 0.001,
#  'class_label_to_name': ['Normal', 'Abnormal'],
#  'class_name_to_label': {'Abnormal': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 6144,
#  'crop_multiple': 32,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': True,
#  'ddp_size': 4,
#  'device': device(type='cuda', index=0),
#  'draw_result': True,
#  'file_format': 'memmap',
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 390625,
#  'latency': 2000,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.75,
#  'mgn': 0.003,
#  'minibatch': 192,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.0,
#  'multi_batch_size': 24,
#  'norm_pix_loss': True,
#  'num_history': 500,
#  'num_params': 379512960,
#  'num_workers': 16,
#  'out_dims': 2,
#  'output_length': 97,
#  'patch_size': 32,
#  'photic': 'X',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=0))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegNormalizePerSignal(eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=0))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegAddGaussianNoiseAge(mean=0.0, std=0.001)
#   (4): EegNormalizePerSignal(eps=1e-08)
#   (5): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003)
#   (6): EegAdditiveGaussianNoise(mean=0.0, std=0.003)
# ),
#  'project': 'caueeg-mae',
#  'resample': 100,
#  'run_mode': 'train',
#  'sampling_rate': 200,
#  'save_model': True,
#  'search_lr': False,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_length': 3072,
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'task': 'abnormal',
#  'task_description': 'Classification of [Normal] and [Abnormal] symptoms',
#  'task_name': 'CAUEEG-Abnormal benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 300000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=6144, length_limit=10000000, multiple=32, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=6144, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'use_age': 'conv',
#  'use_wandb': True,
#  'warmup_min': 3000,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 19531,
#  'watch_model': False,
#  'weight_decay': 0.01}

# %%
# update configuration
for k, v in art_config.items():
    config[k] = v

# %%
# load pretrained model
if not config.get("ddp", False):
    pre_model_state = ckpt["ssl_model_state"]
else:
    pre_model_state_ddp = deepcopy(ckpt["ssl_model_state"])
    pre_model_state = OrderedDict()
    for k, v in pre_model_state_ddp.items():
        name = k[7:]  # remove 'module.' of DataParallel/DistributedDataParallel
        pre_model_state[name] = v

# %%
config["ddp"] = False

# check the workstation environment and update some configurations
check_device_env(config)

# compose dataset
train_loader, val_loader, test_loader, multicrop_test_loader = compose_dataset(config)

pprint.pprint(config)
# Out:
# {'EKG': 'O',
#  '_target_': 'models.ssl.mae_1d.mae_1d_pre_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'art_dropout': 0.1,
#  'art_use_age': 'no',
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 0.0001,
#  'class_label_to_name': ['Normal', 'Abnormal'],
#  'class_name_to_label': {'Abnormal': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 6144,
#  'crop_multiple': 32,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'ddp_size': 4,
#  'device': device(type='cuda', index=1),
#  'draw_result': True,
#  'file_format': 'memmap',
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 390625,
#  'latency': 2000,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.75,
#  'mgn': 0.003,
#  'minibatch': 192,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.0,
#  'multi_batch_size': 24,
#  'norm_pix_loss': True,
#  'num_history': 50,
#  'num_params': 379512960,
#  'num_workers': 16,
#  'out_dims': 2,
#  'output_length': 97,
#  'patch_size': 32,
#  'photic': 'X',
#  'pre_model': 'r3db85gm',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegNormalizePerSignal(eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377], device='cuda:1'), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409], device='cuda:1'))
#   (3): EegAddGaussianNoiseAge(mean=0.0, std=0.001)
#   (4): EegNormalizePerSignal(eps=1e-08)
#   (5): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003)
#   (6): EegAdditiveGaussianNoise(mean=0.0, std=0.003)
# ),
#  'project': 'caueeg-mae-artifact',
#  'resample': 100,
#  'run_mode': 'train',
#  'sampling_rate': 200,
#  'save_model': False,
#  'search_lr': False,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_length': 3072,
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'task': 'abnormal',
#  'task_description': 'Classification of [Normal] and [Abnormal] symptoms',
#  'task_name': 'CAUEEG-Abnormal benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 5000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=6144, length_limit=10000000, multiple=32, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=6144, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'use_age': 'conv',
#  'use_wandb': False,
#  'warmup_min': 150,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 19531,
#  'watch_model': False,
#  'weight_decay': 0.01}

# %%
# generate the model
config["_target_"] = config["_target_"].replace('pre', 'pre_art').replace('.mae_1d.', '.mae_1d_artifact.')
model = generate_model(config).to(device)

# load the model
model_state = model.state_dict()
for k, v in model_state.items():
    if not k.startswith('art') and not k.endswith("pos_embed"):
        model_state[k] = pre_model_state[k]

pre_model_state = deepcopy(model.state_dict())
model.load_state_dict(model_state)
# Out:
# <All keys matched successfully>

# %%
model.requires_grad_(False)
model = model.eval()

model.art_net.requires_grad_(True)
for k, v in model._parameters.items():
    if k.startswith("art"):
        v.requires_grad_(True)
model.art_net = model.art_net.train()

config["num_params"] = count_parameters(model)

# print(model)

# %%
for name, param in model.named_parameters():
    print(f"{name:100}\t|\t{param.requires_grad}")
# Out:
# class_token                                                                                         	|	False
# enc_pos_embed                                                                                       	|	False
# mask_token                                                                                          	|	False
# dec_pos_embed                                                                                       	|	False
# enc_proj.weight                                                                                     	|	False
# enc_proj.bias                                                                                       	|	False
# enc_blocks.encoder_layer_0.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_0.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_0.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_0.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_0.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_0.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_0.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_0.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_0.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_0.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_0.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_0.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_1.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_1.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_1.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_1.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_1.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_1.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_1.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_1.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_1.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_1.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_1.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_1.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_2.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_2.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_2.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_2.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_2.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_2.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_2.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_2.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_2.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_2.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_2.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_2.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_3.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_3.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_3.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_3.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_3.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_3.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_3.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_3.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_3.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_3.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_3.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_3.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_4.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_4.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_4.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_4.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_4.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_4.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_4.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_4.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_4.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_4.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_4.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_4.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_5.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_5.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_5.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_5.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_5.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_5.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_5.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_5.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_5.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_5.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_5.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_5.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_6.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_6.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_6.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_6.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_6.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_6.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_6.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_6.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_6.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_6.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_6.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_6.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_7.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_7.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_7.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_7.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_7.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_7.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_7.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_7.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_7.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_7.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_7.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_7.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_8.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_8.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_8.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_8.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_8.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_8.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_8.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_8.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_8.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_8.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_8.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_8.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_9.norm1.weight                                                             	|	False
# enc_blocks.encoder_layer_9.norm1.bias                                                               	|	False
# enc_blocks.encoder_layer_9.self_attention.in_proj_weight                                            	|	False
# enc_blocks.encoder_layer_9.self_attention.in_proj_bias                                              	|	False
# enc_blocks.encoder_layer_9.self_attention.out_proj.weight                                           	|	False
# enc_blocks.encoder_layer_9.self_attention.out_proj.bias                                             	|	False
# enc_blocks.encoder_layer_9.norm2.weight                                                             	|	False
# enc_blocks.encoder_layer_9.norm2.bias                                                               	|	False
# enc_blocks.encoder_layer_9.mlp.linear_1.weight                                                      	|	False
# enc_blocks.encoder_layer_9.mlp.linear_1.bias                                                        	|	False
# enc_blocks.encoder_layer_9.mlp.linear_2.weight                                                      	|	False
# enc_blocks.encoder_layer_9.mlp.linear_2.bias                                                        	|	False
# enc_blocks.encoder_layer_10.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_10.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_10.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_10.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_10.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_10.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_10.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_10.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_10.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_10.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_10.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_10.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_11.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_11.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_11.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_11.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_11.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_11.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_11.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_11.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_11.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_11.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_11.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_11.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_12.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_12.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_12.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_12.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_12.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_12.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_12.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_12.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_12.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_12.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_12.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_12.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_13.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_13.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_13.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_13.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_13.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_13.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_13.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_13.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_13.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_13.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_13.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_13.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_14.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_14.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_14.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_14.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_14.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_14.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_14.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_14.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_14.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_14.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_14.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_14.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_15.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_15.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_15.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_15.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_15.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_15.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_15.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_15.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_15.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_15.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_15.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_15.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_16.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_16.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_16.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_16.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_16.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_16.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_16.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_16.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_16.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_16.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_16.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_16.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_17.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_17.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_17.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_17.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_17.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_17.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_17.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_17.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_17.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_17.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_17.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_17.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_18.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_18.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_18.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_18.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_18.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_18.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_18.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_18.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_18.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_18.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_18.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_18.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_19.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_19.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_19.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_19.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_19.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_19.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_19.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_19.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_19.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_19.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_19.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_19.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_20.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_20.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_20.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_20.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_20.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_20.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_20.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_20.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_20.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_20.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_20.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_20.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_21.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_21.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_21.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_21.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_21.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_21.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_21.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_21.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_21.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_21.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_21.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_21.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_22.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_22.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_22.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_22.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_22.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_22.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_22.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_22.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_22.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_22.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_22.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_22.mlp.linear_2.bias                                                       	|	False
# enc_blocks.encoder_layer_23.norm1.weight                                                            	|	False
# enc_blocks.encoder_layer_23.norm1.bias                                                              	|	False
# enc_blocks.encoder_layer_23.self_attention.in_proj_weight                                           	|	False
# enc_blocks.encoder_layer_23.self_attention.in_proj_bias                                             	|	False
# enc_blocks.encoder_layer_23.self_attention.out_proj.weight                                          	|	False
# enc_blocks.encoder_layer_23.self_attention.out_proj.bias                                            	|	False
# enc_blocks.encoder_layer_23.norm2.weight                                                            	|	False
# enc_blocks.encoder_layer_23.norm2.bias                                                              	|	False
# enc_blocks.encoder_layer_23.mlp.linear_1.weight                                                     	|	False
# enc_blocks.encoder_layer_23.mlp.linear_1.bias                                                       	|	False
# enc_blocks.encoder_layer_23.mlp.linear_2.weight                                                     	|	False
# enc_blocks.encoder_layer_23.mlp.linear_2.bias                                                       	|	False
# enc_norm.weight                                                                                     	|	False
# enc_norm.bias                                                                                       	|	False
# dec_proj.weight                                                                                     	|	False
# dec_proj.bias                                                                                       	|	False
# dec_blocks.encoder_layer_0.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_0.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_0.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_0.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_0.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_0.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_0.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_0.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_0.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_0.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_0.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_0.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_1.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_1.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_1.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_1.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_1.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_1.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_1.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_1.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_1.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_1.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_1.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_1.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_2.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_2.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_2.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_2.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_2.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_2.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_2.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_2.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_2.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_2.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_2.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_2.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_3.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_3.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_3.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_3.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_3.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_3.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_3.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_3.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_3.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_3.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_3.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_3.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_4.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_4.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_4.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_4.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_4.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_4.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_4.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_4.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_4.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_4.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_4.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_4.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_5.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_5.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_5.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_5.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_5.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_5.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_5.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_5.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_5.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_5.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_5.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_5.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_6.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_6.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_6.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_6.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_6.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_6.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_6.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_6.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_6.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_6.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_6.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_6.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_7.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_7.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_7.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_7.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_7.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_7.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_7.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_7.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_7.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_7.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_7.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_7.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_8.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_8.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_8.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_8.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_8.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_8.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_8.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_8.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_8.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_8.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_8.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_8.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_9.norm1.weight                                                             	|	False
# dec_blocks.encoder_layer_9.norm1.bias                                                               	|	False
# dec_blocks.encoder_layer_9.self_attention.in_proj_weight                                            	|	False
# dec_blocks.encoder_layer_9.self_attention.in_proj_bias                                              	|	False
# dec_blocks.encoder_layer_9.self_attention.out_proj.weight                                           	|	False
# dec_blocks.encoder_layer_9.self_attention.out_proj.bias                                             	|	False
# dec_blocks.encoder_layer_9.norm2.weight                                                             	|	False
# dec_blocks.encoder_layer_9.norm2.bias                                                               	|	False
# dec_blocks.encoder_layer_9.mlp.linear_1.weight                                                      	|	False
# dec_blocks.encoder_layer_9.mlp.linear_1.bias                                                        	|	False
# dec_blocks.encoder_layer_9.mlp.linear_2.weight                                                      	|	False
# dec_blocks.encoder_layer_9.mlp.linear_2.bias                                                        	|	False
# dec_blocks.encoder_layer_10.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_10.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_10.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_10.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_10.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_10.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_10.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_10.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_10.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_10.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_10.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_10.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_11.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_11.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_11.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_11.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_11.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_11.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_11.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_11.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_11.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_11.mlp.linear_1.bias                                                       	|	False
# ...
# dec_blocks.encoder_layer_13.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_13.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_13.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_13.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_13.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_14.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_14.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_14.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_14.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_14.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_14.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_14.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_14.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_14.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_14.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_14.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_14.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_15.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_15.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_15.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_15.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_15.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_15.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_15.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_15.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_15.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_15.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_15.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_15.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_16.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_16.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_16.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_16.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_16.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_16.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_16.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_16.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_16.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_16.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_16.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_16.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_17.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_17.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_17.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_17.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_17.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_17.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_17.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_17.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_17.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_17.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_17.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_17.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_18.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_18.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_18.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_18.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_18.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_18.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_18.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_18.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_18.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_18.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_18.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_18.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_19.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_19.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_19.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_19.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_19.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_19.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_19.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_19.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_19.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_19.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_19.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_19.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_20.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_20.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_20.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_20.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_20.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_20.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_20.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_20.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_20.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_20.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_20.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_20.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_21.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_21.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_21.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_21.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_21.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_21.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_21.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_21.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_21.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_21.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_21.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_21.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_22.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_22.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_22.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_22.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_22.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_22.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_22.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_22.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_22.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_22.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_22.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_22.mlp.linear_2.bias                                                       	|	False
# dec_blocks.encoder_layer_23.norm1.weight                                                            	|	False
# dec_blocks.encoder_layer_23.norm1.bias                                                              	|	False
# dec_blocks.encoder_layer_23.self_attention.in_proj_weight                                           	|	False
# dec_blocks.encoder_layer_23.self_attention.in_proj_bias                                             	|	False
# dec_blocks.encoder_layer_23.self_attention.out_proj.weight                                          	|	False
# dec_blocks.encoder_layer_23.self_attention.out_proj.bias                                            	|	False
# dec_blocks.encoder_layer_23.norm2.weight                                                            	|	False
# dec_blocks.encoder_layer_23.norm2.bias                                                              	|	False
# dec_blocks.encoder_layer_23.mlp.linear_1.weight                                                     	|	False
# dec_blocks.encoder_layer_23.mlp.linear_1.bias                                                       	|	False
# dec_blocks.encoder_layer_23.mlp.linear_2.weight                                                     	|	False
# dec_blocks.encoder_layer_23.mlp.linear_2.bias                                                       	|	False
# dec_norm.weight                                                                                     	|	False
# dec_norm.bias                                                                                       	|	False
# decoder_pred.weight                                                                                 	|	False
# decoder_pred.bias                                                                                   	|	False
# art_net.0.weight                                                                                    	|	True
# art_net.0.bias                                                                                      	|	True
# art_net.1.weight                                                                                    	|	True
# art_net.1.bias                                                                                      	|	True
# art_net.3.weight                                                                                    	|	True
# art_net.3.bias                                                                                      	|	True
# art_net.4.weight                                                                                    	|	True
# art_net.4.bias                                                                                      	|	True
# art_net.6.weight                                                                                    	|	True
# art_net.6.bias                                                                                      	|	True
# art_net.7.weight                                                                                    	|	True
# art_net.7.bias                                                                                      	|	True
# art_net.11.weight                                                                                   	|	True
# art_net.13.weight                                                                                   	|	True
# art_net.13.bias                                                                                     	|	True
# art_net.15.weight                                                                                   	|	True
# art_net.15.bias                                                                                     	|	True

# %%
# collect some garbage
gc.collect()
torch.cuda.empty_cache()
torch.cuda.synchronize()

# fix the seed for reproducibility (a negative seed value means not fixing)
set_seed(config, rank=None)

# train
ssl_train_script(
    config,
    model,
    train_loader,
    config["preprocess_train"],
)

for k, v in model_state.items():
    pre_model_state[k] = model_state[k].to("cpu")
# Out:
# ******************************    Configurations for Train    ******************************
#
# {'EKG': 'O',
#  '_target_': 'models.ssl.mae_1d_artifact.mae_1d_pre_art_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'art_dropout': 0.1,
#  'art_use_age': 'no',
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 0.0001,
#  'class_label_to_name': ['Normal', 'Abnormal'],
#  'class_name_to_label': {'Abnormal': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 6144,
#  'crop_multiple': 32,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'ddp_size': 4,
#  'device': device(type='cuda', index=1),
#  'draw_result': True,
#  'file_format': 'memmap',
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 390625,
#  'latency': 2000,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.75,
#  'mgn': 0.003,
#  'minibatch': 192,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.0,
#  'multi_batch_size': 24,
#  'norm_pix_loss': True,
#  'num_history': 50,
#  'num_params': 87969,
#  'num_workers': 16,
#  'out_dims': 2,
#  'output_length': 97,
#  'patch_size': 32,
#  'photic': 'X',
#  'pre_model': 'r3db85gm',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegNormalizePerSignal(eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377], device='cuda:1'), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409], device='cuda:1'))
#   (3): EegAddGaussianNoiseAge(mean=0.0, std=0.001)
#   (4): EegNormalizePerSignal(eps=1e-08)
#   (5): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003)
#   (6): EegAdditiveGaussianNoise(mean=0.0, std=0.003)
# ),
#  'project': 'caueeg-mae-artifact',
#  'resample': 100,
#  'run_mode': 'train',
#  'sampling_rate': 200,
#  'save_model': False,
#  'search_lr': False,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_length': 3072,
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'task': 'abnormal',
#  'task_description': 'Classification of [Normal] and [Abnormal] symptoms',
#  'task_name': 'CAUEEG-Abnormal benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 5000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=6144, length_limit=10000000, multiple=32, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=6144, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'use_age': 'conv',
#  'use_wandb': False,
#  'warmup_min': 150,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 19531,
#  'watch_model': False,
#  'weight_decay': 0.01}
#
# ********************************************************************************************
#
#      130 /     6510 iter - Loss: 0.4143
#      260 /     6510 iter - Loss: 0.1251
#      390 /     6510 iter - Loss: 0.0662
#      520 /     6510 iter - Loss: 0.0494
#      650 /     6510 iter - Loss: 0.0428
#      780 /     6510 iter - Loss: 0.0373
#      910 /     6510 iter - Loss: 0.0349
#     1040 /     6510 iter - Loss: 0.0315
#     1170 /     6510 iter - Loss: 0.0274
#     1300 /     6510 iter - Loss: 0.0217
#     1430 /     6510 iter - Loss: 0.0170
#     1560 /     6510 iter - Loss: 0.0146
#     1690 /     6510 iter - Loss: 0.0128
#     1820 /     6510 iter - Loss: 0.0121
#     1950 /     6510 iter - Loss: 0.0108
#     2080 /     6510 iter - Loss: 0.0111
#     2210 /     6510 iter - Loss: 0.0113
#     2340 /     6510 iter - Loss: 0.0102
#     2470 /     6510 iter - Loss: 0.0102
#     2600 /     6510 iter - Loss: 0.0097
#     2730 /     6510 iter - Loss: 0.0103
#     2860 /     6510 iter - Loss: 0.0097
#     2990 /     6510 iter - Loss: 0.0092
#     3120 /     6510 iter - Loss: 0.0089
#     3250 /     6510 iter - Loss: 0.0090
#     3380 /     6510 iter - Loss: 0.0094
#     3510 /     6510 iter - Loss: 0.0076
#     3640 /     6510 iter - Loss: 0.0076
#     3770 /     6510 iter - Loss: 0.0084
#     3900 /     6510 iter - Loss: 0.0079
#     4030 /     6510 iter - Loss: 0.0087
#     4160 /     6510 iter - Loss: 0.0071
#     4290 /     6510 iter - Loss: 0.0087
#     4420 /     6510 iter - Loss: 0.0080
#     4550 /     6510 iter - Loss: 0.0086
#     4680 /     6510 iter - Loss: 0.0075
#     4810 /     6510 iter - Loss: 0.0086
#     4940 /     6510 iter - Loss: 0.0070
#     5070 /     6510 iter - Loss: 0.0082
#     5200 /     6510 iter - Loss: 0.0077
#     5330 /     6510 iter - Loss: 0.0082
#     5460 /     6510 iter - Loss: 0.0082
#     5590 /     6510 iter - Loss: 0.0083
#     5720 /     6510 iter - Loss: 0.0085
#     5850 /     6510 iter - Loss: 0.0081
#     5980 /     6510 iter - Loss: 0.0074
#     6110 /     6510 iter - Loss: 0.0083
#     6240 /     6510 iter - Loss: 0.0076
#     6370 /     6510 iter - Loss: 0.0071
#     6500 /     6510 iter - Loss: 0.0077
#     6630 /     6510 iter - Loss: 0.0080

# %% [markdown]
# ---
# ## Visualize

# %%
signal_header = [channel.split('-')[0] for i, channel in enumerate(config["signal_header"])]
fps = config.get('resample', 200)

# %%
@plt.style.context(['ieee', 'science', 'default'])
def draw_eeg_graph(x, pred, mask, art_out, rec_loss, num=None):
    plt.rcParams.update({'font.family': 'Ubuntu'})
    N, C, L = x.shape
    _, l = mask.shape
    patch_size = L // l

    art_out = art_out.reshape(N, -1)
    rec_loss = rec_loss.reshape(N, -1)

    for n in range(N):
        if num is not None and num <= n:
            break
        
        fig = plt.figure(num=1, clear=True, figsize=(25.0, 17.0))
        fig.subplots_adjust(hspace=0)
        
        for c in range(C):
            ax = fig.add_subplot(C, 1, c + 1)
            ax.plot(x[n, c].cpu().numpy(), lw=1, c='tab:red', label='origin')
            ax.plot(pred[n, c].cpu().numpy(), lw=1, c='tab:blue', label='pred')

            art_mid = art_out[n].median()
            rec_mid = art_out[n].median()
            for r in range(l):
                if r > 0:
                    ax.axvline(r*patch_size, color='tab:purple', alpha=0.4)
                if mask[n, r]:
                    ax.axvspan(r*patch_size, (r + 1)*patch_size, facecolor='tab:purple', alpha=0.2)

                if c == 0:
                    if art_mid <= art_out[n, r]:
                        ax.annotate(f"{art_out[n, r]:3.2f}", 
                                    xy=((r + 0.5)*patch_size, 1), ha='center', va='bottom', color='tab:purple')
                    else:
                        ax.annotate(f"{art_out[n, r]:3.2f}", 
                                    xy=((r + 0.5)*patch_size, 1), ha='center', va='bottom')
                    if rec_mid <= rec_loss[n, r]:
                        ax.annotate(f"{rec_loss[n, r]:3.2f}", 
                                    xy=((r + 0.5)*patch_size, -1), ha='center', va='bottom', color='tab:purple')
                    else:
                        ax.annotate(f"{rec_loss[n, r]:3.2f}", 
                                    xy=((r + 0.5)*patch_size, -1), ha='center', va='bottom')

            ax.set_xlim(0, L)
            ax.set_ylabel(signal_header[c])
            ax.set_xticks(np.arange(round(config["seq_length"] / fps) + 1) * fps)
            ax.set_xticklabels([])
            # ax.tick_params(axis='x', width=0.1, length=0.1)
            ax.set_yticks([0])
            ax.set_yticklabels([])
        
        ax.set_xticks(np.arange(round(config["seq_length"] / fps) + 1) * fps)
        ax.set_xticklabels(np.arange(round(config["seq_length"] / fps) + 1))
        
        ax.set_xlabel('Time (s)')
        # fig.savefig(os.path.join(output_folder, 'signal_example.pdf'), transparent=True)
        plt.show()
        fig.clear()
        plt.close(fig)

# %%
with torch.no_grad():
    for target_dataset in tqdm(["val"], desc="Dataset", leave=False):
        if target_dataset == 'train':
            loader = train_loader
        elif target_dataset == 'val':
            loader = val_loader
        elif target_dataset == 'test':
            loader = test_loader
        else:
            raise ValueError('')
                
        for sample_batched in tqdm(loader, total=len(loader), desc='Batch', leave=False):
            print(target_dataset)
            config["preprocess_test"](sample_batched)
            x = sample_batched["signal"]
            age = sample_batched["age"]

            pred, mask = model.mask_and_reconstruct(x, age, config["mask_ratio"])
            rec_loss = model.compute_reconstruction_loss2(x, pred)
            art_out = model.forward_artifact(x, age)
            
            pred_eeg = model.unpatchify(pred)
            draw_eeg_graph(x, pred_eeg, mask, art_out, rec_loss, 2)

            break
        break
# Out:
# Dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# Batch:   0%|          | 0/23 [00:01<?, ?it/s]
# val

# %%
del model, ckpt

gc.collect()
torch.cuda.empty_cache()
torch.cuda.synchronize()

# %% [markdown]
# ---
# ## Finetuning

# %%
for cyc in finetune_cycler:
    # update configuration
    for k, v in finetune_config.items():
        config[k] = v
    for k, v in cyc.items():
        config[k] = v
    config["ddp"] = False

    # check the workstation environment and update some configurations
    check_device_env(config)
    
    # compose dataset
    train_loader, val_loader, test_loader, multicrop_test_loader = compose_dataset(config)
    pprint.pprint(config)

    # generate the model
    config["_target_"] = config["_target_"].replace('.ssl', '').replace('_pre', '')
    model = generate_model(config).to(device)
    
    # load the model
    model_state = model.state_dict()
    for k, v in model_state.items():
        if not k.startswith("fc") and not k.endswith("pos_embed"):
            model_state[k] = pre_model_state[k]
    
    model.load_state_dict(model_state)
    model.finetune_mode(config["tuning_type"])
    config["num_params"] = count_parameters(model)
    
    for name, param in model.named_parameters():
        print(f"{name:100}\t|\t{param.requires_grad}")

    # collect some garbage
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    
    # fix the seed for reproducibility (a negative seed value means not fixing)
    set_seed(config, rank=None)
    
    # train
    train_script(
        config,
        model,
        train_loader,
        val_loader,
        test_loader,
        multicrop_test_loader,
        config["preprocess_train"],
        config["preprocess_test"],
    )

print("- END -")
# Out:
# {'EKG': 'O',
#  '_target_': 'models.ssl.mae_1d_artifact.mae_1d_pre_art_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'art_dropout': 0.1,
#  'art_use_age': 'no',
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 0.0001,
#  'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 12288,
#  'crop_multiple': 16,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'ddp_size': 4,
#  'descending': False,
#  'device': device(type='cuda', index=1),
#  'draw_result': True,
#  'dropout': 0.1,
#  'fc_stages': 2,
#  'file_format': 'memmap',
#  'global_pool': True,
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 6510,
#  'latency': 2000,
#  'layer_wise_lr': True,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.2,
#  'mgn': 0.003,
#  'minibatch': 96,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.1,
#  'multi_batch_size': 12,
#  'norm_pix_loss': True,
#  'num_history': 50,
#  'num_params': 87969,
#  'num_workers': 16,
#  'out_dims': 3,
#  'output_length': 97,
#  'patch_size': 32,
#  'photic': 'X',
#  'pre_model': 'r3db85gm',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegNormalizePerSignal(eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377], device='cuda:1'), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409], device='cuda:1'))
#   (3): EegAddGaussianNoiseAge(mean=0.0, std=0.001)
#   (4): EegNormalizePerSignal(eps=1e-08)
#   (5): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003)
#   (6): EegAdditiveGaussianNoise(mean=0.0, std=0.003)
# ),
#  'project': 'caueeg-mae-artifact-finetune',
#  'resample': 100,
#  'run_mode': 'train',
#  'sampling_rate': 200,
#  'save_model': True,
#  'search_lr': True,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_length': 6144,
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'task': 'dementia',
#  'task_description': 'Classification of [Normal], [MCI], and [Dementia] '
#                      'symptoms.',
#  'task_name': 'CAUEEG-Dementia benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 3000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=12288, length_limit=10000000, multiple=16, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=12288, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'tuning_type': 'finetune',
#  'use_age': 'conv',
#  'use_wandb': True,
#  'warmup_min': 200,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 326,
#  'watch_model': False,
#  'weight_decay': 0.01}
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# class_token                                                                                         	|	True
# enc_pos_embed                                                                                       	|	False
# enc_proj.weight                                                                                     	|	True
# enc_proj.bias                                                                                       	|	True
# enc_blocks.encoder_layer_0.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_0.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_0.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_0.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_0.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_0.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_0.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_0.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_0.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_0.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_0.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_0.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_1.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_1.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_1.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_1.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_1.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_1.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_1.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_1.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_1.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_1.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_1.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_1.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_2.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_2.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_2.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_2.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_2.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_2.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_2.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_2.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_2.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_2.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_2.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_2.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_3.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_3.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_3.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_3.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_3.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_3.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_3.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_3.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_3.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_3.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_3.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_3.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_4.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_4.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_4.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_4.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_4.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_4.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_4.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_4.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_4.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_4.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_4.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_4.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_5.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_5.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_5.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_5.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_5.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_5.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_5.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_5.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_5.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_5.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_5.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_5.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_6.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_6.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_6.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_6.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_6.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_6.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_6.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_6.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_6.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_6.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_6.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_6.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_7.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_7.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_7.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_7.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_7.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_7.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_7.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_7.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_7.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_7.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_7.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_7.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_8.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_8.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_8.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_8.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_8.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_8.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_8.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_8.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_8.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_8.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_8.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_8.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_9.norm1.weight                                                             	|	True
# enc_blocks.encoder_layer_9.norm1.bias                                                               	|	True
# enc_blocks.encoder_layer_9.self_attention.in_proj_weight                                            	|	True
# enc_blocks.encoder_layer_9.self_attention.in_proj_bias                                              	|	True
# enc_blocks.encoder_layer_9.self_attention.out_proj.weight                                           	|	True
# enc_blocks.encoder_layer_9.self_attention.out_proj.bias                                             	|	True
# enc_blocks.encoder_layer_9.norm2.weight                                                             	|	True
# enc_blocks.encoder_layer_9.norm2.bias                                                               	|	True
# enc_blocks.encoder_layer_9.mlp.linear_1.weight                                                      	|	True
# enc_blocks.encoder_layer_9.mlp.linear_1.bias                                                        	|	True
# enc_blocks.encoder_layer_9.mlp.linear_2.weight                                                      	|	True
# enc_blocks.encoder_layer_9.mlp.linear_2.bias                                                        	|	True
# enc_blocks.encoder_layer_10.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_10.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_10.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_10.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_10.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_10.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_10.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_10.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_10.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_10.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_10.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_10.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_11.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_11.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_11.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_11.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_11.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_11.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_11.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_11.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_11.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_11.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_11.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_11.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_12.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_12.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_12.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_12.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_12.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_12.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_12.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_12.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_12.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_12.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_12.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_12.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_13.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_13.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_13.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_13.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_13.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_13.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_13.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_13.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_13.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_13.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_13.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_13.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_14.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_14.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_14.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_14.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_14.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_14.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_14.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_14.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_14.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_14.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_14.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_14.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_15.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_15.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_15.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_15.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_15.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_15.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_15.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_15.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_15.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_15.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_15.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_15.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_16.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_16.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_16.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_16.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_16.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_16.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_16.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_16.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_16.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_16.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_16.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_16.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_17.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_17.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_17.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_17.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_17.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_17.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_17.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_17.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_17.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_17.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_17.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_17.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_18.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_18.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_18.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_18.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_18.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_18.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_18.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_18.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_18.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_18.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_18.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_18.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_19.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_19.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_19.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_19.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_19.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_19.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_19.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_19.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_19.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_19.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_19.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_19.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_20.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_20.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_20.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_20.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_20.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_20.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_20.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_20.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_20.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_20.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_20.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_20.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_21.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_21.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_21.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_21.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_21.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_21.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_21.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_21.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_21.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_21.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_21.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_21.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_22.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_22.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_22.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_22.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_22.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_22.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_22.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_22.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_22.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_22.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_22.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_22.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_23.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_23.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_23.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_23.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_23.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_23.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_23.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_23.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_23.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_23.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_23.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_23.mlp.linear_2.bias                                                       	|	True
# enc_norm.weight                                                                                     	|	True
# enc_norm.bias                                                                                       	|	True
# art_net.0.weight                                                                                    	|	False
# art_net.0.bias                                                                                      	|	False
# art_net.1.weight                                                                                    	|	False
# art_net.1.bias                                                                                      	|	False
# art_net.3.weight                                                                                    	|	False
# art_net.3.bias                                                                                      	|	False
# art_net.4.weight                                                                                    	|	False
# art_net.4.bias                                                                                      	|	False
# art_net.6.weight                                                                                    	|	False
# art_net.6.bias                                                                                      	|	False
# art_net.7.weight                                                                                    	|	False
# art_net.7.bias                                                                                      	|	False
# art_net.11.weight                                                                                   	|	False
# art_net.13.weight                                                                                   	|	False
# art_net.13.bias                                                                                     	|	False
# art_net.15.weight                                                                                   	|	False
# art_net.15.bias                                                                                     	|	False
# fc_stage.0.0.weight                                                                                 	|	True
# fc_stage.0.2.weight                                                                                 	|	True
# fc_stage.0.2.bias                                                                                   	|	True
# fc_stage.1.weight                                                                                   	|	True
# fc_stage.1.bias                                                                                     	|	True
#
# ******************************    Configurations for Train    ******************************
#
# {'EKG': 'O',
#  '_target_': 'models.mae_1d_artifact.mae_1d_art_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'art_dropout': 0.1,
#  'art_use_age': 'no',
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 0.0001,
#  'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 12288,
#  'crop_multiple': 16,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'ddp_size': 4,
#  'descending': False,
#  'device': device(type='cuda', index=1),
#  'draw_result': True,
#  'dropout': 0.1,
#  'fc_stages': 2,
#  'file_format': 'memmap',
#  'global_pool': True,
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 6510,
#  'latency': 2000,
#  'layer_wise_lr': True,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.2,
#  'mgn': 0.003,
#  'minibatch': 96,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.1,
#  'multi_batch_size': 12,
#  'norm_pix_loss': True,
#  'num_history': 50,
#  'num_params': 303528451,
#  'num_workers': 16,
#  'out_dims': 3,
#  'output_length': 193,
#  'patch_size': 32,
#  'photic': 'X',
#  'pre_model': 'r3db85gm',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegNormalizePerSignal(eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377], device='cuda:1'), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409], device='cuda:1'))
#   (3): EegAddGaussianNoiseAge(mean=0.0, std=0.001)
#   (4): EegNormalizePerSignal(eps=1e-08)
#   (5): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003)
#   (6): EegAdditiveGaussianNoise(mean=0.0, std=0.003)
# ),
#  'project': 'caueeg-mae-artifact-finetune',
#  'resample': 100,
#  'run_mode': 'train',
#  'sampling_rate': 200,
#  'save_model': True,
#  'search_lr': True,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_length': 6144,
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'task': 'dementia',
#  'task_description': 'Classification of [Normal], [MCI], and [Dementia] symptoms.',
#  'task_name': 'CAUEEG-Dementia benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 3000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=12288, length_limit=10000000, multiple=16, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=12288, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'tuning_type': 'finetune',
#  'use_age': 'conv',
#  'use_wandb': True,
#  'warmup_min': 200,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 326,
#  'watch_model': False,
#  'weight_decay': 0.01}
#
# ********************************************************************************************
# wandb: Currently logged in as: ipis-mjkim. Use `wandb login --relogin` to force relogin
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/home/imkbsz/workspace/eeg_analysis/wandb/run-20231224_102717-waz1wer1</code>
# Syncing run <strong><a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/waz1wer1' target="_blank">peach-monkey-398</a></strong> to <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune</a>
#  View run at <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/waz1wer1' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/waz1wer1</a>
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:139: UserWarning:
#
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:139: UserWarning:
#
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/wandb/sdk/lib/ipython.py:70: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/wandb/sdk/lib/ipython.py:82: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# VBox(children=(Label(value='7.110 MB of 7.110 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Learning Rate</td><td>▄▇██████▇▇▇▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>Loss</td><td>█▆▅▄▂▂▂▂▂▂▂▂▁▂▁▂▂▁▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂</td></tr><tr><td>Multi-Crop Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Train Accuracy</td><td>▁▃▄▅▇▇▇▇▇███████████████████████████████</td></tr><tr><td>Validation Accuracy</td><td>▁▆▅▃▄▃▆▅▇▄▇▆▆▅▇▇▆▇▇██▇▇▇▆▇▆▇▆▇▇▇▇▇▇▆▆▆▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Loss</td><td>0.20766</td></tr><tr><td>Multi-Crop Test Accuracy</td><td>64.71751</td></tr><tr><td>Test Accuracy</td><td>62.10275</td></tr><tr><td>Train Accuracy</td><td>93.88529</td></tr><tr><td>Validation Accuracy</td><td>64.97199</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peach-monkey-398</strong> at: <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/waz1wer1' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/waz1wer1</a><br/>Synced 7 W&B file(s), 3 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231224_102717-waz1wer1/logs</code>
# {'EKG': 'O',
#  '_target_': 'models.mae_1d_artifact.mae_1d_art_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'art_dropout': 0.1,
#  'art_use_age': 'no',
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 9.191613881702212e-05,
#  'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 12288,
#  'crop_multiple': 16,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'ddp_size': 4,
#  'descending': False,
#  'device': device(type='cuda', index=1),
#  'draw_result': True,
#  'dropout': 0.1,
#  'fc_stages': 2,
#  'file_format': 'memmap',
#  'global_pool': True,
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 7812,
#  'latency': 2000,
#  'layer_wise_lr': True,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.3,
#  'mgn': 0.003,
#  'minibatch': 96,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.1,
#  'multi_batch_size': 12,
#  'norm_pix_loss': True,
#  'num_history': 50,
#  'num_params': 303528451,
#  'num_workers': 16,
#  'out_dims': 3,
#  'output_length': 193,
#  'patch_size': 32,
#  'photic': 'X',
# ...
# enc_blocks.encoder_layer_20.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_20.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_20.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_20.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_20.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_20.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_20.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_21.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_21.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_21.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_21.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_21.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_21.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_21.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_21.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_21.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_21.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_21.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_21.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_22.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_22.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_22.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_22.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_22.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_22.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_22.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_22.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_22.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_22.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_22.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_22.mlp.linear_2.bias                                                       	|	True
# enc_blocks.encoder_layer_23.norm1.weight                                                            	|	True
# enc_blocks.encoder_layer_23.norm1.bias                                                              	|	True
# enc_blocks.encoder_layer_23.self_attention.in_proj_weight                                           	|	True
# enc_blocks.encoder_layer_23.self_attention.in_proj_bias                                             	|	True
# enc_blocks.encoder_layer_23.self_attention.out_proj.weight                                          	|	True
# enc_blocks.encoder_layer_23.self_attention.out_proj.bias                                            	|	True
# enc_blocks.encoder_layer_23.norm2.weight                                                            	|	True
# enc_blocks.encoder_layer_23.norm2.bias                                                              	|	True
# enc_blocks.encoder_layer_23.mlp.linear_1.weight                                                     	|	True
# enc_blocks.encoder_layer_23.mlp.linear_1.bias                                                       	|	True
# enc_blocks.encoder_layer_23.mlp.linear_2.weight                                                     	|	True
# enc_blocks.encoder_layer_23.mlp.linear_2.bias                                                       	|	True
# enc_norm.weight                                                                                     	|	True
# enc_norm.bias                                                                                       	|	True
# art_net.0.weight                                                                                    	|	False
# art_net.0.bias                                                                                      	|	False
# art_net.1.weight                                                                                    	|	False
# art_net.1.bias                                                                                      	|	False
# art_net.3.weight                                                                                    	|	False
# art_net.3.bias                                                                                      	|	False
# art_net.4.weight                                                                                    	|	False
# art_net.4.bias                                                                                      	|	False
# art_net.6.weight                                                                                    	|	False
# art_net.6.bias                                                                                      	|	False
# art_net.7.weight                                                                                    	|	False
# art_net.7.bias                                                                                      	|	False
# art_net.11.weight                                                                                   	|	False
# art_net.13.weight                                                                                   	|	False
# art_net.13.bias                                                                                     	|	False
# art_net.15.weight                                                                                   	|	False
# art_net.15.bias                                                                                     	|	False
# fc_stage.0.0.weight                                                                                 	|	True
# fc_stage.0.2.weight                                                                                 	|	True
# fc_stage.0.2.bias                                                                                   	|	True
# fc_stage.1.weight                                                                                   	|	True
# fc_stage.1.bias                                                                                     	|	True
#
# ******************************    Configurations for Train    ******************************
#
# {'EKG': 'O',
#  '_target_': 'models.mae_1d_artifact.mae_1d_art_l_e1024_d512',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1377]),
#  'age_std': tensor([8.7409]),
#  'art_dropout': 0.1,
#  'art_use_age': 'no',
#  'awgn': 0.003,
#  'awgn_age': 0.001,
#  'base_lr': 0.0001290506491335074,
#  'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'criterion': 'cross-entropy',
#  'crop_length': 12288,
#  'crop_multiple': 16,
#  'crop_timing_analysis': False,
#  'cwd': '',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'ddp_size': 4,
#  'descending': False,
#  'device': device(type='cuda', index=1),
#  'draw_result': True,
#  'dropout': 0.1,
#  'fc_stages': 2,
#  'file_format': 'memmap',
#  'global_pool': True,
#  'in_channels': 20,
#  'input_norm': 'datapoint',
#  'iterations': 7812,
#  'latency': 2000,
#  'layer_wise_lr': True,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mask_ratio': 0.4,
#  'mgn': 0.003,
#  'minibatch': 96,
#  'minibatch_3090': 192,
#  'mixed_precision': True,
#  'mixup': 0.1,
#  'multi_batch_size': 12,
#  'norm_pix_loss': True,
#  'num_history': 50,
#  'num_params': 303528451,
#  'num_workers': 16,
#  'out_dims': 3,
#  'output_length': 193,
#  'patch_size': 32,
#  'photic': 'X',
#  'pre_model': 'r3db85gm',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377]), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409]))
#   (3): EegNormalizePerSignal(eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=1))
#   (1): EegResample(orig_freq=200, new_freq=100, resampling_method='sinc_interp_hann')
#   (2): EegNormalizeAge(mean=tensor([71.1377], device='cuda:1'), std=tensor([8.7409]), eps=1e-08, std_eps=tensor([8.7409], device='cuda:1'))
#   (3): EegAddGaussianNoiseAge(mean=0.0, std=0.001)
#   (4): EegNormalizePerSignal(eps=1e-08)
#   (5): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003)
#   (6): EegAdditiveGaussianNoise(mean=0.0, std=0.003)
# ),
#  'project': 'caueeg-mae-artifact-finetune',
#  'resample': 100,
#  'run_mode': 'train',
#  'sampling_rate': 200,
#  'save_model': True,
#  'search_lr': True,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_length': 6144,
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'task': 'dementia',
#  'task_description': 'Classification of [Normal], [MCI], and [Dementia] symptoms.',
#  'task_name': 'CAUEEG-Dementia benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 3000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=12288, length_limit=10000000, multiple=16, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=12288, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegDropChannels(drop_index=[20])
#     EegToTensor()
# ),
#  'tuning_type': 'finetune',
#  'use_age': 'conv',
#  'use_wandb': True,
#  'warmup_min': 200,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 391,
#  'watch_model': False,
#  'weight_decay': 0.01}
#
# ********************************************************************************************
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/wandb/sdk/lib/ipython.py:70: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/home/imkbsz/workspace/eeg_analysis/wandb/run-20231225_125202-ww5ugech</code>
# Syncing run <strong><a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/ww5ugech' target="_blank">classic-disco-402</a></strong> to <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune</a>
#  View run at <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/ww5ugech' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/ww5ugech</a>
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:139: UserWarning:
#
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:139: UserWarning:
#
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/wandb/sdk/lib/ipython.py:70: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# /home/imkbsz/anaconda3/envs/eeg/lib/python3.9/site-packages/wandb/sdk/lib/ipython.py:82: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# VBox(children=(Label(value='7.255 MB of 7.255 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Learning Rate</td><td>▄▇██████▇▇▇▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>Loss</td><td>█▆▅▄▂▂▂▂▂▂▂▁▁▂▁▁▂▁▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>Multi-Crop Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Train Accuracy</td><td>▁▃▄▆▇▇█▇████████████████████████████████</td></tr><tr><td>Validation Accuracy</td><td>▁▆▆▅▆▅▇█▇▇▆▆▆▆▆▅▆▇▅▆▆▆▆▆▆▆▆▇▆▆▆▇▇▇▇▆▇▆▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Loss</td><td>0.20266</td></tr><tr><td>Multi-Crop Test Accuracy</td><td>65.22599</td></tr><tr><td>Test Accuracy</td><td>62.16984</td></tr><tr><td>Train Accuracy</td><td>94.06917</td></tr><tr><td>Validation Accuracy</td><td>64.03536</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">classic-disco-402</strong> at: <a href='https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/ww5ugech' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-mae-artifact-finetune/runs/ww5ugech</a><br/>Synced 7 W&B file(s), 3 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231225_125202-ww5ugech/logs</code>
# - END -
