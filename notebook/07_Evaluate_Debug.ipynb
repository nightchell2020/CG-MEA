# %% [markdown]
# # Evaluate
#
# This notebook evaluates the network trained previous notebooks and analyzes the results.

# %% [markdown]
# -----
#
# ## Load Packages

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# C:\Users\Minjae\Desktop\EEG_Project

# %%
# Load some packages
import os
from copy import deepcopy
import hydra
from omegaconf import OmegaConf
from collections import OrderedDict

import numpy as np
from sklearn.metrics import classification_report
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import pprint
import matplotlib
import matplotlib.pyplot as plt

# custom package
from datasets.caueeg_script import build_dataset_for_train
import models
from train.evaluate import check_accuracy
from train.evaluate import check_accuracy_extended
from train.evaluate import check_accuracy_extended_debug
from train.evaluate import check_accuracy_multicrop
from train.evaluate import check_accuracy_multicrop_extended
from train.visualize import draw_roc_curve
from train.visualize import draw_confusion
from train.visualize import draw_class_wise_metrics
from train.visualize import draw_error_table
from train.visualize import annotate_heatmap

# %%
print('PyTorch version:', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available(): print('cuda is available.')
else: print('cuda is unavailable.')
# Out:
# PyTorch version: 1.11.0+cu113
# cuda is available.

# %% [markdown]
# -----
#
# ## Load the configuration used during the train phase

# %%
model_name = '6a1tnz3r'
model_path = os.path.join(r'E:\CAUEEG\checkpoint', model_name, 'checkpoint.pt')

ckpt = torch.load(model_path, map_location=device)
print(ckpt.keys())
# Out:
# dict_keys(['model_state', 'config', 'optimizer_state', 'scheduler_state'])

# %%
model_state = ckpt['model_state']
config = ckpt['config']
optimizer = ckpt['optimizer_state']
scheduler = ckpt['scheduler_state']

# %%
pprint.pprint(config, width=250)
# Out:
# {'EKG': 'O',
#  '_target_': 'models.resnet_2d.ResNet2D',
#  'activation': 'relu',
#  'age_mean': tensor([71.2425], device='cuda:0'),
#  'age_std': tensor([9.5208], device='cuda:0'),
#  'awgn': 0.014560543566041024,
#  'awgn_age': 0.0626811693876168,
#  'base_channels': 64,
#  'base_lr': 0.002523829377920773,
#  'block': 'bottleneck',
#  'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'conv_layers': [3, 4, 6, 3],
#  'criterion': 'multi-bce',
#  'crop_multiple': 4,
#  'crop_timing_analysis': False,
#  'cwd': 'C:\\Users\\Minjae\\Desktop\\EEG_Project',
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/02_Curated_Data_220419/',
#  'ddp': False,
#  'device': device(type='cuda'),
#  'draw_result': True,
#  'dropout': 0.2609391962436677,
#  'fc_stages': 2,
#  'file_format': 'memmap',
#  'groups': 32,
#  'in_channels': 42,
#  'input_norm': 'dataset',
#  'iterations': 781250,
#  'latency': 2000,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_one_and_half',
#  'mgn': 0.06347426794981546,
#  'minibatch': 128,
#  'mixup': 0.1,
#  'model': '2D-ResNeXt-50',
#  'multi_batch_size': 16,
#  'num_history': 500,
#  'num_params': 25207619,
#  'out_dims': 3,
#  'output_length': 8,
#  'photic': 'O',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=cuda)
#   (1): EegNormalizeAge(mean=tensor([71.2425], device='cuda:0'),std=tensor([9.5208], device='cuda:0'),eps=1e-08)
#   (2): EegNormalizeMeanStd(mean=tensor([ 0.0028, -0.0010,  0.0298, -0.0466,  0.0128,  0.0051,  0.0013,  0.0241,
#            0.0318,  0.0792, -0.0018, -0.0584, -0.0023, -0.0028, -0.0633,  0.0025,
#           -0.0098, -0.0146, -0.0089, -0.0087, -0.0238], device='cuda:0'),std=tensor([45.2164, 20.5746, 11.9914, 12.0090, 15.9611, 48.1300, 19.7673, 10.7314,
#           12.1005, 15.9640, 20.8918, 14.7044, 13.7871, 22.1414, 17.0930, 15.1118,
#           19.7852, 11.6805, 11.7411, 93.8681, 67.9464], device='cuda:0'),eps=1e-08)
#   (3): EegSpectrogram(n_fft=126, complex_mode=as_real, stft_kwargs={'hop_length': 32})
#   (4): EegNormalizeMeanStd(mean=tensor([[-2.1496e-01, -8.7354e-04,  4.8975e-04,  ..., -3.1819e-04,
#            -2.1303e-04, -3.7861e-03],
#           [-4.7282e-01, -2.2404e-03,  1.1111e-04,  ..., -3.1677e-04,
#            -4.3632e-04, -1.7214e-04],
#           [-6.3409e-02, -1.4108e-04,  4.7933e-04,  ..., -2.4975e-04,
#            -3.7778e-04, -3.0055e-04],
#           ...,
#           [ 0.0000e+00, -2.9380e-02, -1.6152e-02,  ...,  1.4978e-04,
#             2.7503e-04,  6.6624e-11],
#           [ 0.0000e+00, -7.4667e-03, -4.3477e-03,  ...,  2.6514e-05,
#             3.1519e-05,  7.1429e-11],
#           [ 0.0000e+00,  2.4762e-03,  8.8599e-04,  ..., -1.3978e-04,
#            -2.4603e-04, -8.0052e-10]], device='cuda:0'),std=tensor([[1.0779e+02, 1.6150e+01, 7.8273e+00,  ..., 7.4963e-01, 7.5170e-01,
#            9.0339e-01],
#           [1.0471e+02, 1.4138e+01, 7.5084e+00,  ..., 7.5805e-01, 7.5919e-01,
#            9.1282e-01],
#           [9.8399e+01, 1.2324e+01, 7.6630e+00,  ..., 7.8122e-01, 7.8132e-01,
#            9.4885e-01],
#           ...,
#           [0.0000e+00, 2.2367e+01, 1.2621e+01,  ..., 5.6646e-01, 5.7179e-01,
#            8.8156e-08],
#           [0.0000e+00, 1.8967e+01, 2.1875e+01,  ..., 5.1955e-01, 5.2303e-01,
#            1.6805e-07],
#           [0.0000e+00, 5.0620e+00, 5.1320e+00,  ..., 5.9967e-01, 5.9966e-01,
#            4.6605e-07]], device='cuda:0'),eps=1e-08)
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=cuda)
#   (1): EegNormalizeAge(mean=tensor([71.2425], device='cuda:0'),std=tensor([9.5208], device='cuda:0'),eps=1e-08)
#   (2): EegAddGaussianNoiseAge(mean=0.0,std=0.0626811693876168)
#   (3): EegNormalizeMeanStd(mean=tensor([ 0.0028, -0.0010,  0.0298, -0.0466,  0.0128,  0.0051,  0.0013,  0.0241,
#            0.0318,  0.0792, -0.0018, -0.0584, -0.0023, -0.0028, -0.0633,  0.0025,
#           -0.0098, -0.0146, -0.0089, -0.0087, -0.0238], device='cuda:0'),std=tensor([45.2164, 20.5746, 11.9914, 12.0090, 15.9611, 48.1300, 19.7673, 10.7314,
#           12.1005, 15.9640, 20.8918, 14.7044, 13.7871, 22.1414, 17.0930, 15.1118,
#           19.7852, 11.6805, 11.7411, 93.8681, 67.9464], device='cuda:0'),eps=1e-08)
#   (4): EegMultiplicativeGaussianNoise(mean=0.0,std=0.06347426794981546)
#   (5): EegAdditiveGaussianNoise(mean=0.0,std=0.014560543566041024)
#   (6): EegSpectrogram(n_fft=126, complex_mode=as_real, stft_kwargs={'hop_length': 32})
#   (7): EegNormalizeMeanStd(mean=tensor([[-2.1496e-01, -8.7354e-04,  4.8975e-04,  ..., -3.1819e-04,
#            -2.1303e-04, -3.7861e-03],
#           [-4.7282e-01, -2.2404e-03,  1.1111e-04,  ..., -3.1677e-04,
#            -4.3632e-04, -1.7214e-04],
#           [-6.3409e-02, -1.4108e-04,  4.7933e-04,  ..., -2.4975e-04,
#            -3.7778e-04, -3.0055e-04],
#           ...,
#           [ 0.0000e+00, -2.9380e-02, -1.6152e-02,  ...,  1.4978e-04,
#             2.7503e-04,  6.6624e-11],
#           [ 0.0000e+00, -7.4667e-03, -4.3477e-03,  ...,  2.6514e-05,
#             3.1519e-05,  7.1429e-11],
#           [ 0.0000e+00,  2.4762e-03,  8.8599e-04,  ..., -1.3978e-04,
#            -2.4603e-04, -8.0052e-10]], device='cuda:0'),std=tensor([[1.0779e+02, 1.6150e+01, 7.8273e+00,  ..., 7.4963e-01, 7.5170e-01,
#            9.0339e-01],
#           [1.0471e+02, 1.4138e+01, 7.5084e+00,  ..., 7.5805e-01, 7.5919e-01,
#            9.1282e-01],
#           [9.8399e+01, 1.2324e+01, 7.6630e+00,  ..., 7.8122e-01, 7.8132e-01,
#            9.4885e-01],
#           ...,
#           [0.0000e+00, 2.2367e+01, 1.2621e+01,  ..., 5.6646e-01, 5.7179e-01,
#            8.8156e-08],
#           [0.0000e+00, 1.8967e+01, 2.1875e+01,  ..., 5.1955e-01, 5.2303e-01,
#            1.6805e-07],
#           [0.0000e+00, 5.0620e+00, 5.1320e+00,  ..., 5.9967e-01, 5.9966e-01,
#            4.6605e-07]], device='cuda:0'),eps=1e-08)
# ),
#  'run_mode': 'train',
#  'save_model': True,
#  'search_lr': True,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_len_2d': (64, 63),
#  'seq_length': 2000,
#  'signal_2d_mean': tensor([[[[-2.1496e-01],
#           [-8.7354e-04],
#           [ 4.8975e-04],
#           ...,
#           [-3.1819e-04],
#           [-2.1303e-04],
#           [-3.7861e-03]],
#
#          [[-4.7282e-01],
#           [-2.2404e-03],
#           [ 1.1111e-04],
#           ...,
#           [-3.1677e-04],
#           [-4.3632e-04],
#           [-1.7214e-04]],
#
#          [[-6.3409e-02],
#           [-1.4108e-04],
#           [ 4.7933e-04],
#           ...,
#           [-2.4975e-04],
#           [-3.7778e-04],
#           [-3.0055e-04]],
#
#          ...,
#
#          [[ 0.0000e+00],
#           [-2.9380e-02],
#           [-1.6152e-02],
#           ...,
#           [ 1.4978e-04],
#           [ 2.7503e-04],
#           [ 6.6624e-11]],
#
#          [[ 0.0000e+00],
#           [-7.4667e-03],
#           [-4.3477e-03],
#           ...,
#           [ 2.6514e-05],
#           [ 3.1519e-05],
#           [ 7.1429e-11]],
#
#          [[ 0.0000e+00],
#           [ 2.4762e-03],
#           [ 8.8599e-04],
#           ...,
#           [-1.3978e-04],
#           [-2.4603e-04],
#           [-8.0052e-10]]]], device='cuda:0'),
#  'signal_2d_std': tensor([[[[1.0779e+02],
#           [1.6150e+01],
#           [7.8273e+00],
#           ...,
#           [7.4963e-01],
#           [7.5170e-01],
#           [9.0339e-01]],
#
#          [[1.0471e+02],
#           [1.4138e+01],
#           [7.5084e+00],
#           ...,
#           [7.5805e-01],
#           [7.5919e-01],
#           [9.1282e-01]],
#
#          [[9.8399e+01],
#           [1.2324e+01],
#           [7.6630e+00],
#           ...,
#           [7.8122e-01],
#           [7.8132e-01],
#           [9.4885e-01]],
#
#          ...,
#
#          [[0.0000e+00],
#           [2.2367e+01],
#           [1.2621e+01],
#           ...,
#           [5.6646e-01],
#           [5.7179e-01],
#           [8.8156e-08]],
#
#          [[0.0000e+00],
#           [1.8967e+01],
#           [2.1875e+01],
#           ...,
#           [5.1955e-01],
#           [5.2303e-01],
#           [1.6805e-07]],
#
#          [[0.0000e+00],
#           [5.0620e+00],
#           [5.1320e+00],
#           ...,
#           [5.9967e-01],
#           [5.9966e-01],
#           [4.6605e-07]]]], device='cuda:0'),
#  'signal_header': ['Fp1-AVG', 'F3-AVG', 'C3-AVG', 'P3-AVG', 'O1-AVG', 'Fp2-AVG', 'F4-AVG', 'C4-AVG', 'P4-AVG', 'O2-AVG', 'F7-AVG', 'T3-AVG', 'T5-AVG', 'F8-AVG', 'T4-AVG', 'T6-AVG', 'FZ-AVG', 'CZ-AVG', 'PZ-AVG', 'EKG', 'Photic'],
#  'signal_length_limit': 10000000,
#  'signal_mean': tensor([[[ 0.0028],
#          [-0.0010],
#          [ 0.0298],
#          [-0.0466],
#          [ 0.0128],
#          [ 0.0051],
#          [ 0.0013],
#          [ 0.0241],
#          [ 0.0318],
#          [ 0.0792],
#          [-0.0018],
#          [-0.0584],
#          [-0.0023],
#          [-0.0028],
#          [-0.0633],
#          [ 0.0025],
#          [-0.0098],
#          [-0.0146],
#          [-0.0089],
#          [-0.0087],
#          [-0.0238]]], device='cuda:0'),
#  'signal_std': tensor([[[45.2164],
#          [20.5746],
#          [11.9914],
#          [12.0090],
#          [15.9611],
#          [48.1300],
#          [19.7673],
#          [10.7314],
#          [12.1005],
#          [15.9640],
#          [20.8918],
#          [14.7044],
#          [13.7871],
#          [22.1414],
#          [17.0930],
#          [15.1118],
#          [19.7852],
#          [11.6805],
#          [11.7411],
#          [93.8681],
#          [67.9464]]], device='cuda:0'),
#  'stft_params': {'hop_length': 32, 'n_fft': 126},
#  'task': 'task2',
#  'task_description': 'Classification of [Normal], [MCI], and [Dementia] symptoms.',
#  'task_name': 'CAUEEG-Dementia benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 100000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=2000, length_limit=10000000, multiple=4, latency=2000, return_timing=False)
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=2000, length_limit=10000000, multiple=8, latency=2000, return_timing=False)
#     EegToTensor()
# ),
#  'use_age': 'conv',
#  'use_wandb': True,
#  'warmup_min': 3000,
#  'warmup_ratio': 0.05,
#  'warmup_steps': 39062,
#  'watch_model': False,
#  'weight_decay': 0.047077275853309494,
#  'width_per_group': 4}

# %% [markdown]
# -----
#
# ## Load the target model

# %%
# model = config['generator'](**config).to(device)
model = hydra.utils.instantiate(config).to(device)

if config.get('ddp', False):
    model_state_ddp = deepcopy(model_state)
    model_state = OrderedDict()
    for k, v in model_state_ddp.items():
        name = k[7:] # remove 'module.' of DataParallel/DistributedDataParallel
        model_state[name] = v
        
model.load_state_dict(model_state)
# Out:
# <All keys matched successfully>

# %% [markdown]
# -----
#
# ## Evaluate the model and analyze the performance by the crop timing

# %% [markdown]
# ### Configurations

# %%
config = ckpt['config']

config.pop('cwd', 0)
config['ddp'] = False
config['crop_timing_analysis'] = True
config['eval'] = True
config['device'] = device

# config['seq_length'] = 16000 # TODO
# config['test_crop_multiple'] = 32 # TODO

repeat = round(16 / config['crop_multiple'])  # 500
print(repeat)
# Out:
# 4

# %% [markdown]
# ### Build Dataset

# %%
train_loader, val_loader, test_loader, multicrop_test_loader = build_dataset_for_train(config, verbose=True)
# Out:
# transform: Compose(
#     EegRandomCrop(crop_length=2000, length_limit=10000000, multiple=4, latency=2000, return_timing=True)
#     EegToTensor()
# )
#
# ----------------------------------------------------------------------------------------------------
#
# transform_multicrop: Compose(
#     EegRandomCrop(crop_length=2000, length_limit=10000000, multiple=8, latency=2000, return_timing=True)
#     EegToTensor()
# )
#
# ----------------------------------------------------------------------------------------------------
#
#
# task config:
# {'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'task_description': 'Classification of [Normal], [MCI], and [Dementia] '
#                      'symptoms.',
#  'task_name': 'CAUEEG-Dementia benchmark'}
#
#  ----------------------------------------------------------------------------------------------------
#
# train_dataset[0].keys():
# dict_keys(['serial', 'age', 'symptom', 'class_name', 'class_label', 'signal', 'crop_timing'])
# train signal shape: torch.Size([21, 2000])
#
#
# ----------------------------------------------------------------------------------------------------
#
# val_dataset[0].keys():
# dict_keys(['serial', 'age', 'symptom', 'class_name', 'class_label', 'signal', 'crop_timing'])
#
# ----------------------------------------------------------------------------------------------------
#
# test_dataset[0].keys():
# dict_keys(['serial', 'age', 'symptom', 'class_name', 'class_label', 'signal', 'crop_timing'])
#
# ----------------------------------------------------------------------------------------------------
#
# test_dataset[0].keys():
# dict_keys(['serial', 'age', 'symptom', 'class_name', 'class_label', 'signal', 'crop_timing'])
# test signal shape: torch.Size([21, 2000])
#
# ----------------------------------------------------------------------------------------------------
#
# preprocess_train: Sequential(
#   (0): EegToDevice(device=cuda)
#   (1): EegNormalizeAge(mean=tensor([71.2425], device='cuda:0'),std=tensor([9.5208], device='cuda:0'),eps=1e-08)
#   (2): EegAddGaussianNoiseAge(mean=0.0,std=0.0626811693876168)
#   (3): EegNormalizeMeanStd(mean=tensor([ 0.0028, -0.0010,  0.0298, -0.0466,  0.0128,  0.0051,  0.0013,  0.0241,
#            0.0318,  0.0792, -0.0018, -0.0584, -0.0023, -0.0028, -0.0633,  0.0025,
#           -0.0098, -0.0146, -0.0089, -0.0087, -0.0238], device='cuda:0'),std=tensor([45.2164, 20.5746, 11.9914, 12.0090, 15.9611, 48.1300, 19.7673, 10.7314,
#           12.1005, 15.9640, 20.8918, 14.7044, 13.7871, 22.1414, 17.0930, 15.1118,
#           19.7852, 11.6805, 11.7411, 93.8681, 67.9464], device='cuda:0'),eps=1e-08)
#   (4): EegMultiplicativeGaussianNoise(mean=0.0,std=0.06347426794981546)
#   (5): EegAdditiveGaussianNoise(mean=0.0,std=0.014560543566041024)
#   (6): EegSpectrogram(n_fft=126, complex_mode=as_real, stft_kwargs={'hop_length': 32})
#   (7): EegNormalizeMeanStd(mean=tensor([[-2.1496e-01, -8.7354e-04,  4.8975e-04,  ..., -3.1819e-04,
#            -2.1303e-04, -3.7861e-03],
#           [-4.7282e-01, -2.2404e-03,  1.1111e-04,  ..., -3.1677e-04,
#            -4.3632e-04, -1.7214e-04],
#           [-6.3409e-02, -1.4108e-04,  4.7933e-04,  ..., -2.4975e-04,
#            -3.7778e-04, -3.0055e-04],
#           ...,
#           [ 0.0000e+00, -2.9380e-02, -1.6152e-02,  ...,  1.4978e-04,
#             2.7503e-04,  6.6624e-11],
#           [ 0.0000e+00, -7.4667e-03, -4.3477e-03,  ...,  2.6514e-05,
#             3.1519e-05,  7.1429e-11],
#           [ 0.0000e+00,  2.4762e-03,  8.8599e-04,  ..., -1.3978e-04,
#            -2.4603e-04, -8.0052e-10]], device='cuda:0'),std=tensor([[1.0779e+02, 1.6150e+01, 7.8273e+00,  ..., 7.4963e-01, 7.5170e-01,
#            9.0339e-01],
#           [1.0471e+02, 1.4138e+01, 7.5084e+00,  ..., 7.5805e-01, 7.5919e-01,
#            9.1282e-01],
#           [9.8399e+01, 1.2324e+01, 7.6630e+00,  ..., 7.8122e-01, 7.8132e-01,
#            9.4885e-01],
#           ...,
#           [0.0000e+00, 2.2367e+01, 1.2621e+01,  ..., 5.6646e-01, 5.7179e-01,
#            8.8156e-08],
#           [0.0000e+00, 1.8967e+01, 2.1875e+01,  ..., 5.1955e-01, 5.2303e-01,
#            1.6805e-07],
#           [0.0000e+00, 5.0620e+00, 5.1320e+00,  ..., 5.9967e-01, 5.9966e-01,
#            4.6605e-07]], device='cuda:0'),eps=1e-08)
# )
#
# ----------------------------------------------------------------------------------------------------
#
# preprocess_test: Sequential(
#   (0): EegToDevice(device=cuda)
#   (1): EegNormalizeAge(mean=tensor([71.2425], device='cuda:0'),std=tensor([9.5208], device='cuda:0'),eps=1e-08)
#   (2): EegNormalizeMeanStd(mean=tensor([ 0.0028, -0.0010,  0.0298, -0.0466,  0.0128,  0.0051,  0.0013,  0.0241,
#            0.0318,  0.0792, -0.0018, -0.0584, -0.0023, -0.0028, -0.0633,  0.0025,
#           -0.0098, -0.0146, -0.0089, -0.0087, -0.0238], device='cuda:0'),std=tensor([45.2164, 20.5746, 11.9914, 12.0090, 15.9611, 48.1300, 19.7673, 10.7314,
#           12.1005, 15.9640, 20.8918, 14.7044, 13.7871, 22.1414, 17.0930, 15.1118,
#           19.7852, 11.6805, 11.7411, 93.8681, 67.9464], device='cuda:0'),eps=1e-08)
#   (3): EegSpectrogram(n_fft=126, complex_mode=as_real, stft_kwargs={'hop_length': 32})
#   (4): EegNormalizeMeanStd(mean=tensor([[-2.1496e-01, -8.7354e-04,  4.8975e-04,  ..., -3.1819e-04,
#            -2.1303e-04, -3.7861e-03],
#           [-4.7282e-01, -2.2404e-03,  1.1111e-04,  ..., -3.1677e-04,
#            -4.3632e-04, -1.7214e-04],
#           [-6.3409e-02, -1.4108e-04,  4.7933e-04,  ..., -2.4975e-04,
#            -3.7778e-04, -3.0055e-04],
#           ...,
#           [ 0.0000e+00, -2.9380e-02, -1.6152e-02,  ...,  1.4978e-04,
#             2.7503e-04,  6.6624e-11],
#           [ 0.0000e+00, -7.4667e-03, -4.3477e-03,  ...,  2.6514e-05,
#             3.1519e-05,  7.1429e-11],
#           [ 0.0000e+00,  2.4762e-03,  8.8599e-04,  ..., -1.3978e-04,
#            -2.4603e-04, -8.0052e-10]], device='cuda:0'),std=tensor([[1.0779e+02, 1.6150e+01, 7.8273e+00,  ..., 7.4963e-01, 7.5170e-01,
#            9.0339e-01],
#           [1.0471e+02, 1.4138e+01, 7.5084e+00,  ..., 7.5805e-01, 7.5919e-01,
#            9.1282e-01],
#           [9.8399e+01, 1.2324e+01, 7.6630e+00,  ..., 7.8122e-01, 7.8132e-01,
#            9.4885e-01],
#           ...,
#           [0.0000e+00, 2.2367e+01, 1.2621e+01,  ..., 5.6646e-01, 5.7179e-01,
#            8.8156e-08],
#           [0.0000e+00, 1.8967e+01, 2.1875e+01,  ..., 5.1955e-01, 5.2303e-01,
#            1.6805e-07],
#           [0.0000e+00, 5.0620e+00, 5.1320e+00,  ..., 5.9967e-01, 5.9966e-01,
#            4.6605e-07]], device='cuda:0'),eps=1e-08)
# )
#
# ----------------------------------------------------------------------------------------------------
#
# 0 torch.Size([128, 42, 64, 63]) torch.Size([128]) torch.Size([128])
# 1 torch.Size([128, 42, 64, 63]) torch.Size([128]) torch.Size([128])
# 2 torch.Size([128, 42, 64, 63]) torch.Size([128]) torch.Size([128])
# 3 torch.Size([128, 42, 64, 63]) torch.Size([128]) torch.Size([128])
# 4 torch.Size([128, 42, 64, 63]) torch.Size([128]) torch.Size([128])
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Train set

# %%
_ = check_accuracy_extended_debug(model, train_loader, 
                                  config['preprocess_test'], config, repeat=repeat)
train_acc = _[0] 
train_score = _[1]
train_target = _[2]
train_confusion = _[3]
train_error_table = _[4]
train_crop_timing = _[5]

print(train_acc)
# Out:
# 99.97979525862068

# %%
draw_roc_curve(train_score, train_target, config['class_label_to_name'], use_wandb=False)
draw_confusion(train_confusion, config['class_label_to_name'], use_wandb=False)
draw_error_table(train_error_table, use_wandb=False, fig_size=(60.0, 4.0))

# %% [markdown]
# ### Validation set

# %%
_ = check_accuracy_extended_debug(model, val_loader, 
                                  config['preprocess_test'], config, repeat=repeat)
val_acc = _[0]
val_score = _[1]
val_target = _[2]
val_confusion = _[3]
val_error_table = _[4]
val_crop_timing = _[5]

print(val_acc)
# Out:
# 60.871848739495796

# %%
draw_roc_curve(val_score, val_target, config['class_label_to_name'], use_wandb=False)
draw_confusion(val_confusion, config['class_label_to_name'], use_wandb=False)
draw_error_table(val_error_table, use_wandb=False)

# %% [markdown]
# ### Test set

# %%
_ = check_accuracy_extended_debug(model, test_loader, 
                                  config['preprocess_test'], config, repeat=repeat)
test_acc = _[0]
test_score = _[1]
test_target = _[2]
test_confusion = _[3]
test_error_table = _[4]
test_crop_timing = _[5]

print(test_acc)
# Out:
# 61.38771186440678

# %%
draw_roc_curve(test_score, test_target, config['class_label_to_name'], use_wandb=False)
draw_confusion(test_confusion, config['class_label_to_name'], use_wandb=False)
draw_class_wise_metrics(test_confusion, config['class_label_to_name'], use_wandb=False)
draw_error_table(test_error_table, use_wandb=False)

# %%
_ = check_accuracy_extended_debug(model, test_loader, 
                                  config['preprocess_test'], config, repeat=repeat)
test_acc = _[0]
test_score = _[1]
test_target = _[2]
test_confusion = _[3]
test_error_table = _[4]

print(test_acc)
# Out:
# 62.02330508474576

# %% [markdown]
# ### Test set (with test-time augmentation)

# %%
_ = check_accuracy_multicrop_extended(model, multicrop_test_loader, 
                                      config['preprocess_test'], config, repeat=repeat)
multi_test_acc = _[0]
multi_test_score = _[1]
multi_test_target = _[2]
multi_test_confusion = _[3]

print(multi_test_acc)
# Out:
# 65.67796610169492

# %%
draw_roc_curve(multi_test_score, multi_test_target, config['class_label_to_name'], use_wandb=False)
draw_confusion(multi_test_confusion, config['class_label_to_name'], use_wandb=False)
draw_class_wise_metrics(multi_test_confusion, config['class_label_to_name'], use_wandb=False)

# %% [markdown]
# ### Examine whether the model has a bias related to the cropping starting time

# %%
train_pos = []
train_neg = []

for k, v in train_crop_timing.items():
    for i in range(v.get('correct', 0)):
        train_pos.append(k)
    for i in range(v.get('incorrect', 0)):
        train_neg.append(k)

##

val_pos = []
val_neg = []

for k, v in val_crop_timing.items():
    for i in range(v.get('correct', 0)):
        val_pos.append(k)
    for i in range(v.get('incorrect', 0)):
        val_neg.append(k)

##

test_pos = []
test_neg = []

for k, v in test_crop_timing.items():
    for i in range(v.get('correct', 0)):
        test_pos.append(k)
    for i in range(v.get('incorrect', 0)):
        test_neg.append(k)

# %%
fig = plt.figure(num=1, clear=True, figsize=(16, 10), constrained_layout=True)
n_bins = 50
density = False

ax = fig.add_subplot(3, 1, 1)
ax.hist(train_pos, bins=n_bins, color='g', alpha=0.7, density=density)
ax.hist(train_neg, bins=n_bins, color='r', alpha=0.7, density=density)
ax.set_title(f'Training Set: True/Neg Historgram by Random Crop Time')
ax.set_xlabel('Random Crop Time')
ax.set_ylabel('Count')

ax = fig.add_subplot(3, 1, 2)
ax.hist(val_pos, bins=n_bins, color='g', alpha=0.7, density=density)
ax.hist(val_neg, bins=n_bins, color='r', alpha=0.7, density=density)
ax.set_title(f'Validation Set: True/Neg Historgram by Random Crop Time')
ax.set_xlabel('Random Crop Time')
ax.set_ylabel('Count')

ax = fig.add_subplot(3, 1, 3)
ax.hist(test_pos, bins=n_bins, color='g', alpha=0.7, density=density)
ax.hist(test_neg, bins=n_bins, color='r', alpha=0.7, density=density)
ax.set_title(f'Test Set: True/Neg Historgram by Random Crop Time')
ax.set_xlabel('Random Crop Time')
ax.set_ylabel('Count')

plt.show()
fig.clear()
plt.close(fig)

# %% [markdown]
# -----
#
# ## Evaluate the model with length limit

# %% [markdown]
# ### Configurations

# %%
config = ckpt['config']

config['crop_timing_analysis'] = False
config['signal_length_limit'] = 200 * 60 * 4  # 7 minutes
config['eval'] = True
config['device'] = device

repeat = round(50 / config['crop_multiple'])

train_loader, val_loader, test_loader, multi_test_loader = build_dataset_for_train(config, verbose=False)

# %%
# train
train_acc = check_accuracy(model, train_loader, 
                           config['preprocess_test'], config, repeat=repeat)
val_acc = check_accuracy(model, val_loader, 
                         config['preprocess_test'], config, repeat=repeat)
test_acc = check_accuracy(model, test_loader, 
                          config['preprocess_test'], config, repeat=repeat)
multi_test_acc = check_accuracy_multicrop(model, multi_test_loader, 
                                          config['preprocess_test'], config, repeat=repeat)

print(train_acc, val_acc, test_acc, multi_test_acc)
# Out:
# 99.99551005747126 60.871848739495796 62.800141242937855 67.090395480226
