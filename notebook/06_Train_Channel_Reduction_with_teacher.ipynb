# %% [markdown]
# # Train Channel Reduction
#
# - Train deep classifiers for the EEG-based diagnostic classification with channel reduction.
#     - CAUEEG-Dementia benchmark: Classification of **Normal**, **MCI**, and **Dementia** symptoms
#     - CAUEEG-Abnormal benchmark: Classification of **Normal** and **Abnormal** symptoms

# %% [markdown]
# -----
#
# ## Load Packages

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# C:\Users\Minjae\Desktop\EEG_Project

# %%
# Load some packages
import hydra
from omegaconf import OmegaConf
import wandb
import pprint
from copy import deepcopy
import itertools
from tqdm.auto import tqdm

# custom package
from run_train import check_device_env
from run_train import prepare_and_run_train

# %% [markdown]
# ---
#
# ## Specify the dataset, model, and train setting

# %%
script = "train=distillation-score train.distil_teacher_score=local/ensemble-dementia-class-score.pt data.EKG=O data.awgn=0.0479404157791391 data.awgn_age=0.031086177931273194 data.mgn=0.003676528367854981 data.photic=X data.seq_length=4000 model=2D-VGG-19 model.activation=gelu model.dropout=0.20149124331753415 model.fc_stages=2 model.use_age=conv train.criterion=multi-bce train.lr_scheduler_type=cosine_decay_with_warmup_half train.mixup=0.3 train.weight_decay=0.012528558998673434 data=caueeg-dementia train.base_lr=0.001 train.search_lr=False"
print(script)
# Out:
# train=distillation-score train.distil_teacher_score=local/ensemble-dementia-class-score.pt data.EKG=O data.awgn=0.0479404157791391 data.awgn_age=0.031086177931273194 data.mgn=0.003676528367854981 data.photic=X data.seq_length=4000 model=2D-VGG-19 model.activation=gelu model.dropout=0.20149124331753415 model.fc_stages=2 model.use_age=conv train.criterion=multi-bce train.lr_scheduler_type=cosine_decay_with_warmup_half train.mixup=0.3 train.weight_decay=0.012528558998673434 data=caueeg-dementia train.base_lr=0.001 train.search_lr=False

# %%
add_configs_base = []

for seg in script.split(" "):
    if 'train.project' in seg:
        continue
    elif "." in seg and "++" not in seg:
        seg = "++" + seg
    add_configs_base.append(seg)

add_configs_base.append("++model.base_model=2s1700lg")
add_configs_base.append("++train.project=caueeg-dementia-channel-reduction")
add_configs_base.append("++train.device=cuda:0")
add_configs_base.append("++train.total_samples=1.0e+7")

pprint.pprint(add_configs_base)
# Out:
# ['train=distillation-score',
#  '++train.distil_teacher_score=local/ensemble-dementia-class-score.pt',
#  '++data.EKG=O',
#  '++data.awgn=0.0479404157791391',
#  '++data.awgn_age=0.031086177931273194',
#  '++data.mgn=0.003676528367854981',
#  '++data.photic=X',
#  '++data.seq_length=4000',
#  'model=2D-VGG-19',
#  '++model.activation=gelu',
#  '++model.dropout=0.20149124331753415',
#  '++model.fc_stages=2',
#  '++model.use_age=conv',
#  '++train.criterion=multi-bce',
#  '++train.lr_scheduler_type=cosine_decay_with_warmup_half',
#  '++train.mixup=0.3',
#  '++train.weight_decay=0.012528558998673434',
#  'data=caueeg-dementia',
#  '++train.base_lr=0.001',
#  '++train.search_lr=False',
#  '++model.base_model=2s1700lg',
#  '++train.project=caueeg-dementia-channel-reduction',
#  '++train.device=cuda:0',
#  '++train.total_samples=1.0e+7']

# %% [markdown]
# ---
#
# ## Initializing configurations using Hydra and Train

# %%
signal_header = ["Fp1-AVG", "F3-AVG", "C3-AVG", "P3-AVG", "O1-AVG",
                 "Fp2-AVG", "F4-AVG", "C4-AVG", "P4-AVG", "O2-AVG", 
                 "F7-AVG", "T3-AVG", "T5-AVG","F8-AVG", "T4-AVG", 
                 "T6-AVG", "FZ-AVG", "CZ-AVG", "PZ-AVG", "EKG", "Photic"]

# %%
# channel_nums = range(19)
# for channel_reduction_list in tqdm(list(itertools.combinations(channel_nums, 18))):
#     add_configs = deepcopy(add_configs_base)

#     with hydra.initialize(config_path="../config"):
#         cfg = hydra.compose(config_name="default", overrides=add_configs)

#     config = {
#         **OmegaConf.to_container(cfg.data),
#         **OmegaConf.to_container(cfg.train),
#         **OmegaConf.to_container(cfg.model),
#     }
#     config['channel_reduction_list'] = [*channel_reduction_list]
#     config['EKG'] = "X"
#     config['photic'] = "X"
#     config['channel_survive'] = [signal_header[i] for i in channel_nums if i not in channel_reduction_list]
    

#     check_device_env(config)
#     # pprint.pprint(config)
#     prepare_and_run_train(rank=None, world_size=None, config=config)

# %%
# channel_nums = range(19)
# for channel_difference in tqdm(list(itertools.combinations(channel_nums, 2))):
#     add_configs = deepcopy(add_configs_base)

#     with hydra.initialize(config_path="../config"):
#         cfg = hydra.compose(config_name="default", overrides=add_configs)

#     config = {
#         **OmegaConf.to_container(cfg.data),
#         **OmegaConf.to_container(cfg.train),
#         **OmegaConf.to_container(cfg.model),
#     }
#     config['channel_difference'] = [*channel_difference]
#     config['EKG'] = "X"
#     config['photic'] = "X"
#     config['montage'] = ' - '.join([signal_header[i].split('-')[0] for i in channel_difference])
#     config['device'] = 'cuda:3'

#     check_device_env(config)
#     # pprint.pprint(config)
#     prepare_and_run_train(rank=None, world_size=None, config=config)

# %%
channel_difference = [6, 15]
add_configs = deepcopy(add_configs_base)

with hydra.initialize(config_path="../config"):
    cfg = hydra.compose(config_name="default", overrides=add_configs)

config = {
    **OmegaConf.to_container(cfg.data),
    **OmegaConf.to_container(cfg.train),
    **OmegaConf.to_container(cfg.model),
}
config['channel_difference'] = [*channel_difference]
config['EKG'] = "X"
config['photic'] = "X"
config['montage'] = ' - '.join([signal_header[i].split('-')[0] for i in channel_difference])
config['device'] = 'cuda:0'

check_device_env(config)
# pprint.pprint(config)
prepare_and_run_train(rank=None, world_size=None, config=config)
# Out:
# ******************************    Configurations for Train    ******************************
#
# {'EKG': 'X',
#  '_target_': 'models.vgg_2d.VGG2D',
#  'activation': 'gelu',
#  'age_mean': tensor([71.1417]),
#  'age_std': tensor([9.7264]),
#  'awgn': 0.0479404157791391,
#  'awgn_age': 0.031086177931273194,
#  'base_lr': 0.001,
#  'base_model': '2s1700lg',
#  'batch_norm': True,
#  'channel_difference': [6, 15],
#  'class_label_to_name': ['Normal', 'MCI', 'Dementia'],
#  'class_name_to_label': {'Dementia': 2, 'MCI': 1, 'Normal': 0},
#  'criterion': 'multi-bce',
#  'crop_multiple': 4,
#  'crop_timing_analysis': False,
#  'dataset_name': 'CAUEEG dataset',
#  'dataset_path': 'local/dataset/caueeg-dataset/',
#  'ddp': False,
#  'device': device(type='cuda', index=0),
#  'distil_alpha': 1.0,
#  'distil_tau': 1.0,
#  'distil_teacher': 'score',
#  'distil_teacher_score': tensor([[ 0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000],
#         [ 4.4546, -2.6231, -3.3622],
#         ...,
#         [-1.7782, -2.1832,  3.3826],
#         [-2.4056, -1.8465,  3.2377],
#         [-2.3053, -1.8745,  3.5382]], device='cuda:0'),
#  'distil_type': 'soft',
#  'draw_result': True,
#  'dropout': 0.20149124331753415,
#  'fc_stages': 2,
#  'file_format': 'memmap',
#  'in_channels': 2,
#  'input_norm': 'dataset',
#  'latency': 2000,
#  'load_event': False,
#  'lr_scheduler_type': 'cosine_decay_with_warmup_half',
#  'mgn': 0.003676528367854981,
#  'minibatch': 256,
#  'minibatch_3090': 256,
#  'mixup': 0.3,
#  'model': '2D-VGG-19',
#  'montage': 'F4 - T6',
#  'multi_batch_size': 32,
#  'num_history': 500,
#  'num_params': 20162243,
#  'out_dims': 3,
#  'output_length': 5,
#  'photic': 'X',
#  'preprocess_test': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=0))
#   (1): EegNormalizeAge(mean=tensor([71.1417]), std=tensor([9.7264]), eps=1e-08, std_eps=tensor([9.7264]))
#   (2): EegNormalizeMeanStd(mean=tensor([[[0.0502]]]), std=tensor([[[30.3874]]]), eps=1e-08, std_eps=tensor([[[30.3874]]]))
#   (3): EegSpectrogram(n_fft=179, complex_mode='as_real', stft_kwargs={'hop_length': 45})
#   (4): EegNormalizeMeanStd(mean=tensor([[[[-4.6854e-01],
#             [-2.9285e-03],
#             [-1.8059e-03],
#             [ 1.9164e-03],
#             [-1.3249e-02],
#             [ 5.3307e-04],
#             [ 1.5989e-04],
#             [ 1.5888e-03],
#             [-2.1761e-02],
#             [-4.9173e-03],
#             [-2.0585e-03],
#             [-2.6960e-03],
#             [ 1.2655e-02],
#             [ 1.2907e-03],
#             [-1.0924e-03],
#             [-1.0661e-03],
#             [ 5.2922e-03],
#             [-1.9977e-04],
#             [-6.5483e-04],
#             [-9.4698e-04],
#             [ 3.5059e-03],
#             [-5.5977e-04],
#             [-4.1707e-04],
#             [-7.8730e-04],
#             [ 1.5696e-03],
#             [-3.1200e-04],
#             [-4.5329e-04],
#             [-2.3344e-04],
#             [ 6.0557e-05],
#             [-2.3415e-04],
#             [-7.4846e-05],
#             [ 7.9993e-04],
#             [-5.9483e-03],
#             [-1.7851e-03],
#             [-1.4063e-03],
#             [-1.2721e-03],
#             [ 1.6052e-03],
#             [-4.0195e-04],
#             [-3.7079e-04],
#             [-6.1911e-04],
#             [-1.3828e-03],
#             [-9.0136e-04],
#             [-9.4556e-04],
#             [-2.3298e-04],
#             [ 9.2243e-04],
#             [-2.3543e-04],
#             [-1.9445e-04],
#             [ 5.3912e-04],
#             [-2.3439e-03],
#             [-1.1274e-03],
#             [-9.6116e-04],
#             [-9.7787e-04],
#             [-9.1182e-04],
#             [-8.3417e-04],
#             [-9.6220e-04],
#             [-1.1801e-03],
#             [ 1.8223e-04],
#             [-7.2040e-04],
#             [-8.9891e-04],
#             [-1.4540e-03],
#             [ 9.8739e-04],
#             [-2.9185e-04],
#             [-6.3093e-04],
#             [-1.2649e-03],
#             [ 7.0902e-04],
#             [-3.5998e-04],
#             [-6.2454e-04],
#             [-1.1828e-03],
#             [ 1.1685e-03],
#             [ 2.9734e-05],
#             [-2.0702e-04],
#             [-5.8995e-04],
#             [ 2.6587e-04],
#             [-1.7404e-04],
#             [-1.2760e-04],
#             [-4.5901e-05],
#             [-8.9414e-04],
#             [-5.4469e-04],
#             [-5.2700e-04],
#             [-4.4598e-04],
#             [-3.0201e-04],
#             [-3.8129e-04],
#             [-5.0657e-04],
#             [-3.0813e-04],
#             [-5.8252e-04],
#             [-5.6659e-04],
#             [-5.7919e-04],
#             [-7.2741e-04],
#             [-8.4940e-05],
#             [-3.0269e-04]],
#
#            [[ 0.0000e+00],
#             [ 2.4395e-02],
#             [ 1.3230e-02],
#             [ 8.6958e-03],
#             [ 7.9578e-03],
#             [ 3.6029e-03],
#             [ 3.4110e-03],
#             [ 3.4531e-03],
#             [ 3.3025e-02],
#             [ 3.4108e-03],
#             [ 2.7207e-03],
#             [ 2.0513e-03],
#             [-1.4441e-03],
#             [ 3.1641e-03],
#             [ 1.7816e-03],
#             [ 7.3419e-04],
#             [ 1.4655e-02],
#             [ 3.8651e-03],
#             [ 2.6059e-03],
#             [ 2.2916e-03],
#             [ 5.6392e-03],
#             [ 1.3765e-03],
#             [ 1.7823e-03],
#             [ 2.0614e-03],
#             [-5.4518e-03],
#             [ 4.0615e-04],
#             [ 8.4488e-04],
#             [ 4.1486e-04],
#             [ 1.6260e-03],
#             [ 1.2405e-03],
#             [ 1.0062e-03],
#             [ 7.3703e-04],
#             [ 2.1287e-03],
#             [ 1.0558e-03],
#             [ 1.0124e-03],
#             [ 1.5267e-03],
#             [-2.0213e-03],
#             [-1.1132e-04],
#             [-1.9787e-05],
#             [-1.9798e-05],
#             [ 3.2696e-03],
#             [ 7.7495e-04],
#             [ 6.8778e-04],
#             [ 5.3712e-04],
#             [-1.2593e-03],
#             [-1.5215e-04],
#             [-2.2292e-04],
#             [-1.0134e-03],
#             [ 3.7355e-03],
#             [ 9.5673e-04],
#             [ 5.4000e-04],
#             [-4.6472e-05],
#             [ 2.4180e-03],
#             [ 9.3887e-04],
#             [ 8.3155e-04],
#             [ 7.2666e-04],
#             [-6.6365e-05],
#             [ 2.5808e-04],
#             [ 2.8045e-04],
#             [-1.2385e-04],
#             [ 1.5881e-03],
#             [ 5.7261e-04],
#             [ 4.5084e-04],
#             [ 1.9225e-04],
#             [ 9.5362e-04],
#             [ 8.9974e-04],
#             [ 8.9969e-04],
#             [ 1.5564e-03],
#             [-1.2673e-03],
#             [ 1.1551e-04],
#             [ 3.2286e-04],
#             [ 8.3614e-04],
#             [-1.0558e-03],
#             [-2.4443e-04],
#             [-1.6771e-04],
#             [-6.7746e-04],
#             [ 1.0811e-03],
#             [ 3.7593e-04],
#             [ 3.4517e-04],
#             [ 5.9576e-04],
#             [-2.4670e-04],
#             [ 5.0949e-05],
#             [ 8.6170e-05],
#             [ 1.2119e-04],
#             [ 3.5017e-05],
#             [ 4.3846e-05],
#             [ 2.3600e-05],
#             [ 5.4796e-05],
#             [-4.8581e-05],
#             [-2.8970e-06]]]], device='cuda:0'), std=tensor([[[[138.1020],
#             [ 22.9941],
#             [ 11.9996],
#             [  8.4260],
#             [  7.0407],
#             [  6.7325],
#             [  7.2508],
#             [  8.9661],
#             [ 10.5088],
#             [  8.8724],
#             [  6.2375],
#             [  4.8063],
#             [  4.0451],
#             [  3.8342],
#             [  3.7701],
#             [  3.6967],
#             [  3.6644],
#             [  3.6043],
#             [  3.4257],
#             [  3.2477],
#             [  2.9809],
#             [  2.8858],
#             [  2.7313],
#             [  2.6129],
#             [  2.4492],
#             [  2.4165],
#             [  2.3293],
#             [  2.2534],
#             [  2.1411],
#             [  2.1038],
#             [  2.0471],
#             [  1.9765],
#             [  1.8987],
#             [  1.8927],
#             [  1.8237],
#             [  1.8062],
#             [  1.7255],
#             [  1.7395],
#             [  1.6978],
#             [  1.6819],
#             [  1.6215],
#             [  1.6198],
#             [  1.5815],
#             [  1.5477],
#             [  1.4857],
#             [  1.4750],
#             [  1.4238],
#             [  1.3833],
#             [  1.2997],
#             [  1.2562],
#             [  1.1623],
#             [  1.0724],
#             [  0.9533],
#             [  0.8896],
#             [  0.8985],
#             [  0.8906],
#             [  0.9545],
#             [  1.0329],
#             [  1.0829],
#             [  1.1063],
#             [  1.1026],
#             [  1.1225],
#             [  1.1027],
#             [  1.0945],
#             [  1.0563],
#             [  1.0590],
#             [  1.0247],
#             [  1.0051],
#             [  0.9703],
#             [  0.9607],
#             [  0.9368],
#             [  0.9166],
#             [  0.8936],
#             [  0.8815],
#             [  0.8663],
#             [  0.8512],
#             [  0.8353],
#             [  0.8331],
#             [  0.8227],
#             [  0.8172],
#             [  0.8058],
#             [  0.8105],
#             [  0.8059],
#             [  0.8019],
#             [  0.8000],
#             [  0.8021],
#             [  0.8034],
#             [  0.7993],
#             [  0.7987],
#             [  0.8026]],
#
#            [[  0.0000],
#             [ 38.1045],
#             [ 19.7558],
#             [ 13.6364],
#             [ 10.6793],
#             [  9.4429],
#             [  9.2219],
#             [ 10.3952],
#             [ 11.7117],
#             [ 10.0897],
#             [  7.3948],
#             [  5.9648],
#             [  5.0512],
#             [  4.7889],
#             [  4.5392],
#             [  4.4504],
#             [  4.2578],
#             [  4.2056],
#             [  3.9521],
#             [  3.7419],
#             [  3.4541],
#             [  3.3079],
#             [  3.1374],
#             [  2.9731],
#             [  2.8002],
#             [  2.7319],
#             [  2.6108],
#             [  2.5329],
#             [  2.3732],
#             [  2.3427],
#             [  2.2453],
#             [  2.1683],
#             [  2.0662],
#             [  2.0400],
#             [  1.9764],
#             [  1.9165],
#             [  1.8426],
#             [  1.8230],
#             [  1.7837],
#             [  1.7447],
#             [  1.6664],
#             [  1.6597],
#             [  1.6135],
#             [  1.5720],
#             [  1.4927],
#             [  1.4696],
#             [  1.4191],
#             [  1.3549],
#             [  1.2688],
#             [  1.1994],
#             [  1.1114],
#             [  0.9934],
#             [  0.8692],
#             [  0.7836],
#             [  0.7895],
#             [  0.7682],
#             [  0.8331],
#             [  0.9076],
#             [  0.9523],
#             [  0.9715],
#             [  0.9625],
#             [  0.9705],
#             [  0.9572],
#             [  0.9237],
#             [  0.8971],
#             [  0.8730],
#             [  0.8447],
#             [  0.8042],
#             [  0.7684],
#             [  0.7461],
#             [  0.7152],
#             [  0.6863],
#             [  0.6522],
#             [  0.6327],
#             [  0.6084],
#             [  0.5828],
#             [  0.5633],
#             [  0.5490],
#             [  0.5392],
#             [  0.5188],
#             [  0.5107],
#             [  0.5042],
#             [  0.4992],
#             [  0.4886],
#             [  0.4826],
#             [  0.4858],
#             [  0.4801],
#             [  0.4765],
#             [  0.4746],
#             [  0.4795]]]], device='cuda:0'), eps=1e-08, std_eps=tensor([[[[1.3810e+02],
#             [2.2994e+01],
#             [1.2000e+01],
#             [8.4260e+00],
#             [7.0407e+00],
#             [6.7325e+00],
#             [7.2508e+00],
#             [8.9661e+00],
#             [1.0509e+01],
#             [8.8724e+00],
#             [6.2375e+00],
#             [4.8063e+00],
#             [4.0451e+00],
#             [3.8342e+00],
#             [3.7701e+00],
#             [3.6967e+00],
#             [3.6644e+00],
#             [3.6043e+00],
#             [3.4257e+00],
#             [3.2477e+00],
#             [2.9809e+00],
#             [2.8858e+00],
#             [2.7313e+00],
#             [2.6129e+00],
#             [2.4492e+00],
#             [2.4165e+00],
#             [2.3293e+00],
#             [2.2534e+00],
#             [2.1411e+00],
#             [2.1038e+00],
#             [2.0471e+00],
#             [1.9765e+00],
#             [1.8987e+00],
#             [1.8927e+00],
#             [1.8237e+00],
#             [1.8062e+00],
#             [1.7255e+00],
#             [1.7395e+00],
#             [1.6978e+00],
#             [1.6819e+00],
#             [1.6215e+00],
#             [1.6198e+00],
#             [1.5815e+00],
#             [1.5477e+00],
#             [1.4857e+00],
#             [1.4750e+00],
#             [1.4238e+00],
#             [1.3833e+00],
#             [1.2997e+00],
#             [1.2562e+00],
#             [1.1623e+00],
#             [1.0724e+00],
#             [9.5334e-01],
#             [8.8961e-01],
#             [8.9854e-01],
#             [8.9056e-01],
#             [9.5454e-01],
#             [1.0329e+00],
#             [1.0829e+00],
#             [1.1063e+00],
#             [1.1026e+00],
#             [1.1225e+00],
#             [1.1027e+00],
#             [1.0945e+00],
#             [1.0563e+00],
#             [1.0590e+00],
#             [1.0247e+00],
#             [1.0051e+00],
#             [9.7031e-01],
#             [9.6072e-01],
#             [9.3683e-01],
#             [9.1663e-01],
#             [8.9355e-01],
#             [8.8150e-01],
#             [8.6628e-01],
#             [8.5120e-01],
#             [8.3525e-01],
#             [8.3313e-01],
#             [8.2270e-01],
#             [8.1716e-01],
#             [8.0577e-01],
#             [8.1053e-01],
#             [8.0588e-01],
#             [8.0185e-01],
#             [7.9997e-01],
#             [8.0214e-01],
#             [8.0343e-01],
#             [7.9934e-01],
#             [7.9867e-01],
#             [8.0260e-01]],
#
#            [[1.0000e-08],
#             [3.8105e+01],
#             [1.9756e+01],
#             [1.3636e+01],
#             [1.0679e+01],
#             [9.4429e+00],
#             [9.2219e+00],
#             [1.0395e+01],
#             [1.1712e+01],
#             [1.0090e+01],
#             [7.3948e+00],
#             [5.9648e+00],
#             [5.0512e+00],
#             [4.7889e+00],
#             [4.5392e+00],
#             [4.4504e+00],
#             [4.2578e+00],
#             [4.2056e+00],
#             [3.9521e+00],
#             [3.7419e+00],
#             [3.4541e+00],
#             [3.3079e+00],
#             [3.1374e+00],
#             [2.9731e+00],
#             [2.8002e+00],
#             [2.7319e+00],
#             [2.6108e+00],
#             [2.5329e+00],
#             [2.3732e+00],
#             [2.3427e+00],
#             [2.2453e+00],
#             [2.1683e+00],
#             [2.0662e+00],
#             [2.0400e+00],
#             [1.9764e+00],
#             [1.9165e+00],
#             [1.8426e+00],
#             [1.8230e+00],
#             [1.7837e+00],
#             [1.7447e+00],
#             [1.6664e+00],
#             [1.6597e+00],
#             [1.6135e+00],
#             [1.5720e+00],
#             [1.4927e+00],
#             [1.4696e+00],
#             [1.4191e+00],
#             [1.3549e+00],
#             [1.2688e+00],
#             [1.1994e+00],
#             [1.1114e+00],
#             [9.9344e-01],
#             [8.6919e-01],
#             [7.8357e-01],
#             [7.8948e-01],
#             [7.6815e-01],
#             [8.3310e-01],
#             [9.0762e-01],
#             [9.5234e-01],
#             [9.7148e-01],
#             [9.6251e-01],
#             [9.7046e-01],
#             [9.5721e-01],
#             [9.2371e-01],
#             [8.9712e-01],
#             [8.7298e-01],
#             [8.4465e-01],
#             [8.0416e-01],
#             [7.6842e-01],
#             [7.4615e-01],
#             [7.1520e-01],
#             [6.8625e-01],
#             [6.5221e-01],
#             [6.3270e-01],
#             [6.0836e-01],
#             [5.8283e-01],
#             [5.6328e-01],
#             [5.4895e-01],
#             [5.3916e-01],
#             [5.1882e-01],
#             [5.1074e-01],
#             [5.0415e-01],
#             [4.9916e-01],
#             [4.8861e-01],
#             [4.8255e-01],
#             [4.8584e-01],
#             [4.8007e-01],
#             [4.7650e-01],
#             [4.7464e-01],
#             [4.7946e-01]]]], device='cuda:0'))
# ),
#  'preprocess_train': Sequential(
#   (0): EegToDevice(device=device(type='cuda', index=0))
#   (1): EegNormalizeAge(mean=tensor([71.1417], device='cuda:0'), std=tensor([9.7264]), eps=1e-08, std_eps=tensor([9.7264], device='cuda:0'))
#   (2): EegAddGaussianNoiseAge(mean=0.0, std=0.031086177931273194)
#   (3): EegNormalizeMeanStd(mean=tensor([[[0.0502]]], device='cuda:0'), std=tensor([[[30.3874]]]), eps=1e-08, std_eps=tensor([[[30.3874]]], device='cuda:0'))
#   (4): EegMultiplicativeGaussianNoise(mean=0.0, std=0.003676528367854981)
#   (5): EegAdditiveGaussianNoise(mean=0.0, std=0.0479404157791391)
#   (6): EegSpectrogram(n_fft=179, complex_mode='as_real', stft_kwargs={'hop_length': 45})
#   (7): EegNormalizeMeanStd(mean=tensor([[[[-4.6854e-01],
#             [-2.9285e-03],
#             [-1.8059e-03],
#             [ 1.9164e-03],
#             [-1.3249e-02],
#             [ 5.3307e-04],
#             [ 1.5989e-04],
#             [ 1.5888e-03],
#             [-2.1761e-02],
#             [-4.9173e-03],
#             [-2.0585e-03],
#             [-2.6960e-03],
#             [ 1.2655e-02],
#             [ 1.2907e-03],
#             [-1.0924e-03],
#             [-1.0661e-03],
#             [ 5.2922e-03],
#             [-1.9977e-04],
#             [-6.5483e-04],
#             [-9.4698e-04],
#             [ 3.5059e-03],
#             [-5.5977e-04],
#             [-4.1707e-04],
#             [-7.8730e-04],
#             [ 1.5696e-03],
#             [-3.1200e-04],
#             [-4.5329e-04],
#             [-2.3344e-04],
#             [ 6.0557e-05],
#             [-2.3415e-04],
#             [-7.4846e-05],
#             [ 7.9993e-04],
#             [-5.9483e-03],
#             [-1.7851e-03],
#             [-1.4063e-03],
#             [-1.2721e-03],
#             [ 1.6052e-03],
#             [-4.0195e-04],
#             [-3.7079e-04],
#             [-6.1911e-04],
#             [-1.3828e-03],
#             [-9.0136e-04],
#             [-9.4556e-04],
#             [-2.3298e-04],
#             [ 9.2243e-04],
#             [-2.3543e-04],
#             [-1.9445e-04],
#             [ 5.3912e-04],
#             [-2.3439e-03],
#             [-1.1274e-03],
#             [-9.6116e-04],
#             [-9.7787e-04],
#             [-9.1182e-04],
#             [-8.3417e-04],
#             [-9.6220e-04],
#             [-1.1801e-03],
#             [ 1.8223e-04],
#             [-7.2040e-04],
#             [-8.9891e-04],
#             [-1.4540e-03],
#             [ 9.8739e-04],
#             [-2.9185e-04],
#             [-6.3093e-04],
#             [-1.2649e-03],
#             [ 7.0902e-04],
#             [-3.5998e-04],
#             [-6.2454e-04],
#             [-1.1828e-03],
#             [ 1.1685e-03],
#             [ 2.9734e-05],
#             [-2.0702e-04],
#             [-5.8995e-04],
#             [ 2.6587e-04],
#             [-1.7404e-04],
#             [-1.2760e-04],
#             [-4.5901e-05],
#             [-8.9414e-04],
#             [-5.4469e-04],
#             [-5.2700e-04],
#             [-4.4598e-04],
#             [-3.0201e-04],
#             [-3.8129e-04],
#             [-5.0657e-04],
#             [-3.0813e-04],
#             [-5.8252e-04],
#             [-5.6659e-04],
#             [-5.7919e-04],
#             [-7.2741e-04],
#             [-8.4940e-05],
#             [-3.0269e-04]],
#
#            [[ 0.0000e+00],
#             [ 2.4395e-02],
#             [ 1.3230e-02],
#             [ 8.6958e-03],
#             [ 7.9578e-03],
#             [ 3.6029e-03],
#             [ 3.4110e-03],
#             [ 3.4531e-03],
#             [ 3.3025e-02],
#             [ 3.4108e-03],
#             [ 2.7207e-03],
#             [ 2.0513e-03],
#             [-1.4441e-03],
#             [ 3.1641e-03],
#             [ 1.7816e-03],
#             [ 7.3419e-04],
#             [ 1.4655e-02],
#             [ 3.8651e-03],
#             [ 2.6059e-03],
#             [ 2.2916e-03],
#             [ 5.6392e-03],
#             [ 1.3765e-03],
#             [ 1.7823e-03],
#             [ 2.0614e-03],
#             [-5.4518e-03],
#             [ 4.0615e-04],
#             [ 8.4488e-04],
#             [ 4.1486e-04],
#             [ 1.6260e-03],
#             [ 1.2405e-03],
#             [ 1.0062e-03],
#             [ 7.3703e-04],
#             [ 2.1287e-03],
#             [ 1.0558e-03],
#             [ 1.0124e-03],
#             [ 1.5267e-03],
#             [-2.0213e-03],
#             [-1.1132e-04],
#             [-1.9787e-05],
#             [-1.9798e-05],
#             [ 3.2696e-03],
#             [ 7.7495e-04],
#             [ 6.8778e-04],
#             [ 5.3712e-04],
#             [-1.2593e-03],
#             [-1.5215e-04],
#             [-2.2292e-04],
#             [-1.0134e-03],
#             [ 3.7355e-03],
#             [ 9.5673e-04],
#             [ 5.4000e-04],
#             [-4.6472e-05],
#             [ 2.4180e-03],
#             [ 9.3887e-04],
#             [ 8.3155e-04],
#             [ 7.2666e-04],
#             [-6.6365e-05],
#             [ 2.5808e-04],
#             [ 2.8045e-04],
#             [-1.2385e-04],
#             [ 1.5881e-03],
#             [ 5.7261e-04],
#             [ 4.5084e-04],
#             [ 1.9225e-04],
#             [ 9.5362e-04],
#             [ 8.9974e-04],
#             [ 8.9969e-04],
#             [ 1.5564e-03],
#             [-1.2673e-03],
#             [ 1.1551e-04],
#             [ 3.2286e-04],
#             [ 8.3614e-04],
#             [-1.0558e-03],
#             [-2.4443e-04],
#             [-1.6771e-04],
#             [-6.7746e-04],
#             [ 1.0811e-03],
#             [ 3.7593e-04],
#             [ 3.4517e-04],
#             [ 5.9576e-04],
#             [-2.4670e-04],
#             [ 5.0949e-05],
#             [ 8.6170e-05],
#             [ 1.2119e-04],
#             [ 3.5017e-05],
#             [ 4.3846e-05],
#             [ 2.3600e-05],
#             [ 5.4796e-05],
#             [-4.8581e-05],
#             [-2.8970e-06]]]], device='cuda:0'), std=tensor([[[[138.1020],
#             [ 22.9941],
#             [ 11.9996],
#             [  8.4260],
#             [  7.0407],
#             [  6.7325],
#             [  7.2508],
#             [  8.9661],
#             [ 10.5088],
#             [  8.8724],
#             [  6.2375],
#             [  4.8063],
#             [  4.0451],
#             [  3.8342],
#             [  3.7701],
#             [  3.6967],
#             [  3.6644],
#             [  3.6043],
#             [  3.4257],
#             [  3.2477],
#             [  2.9809],
#             [  2.8858],
#             [  2.7313],
#             [  2.6129],
#             [  2.4492],
#             [  2.4165],
#             [  2.3293],
#             [  2.2534],
#             [  2.1411],
#             [  2.1038],
#             [  2.0471],
#             [  1.9765],
#             [  1.8987],
#             [  1.8927],
#             [  1.8237],
#             [  1.8062],
#             [  1.7255],
#             [  1.7395],
#             [  1.6978],
#             [  1.6819],
#             [  1.6215],
#             [  1.6198],
#             [  1.5815],
#             [  1.5477],
#             [  1.4857],
#             [  1.4750],
#             [  1.4238],
#             [  1.3833],
#             [  1.2997],
#             [  1.2562],
#             [  1.1623],
#             [  1.0724],
#             [  0.9533],
#             [  0.8896],
#             [  0.8985],
#             [  0.8906],
#             [  0.9545],
#             [  1.0329],
#             [  1.0829],
#             [  1.1063],
#             [  1.1026],
#             [  1.1225],
#             [  1.1027],
#             [  1.0945],
#             [  1.0563],
#             [  1.0590],
#             [  1.0247],
#             [  1.0051],
#             [  0.9703],
#             [  0.9607],
#             [  0.9368],
#             [  0.9166],
#             [  0.8936],
#             [  0.8815],
#             [  0.8663],
#             [  0.8512],
#             [  0.8353],
#             [  0.8331],
#             [  0.8227],
#             [  0.8172],
#             [  0.8058],
#             [  0.8105],
#             [  0.8059],
#             [  0.8019],
#             [  0.8000],
#             [  0.8021],
#             [  0.8034],
#             [  0.7993],
#             [  0.7987],
#             [  0.8026]],
#
#            [[  0.0000],
#             [ 38.1045],
#             [ 19.7558],
#             [ 13.6364],
#             [ 10.6793],
#             [  9.4429],
#             [  9.2219],
#             [ 10.3952],
#             [ 11.7117],
#             [ 10.0897],
#             [  7.3948],
#             [  5.9648],
#             [  5.0512],
#             [  4.7889],
#             [  4.5392],
#             [  4.4504],
#             [  4.2578],
#             [  4.2056],
#             [  3.9521],
#             [  3.7419],
#             [  3.4541],
#             [  3.3079],
#             [  3.1374],
#             [  2.9731],
#             [  2.8002],
#             [  2.7319],
#             [  2.6108],
#             [  2.5329],
#             [  2.3732],
#             [  2.3427],
#             [  2.2453],
#             [  2.1683],
#             [  2.0662],
#             [  2.0400],
#             [  1.9764],
#             [  1.9165],
#             [  1.8426],
#             [  1.8230],
#             [  1.7837],
#             [  1.7447],
#             [  1.6664],
#             [  1.6597],
#             [  1.6135],
#             [  1.5720],
#             [  1.4927],
#             [  1.4696],
#             [  1.4191],
#             [  1.3549],
#             [  1.2688],
#             [  1.1994],
#             [  1.1114],
#             [  0.9934],
#             [  0.8692],
#             [  0.7836],
#             [  0.7895],
#             [  0.7682],
#             [  0.8331],
#             [  0.9076],
#             [  0.9523],
#             [  0.9715],
#             [  0.9625],
#             [  0.9705],
#             [  0.9572],
#             [  0.9237],
#             [  0.8971],
#             [  0.8730],
#             [  0.8447],
#             [  0.8042],
#             [  0.7684],
#             [  0.7461],
#             [  0.7152],
#             [  0.6863],
#             [  0.6522],
#             [  0.6327],
#             [  0.6084],
#             [  0.5828],
#             [  0.5633],
#             [  0.5490],
#             [  0.5392],
#             [  0.5188],
#             [  0.5107],
#             [  0.5042],
#             [  0.4992],
#             [  0.4886],
#             [  0.4826],
#             [  0.4858],
#             [  0.4801],
#             [  0.4765],
#             [  0.4746],
#             [  0.4795]]]], device='cuda:0'), eps=1e-08, std_eps=tensor([[[[1.3810e+02],
#             [2.2994e+01],
#             [1.2000e+01],
#             [8.4260e+00],
#             [7.0407e+00],
#             [6.7325e+00],
#             [7.2508e+00],
#             [8.9661e+00],
#             [1.0509e+01],
#             [8.8724e+00],
#             [6.2375e+00],
#             [4.8063e+00],
#             [4.0451e+00],
#             [3.8342e+00],
#             [3.7701e+00],
#             [3.6967e+00],
#             [3.6644e+00],
#             [3.6043e+00],
#             [3.4257e+00],
#             [3.2477e+00],
#             [2.9809e+00],
#             [2.8858e+00],
#             [2.7313e+00],
#             [2.6129e+00],
#             [2.4492e+00],
#             [2.4165e+00],
#             [2.3293e+00],
#             [2.2534e+00],
#             [2.1411e+00],
#             [2.1038e+00],
#             [2.0471e+00],
#             [1.9765e+00],
#             [1.8987e+00],
#             [1.8927e+00],
#             [1.8237e+00],
#             [1.8062e+00],
#             [1.7255e+00],
#             [1.7395e+00],
#             [1.6978e+00],
#             [1.6819e+00],
#             [1.6215e+00],
#             [1.6198e+00],
#             [1.5815e+00],
#             [1.5477e+00],
#             [1.4857e+00],
#             [1.4750e+00],
#             [1.4238e+00],
#             [1.3833e+00],
#             [1.2997e+00],
#             [1.2562e+00],
#             [1.1623e+00],
#             [1.0724e+00],
#             [9.5334e-01],
#             [8.8961e-01],
#             [8.9854e-01],
#             [8.9056e-01],
#             [9.5454e-01],
#             [1.0329e+00],
#             [1.0829e+00],
#             [1.1063e+00],
#             [1.1026e+00],
#             [1.1225e+00],
#             [1.1027e+00],
#             [1.0945e+00],
#             [1.0563e+00],
#             [1.0590e+00],
#             [1.0247e+00],
#             [1.0051e+00],
#             [9.7031e-01],
#             [9.6072e-01],
#             [9.3683e-01],
#             [9.1663e-01],
#             [8.9355e-01],
#             [8.8150e-01],
#             [8.6628e-01],
#             [8.5120e-01],
#             [8.3525e-01],
#             [8.3313e-01],
#             [8.2270e-01],
#             [8.1716e-01],
#             [8.0577e-01],
#             [8.1053e-01],
#             [8.0588e-01],
#             [8.0185e-01],
#             [7.9997e-01],
#             [8.0214e-01],
#             [8.0343e-01],
#             [7.9934e-01],
#             [7.9867e-01],
#             [8.0260e-01]],
#
#            [[1.0000e-08],
#             [3.8105e+01],
#             [1.9756e+01],
#             [1.3636e+01],
#             [1.0679e+01],
#             [9.4429e+00],
#             [9.2219e+00],
#             [1.0395e+01],
#             [1.1712e+01],
#             [1.0090e+01],
#             [7.3948e+00],
#             [5.9648e+00],
#             [5.0512e+00],
#             [4.7889e+00],
#             [4.5392e+00],
#             [4.4504e+00],
#             [4.2578e+00],
#             [4.2056e+00],
#             [3.9521e+00],
#             [3.7419e+00],
#             [3.4541e+00],
#             [3.3079e+00],
#             [3.1374e+00],
#             [2.9731e+00],
#             [2.8002e+00],
#             [2.7319e+00],
#             [2.6108e+00],
#             [2.5329e+00],
#             [2.3732e+00],
#             [2.3427e+00],
#             [2.2453e+00],
#             [2.1683e+00],
#             [2.0662e+00],
#             [2.0400e+00],
#             [1.9764e+00],
#             [1.9165e+00],
#             [1.8426e+00],
#             [1.8230e+00],
#             [1.7837e+00],
#             [1.7447e+00],
#             [1.6664e+00],
#             [1.6597e+00],
#             [1.6135e+00],
#             [1.5720e+00],
#             [1.4927e+00],
#             [1.4696e+00],
#             [1.4191e+00],
#             [1.3549e+00],
#             [1.2688e+00],
#             [1.1994e+00],
#             [1.1114e+00],
#             [9.9344e-01],
#             [8.6919e-01],
#             [7.8357e-01],
#             [7.8948e-01],
#             [7.6815e-01],
#             [8.3310e-01],
#             [9.0762e-01],
#             [9.5234e-01],
#             [9.7148e-01],
#             [9.6251e-01],
#             [9.7046e-01],
#             [9.5721e-01],
#             [9.2371e-01],
#             [8.9712e-01],
#             [8.7298e-01],
#             [8.4465e-01],
#             [8.0416e-01],
#             [7.6842e-01],
#             [7.4615e-01],
#             [7.1520e-01],
#             [6.8625e-01],
#             [6.5221e-01],
#             [6.3270e-01],
#             [6.0836e-01],
#             [5.8283e-01],
#             [5.6328e-01],
#             [5.4895e-01],
#             [5.3916e-01],
#             [5.1882e-01],
#             [5.1074e-01],
#             [5.0415e-01],
#             [4.9916e-01],
#             [4.8861e-01],
#             [4.8255e-01],
#             [4.8584e-01],
#             [4.8007e-01],
#             [4.7650e-01],
#             [4.7464e-01],
#             [4.7946e-01]]]], device='cuda:0'))
# ),
#  'project': 'caueeg-dementia-channel-reduction',
#  'run_mode': 'train',
#  'save_model': True,
#  'search_lr': False,
#  'search_multiplier': 1.0,
#  'seed': 0,
#  'seq_len_2d': (90, 89),
#  'seq_length': 4000,
#  'signal_2d_mean': tensor([[[[-4.6854e-01],
#           [-2.9285e-03],
#           [-1.8059e-03],
#           [ 1.9164e-03],
#           [-1.3249e-02],
#           [ 5.3307e-04],
#           [ 1.5989e-04],
#           [ 1.5888e-03],
#           [-2.1761e-02],
#           [-4.9173e-03],
#           [-2.0585e-03],
#           [-2.6960e-03],
#           [ 1.2655e-02],
#           [ 1.2907e-03],
#           [-1.0924e-03],
#           [-1.0661e-03],
#           [ 5.2922e-03],
#           [-1.9977e-04],
#           [-6.5483e-04],
#           [-9.4698e-04],
#           [ 3.5059e-03],
#           [-5.5977e-04],
#           [-4.1707e-04],
#           [-7.8730e-04],
#           [ 1.5696e-03],
#           [-3.1200e-04],
#           [-4.5329e-04],
#           [-2.3344e-04],
#           [ 6.0557e-05],
#           [-2.3415e-04],
#           [-7.4846e-05],
#           [ 7.9993e-04],
#           [-5.9483e-03],
#           [-1.7851e-03],
#           [-1.4063e-03],
#           [-1.2721e-03],
#           [ 1.6052e-03],
#           [-4.0195e-04],
#           [-3.7079e-04],
#           [-6.1911e-04],
#           [-1.3828e-03],
#           [-9.0136e-04],
#           [-9.4556e-04],
#           [-2.3298e-04],
#           [ 9.2243e-04],
#           [-2.3543e-04],
#           [-1.9445e-04],
#           [ 5.3912e-04],
#           [-2.3439e-03],
#           [-1.1274e-03],
#           [-9.6116e-04],
#           [-9.7787e-04],
#           [-9.1182e-04],
#           [-8.3417e-04],
#           [-9.6220e-04],
#           [-1.1801e-03],
#           [ 1.8223e-04],
#           [-7.2040e-04],
#           [-8.9891e-04],
#           [-1.4540e-03],
#           [ 9.8739e-04],
#           [-2.9185e-04],
#           [-6.3093e-04],
#           [-1.2649e-03],
#           [ 7.0902e-04],
#           [-3.5998e-04],
#           [-6.2454e-04],
#           [-1.1828e-03],
#           [ 1.1685e-03],
#           [ 2.9734e-05],
#           [-2.0702e-04],
#           [-5.8995e-04],
#           [ 2.6587e-04],
#           [-1.7404e-04],
#           [-1.2760e-04],
#           [-4.5901e-05],
#           [-8.9414e-04],
#           [-5.4469e-04],
#           [-5.2700e-04],
#           [-4.4598e-04],
#           [-3.0201e-04],
#           [-3.8129e-04],
#           [-5.0657e-04],
#           [-3.0813e-04],
#           [-5.8252e-04],
#           [-5.6659e-04],
#           [-5.7919e-04],
#           [-7.2741e-04],
#           [-8.4940e-05],
#           [-3.0269e-04]],
#
#          [[ 0.0000e+00],
#           [ 2.4395e-02],
#           [ 1.3230e-02],
#           [ 8.6958e-03],
#           [ 7.9578e-03],
#           [ 3.6029e-03],
#           [ 3.4110e-03],
#           [ 3.4531e-03],
#           [ 3.3025e-02],
#           [ 3.4108e-03],
#           [ 2.7207e-03],
#           [ 2.0513e-03],
#           [-1.4441e-03],
#           [ 3.1641e-03],
#           [ 1.7816e-03],
#           [ 7.3419e-04],
#           [ 1.4655e-02],
#           [ 3.8651e-03],
#           [ 2.6059e-03],
#           [ 2.2916e-03],
#           [ 5.6392e-03],
#           [ 1.3765e-03],
#           [ 1.7823e-03],
#           [ 2.0614e-03],
#           [-5.4518e-03],
#           [ 4.0615e-04],
#           [ 8.4488e-04],
#           [ 4.1486e-04],
#           [ 1.6260e-03],
#           [ 1.2405e-03],
#           [ 1.0062e-03],
#           [ 7.3703e-04],
#           [ 2.1287e-03],
#           [ 1.0558e-03],
#           [ 1.0124e-03],
#           [ 1.5267e-03],
#           [-2.0213e-03],
#           [-1.1132e-04],
#           [-1.9787e-05],
#           [-1.9798e-05],
#           [ 3.2696e-03],
#           [ 7.7495e-04],
#           [ 6.8778e-04],
#           [ 5.3712e-04],
#           [-1.2593e-03],
#           [-1.5215e-04],
#           [-2.2292e-04],
#           [-1.0134e-03],
#           [ 3.7355e-03],
#           [ 9.5673e-04],
#           [ 5.4000e-04],
#           [-4.6472e-05],
#           [ 2.4180e-03],
#           [ 9.3887e-04],
#           [ 8.3155e-04],
#           [ 7.2666e-04],
#           [-6.6365e-05],
#           [ 2.5808e-04],
#           [ 2.8045e-04],
#           [-1.2385e-04],
#           [ 1.5881e-03],
#           [ 5.7261e-04],
#           [ 4.5084e-04],
#           [ 1.9225e-04],
#           [ 9.5362e-04],
#           [ 8.9974e-04],
#           [ 8.9969e-04],
#           [ 1.5564e-03],
#           [-1.2673e-03],
#           [ 1.1551e-04],
#           [ 3.2286e-04],
#           [ 8.3614e-04],
#           [-1.0558e-03],
#           [-2.4443e-04],
#           [-1.6771e-04],
#           [-6.7746e-04],
#           [ 1.0811e-03],
#           [ 3.7593e-04],
#           [ 3.4517e-04],
#           [ 5.9576e-04],
#           [-2.4670e-04],
#           [ 5.0949e-05],
#           [ 8.6170e-05],
#           [ 1.2119e-04],
#           [ 3.5017e-05],
#           [ 4.3846e-05],
#           [ 2.3600e-05],
#           [ 5.4796e-05],
#           [-4.8581e-05],
#           [-2.8970e-06]]]], device='cuda:0'),
#  'signal_2d_std': tensor([[[[138.1020],
#           [ 22.9941],
#           [ 11.9996],
#           [  8.4260],
#           [  7.0407],
#           [  6.7325],
#           [  7.2508],
#           [  8.9661],
#           [ 10.5088],
#           [  8.8724],
#           [  6.2375],
#           [  4.8063],
#           [  4.0451],
#           [  3.8342],
#           [  3.7701],
#           [  3.6967],
#           [  3.6644],
#           [  3.6043],
#           [  3.4257],
#           [  3.2477],
#           [  2.9809],
#           [  2.8858],
#           [  2.7313],
#           [  2.6129],
#           [  2.4492],
#           [  2.4165],
#           [  2.3293],
#           [  2.2534],
#           [  2.1411],
#           [  2.1038],
#           [  2.0471],
#           [  1.9765],
#           [  1.8987],
#           [  1.8927],
#           [  1.8237],
#           [  1.8062],
#           [  1.7255],
#           [  1.7395],
#           [  1.6978],
#           [  1.6819],
#           [  1.6215],
#           [  1.6198],
#           [  1.5815],
#           [  1.5477],
#           [  1.4857],
#           [  1.4750],
#           [  1.4238],
#           [  1.3833],
#           [  1.2997],
#           [  1.2562],
#           [  1.1623],
#           [  1.0724],
#           [  0.9533],
#           [  0.8896],
#           [  0.8985],
#           [  0.8906],
#           [  0.9545],
#           [  1.0329],
#           [  1.0829],
#           [  1.1063],
#           [  1.1026],
#           [  1.1225],
#           [  1.1027],
#           [  1.0945],
#           [  1.0563],
#           [  1.0590],
#           [  1.0247],
#           [  1.0051],
#           [  0.9703],
#           [  0.9607],
#           [  0.9368],
#           [  0.9166],
#           [  0.8936],
#           [  0.8815],
#           [  0.8663],
#           [  0.8512],
#           [  0.8353],
#           [  0.8331],
#           [  0.8227],
#           [  0.8172],
#           [  0.8058],
#           [  0.8105],
#           [  0.8059],
#           [  0.8019],
#           [  0.8000],
#           [  0.8021],
#           [  0.8034],
#           [  0.7993],
#           [  0.7987],
#           [  0.8026]],
#
#          [[  0.0000],
#           [ 38.1045],
#           [ 19.7558],
#           [ 13.6364],
#           [ 10.6793],
#           [  9.4429],
#           [  9.2219],
#           [ 10.3952],
#           [ 11.7117],
#           [ 10.0897],
#           [  7.3948],
#           [  5.9648],
#           [  5.0512],
#           [  4.7889],
#           [  4.5392],
#           [  4.4504],
#           [  4.2578],
#           [  4.2056],
#           [  3.9521],
#           [  3.7419],
#           [  3.4541],
#           [  3.3079],
#           [  3.1374],
#           [  2.9731],
#           [  2.8002],
#           [  2.7319],
#           [  2.6108],
#           [  2.5329],
#           [  2.3732],
#           [  2.3427],
#           [  2.2453],
#           [  2.1683],
#           [  2.0662],
#           [  2.0400],
#           [  1.9764],
#           [  1.9165],
#           [  1.8426],
#           [  1.8230],
#           [  1.7837],
#           [  1.7447],
#           [  1.6664],
#           [  1.6597],
#           [  1.6135],
#           [  1.5720],
#           [  1.4927],
#           [  1.4696],
#           [  1.4191],
#           [  1.3549],
#           [  1.2688],
#           [  1.1994],
#           [  1.1114],
#           [  0.9934],
#           [  0.8692],
#           [  0.7836],
#           [  0.7895],
#           [  0.7682],
#           [  0.8331],
#           [  0.9076],
#           [  0.9523],
#           [  0.9715],
#           [  0.9625],
#           [  0.9705],
#           [  0.9572],
#           [  0.9237],
#           [  0.8971],
#           [  0.8730],
#           [  0.8447],
#           [  0.8042],
#           [  0.7684],
#           [  0.7461],
#           [  0.7152],
#           [  0.6863],
#           [  0.6522],
#           [  0.6327],
#           [  0.6084],
#           [  0.5828],
#           [  0.5633],
#           [  0.5490],
#           [  0.5392],
#           [  0.5188],
#           [  0.5107],
#           [  0.5042],
#           [  0.4992],
#           [  0.4886],
#           [  0.4826],
#           [  0.4858],
#           [  0.4801],
#           [  0.4765],
#           [  0.4746],
#           [  0.4795]]]], device='cuda:0'),
#  'signal_header': ['Fp1-AVG',
#                    'F3-AVG',
#                    'C3-AVG',
#                    'P3-AVG',
#                    'O1-AVG',
#                    'Fp2-AVG',
#                    'F4-AVG',
#                    'C4-AVG',
#                    'P4-AVG',
#                    'O2-AVG',
#                    'F7-AVG',
#                    'T3-AVG',
#                    'T5-AVG',
#                    'F8-AVG',
#                    'T4-AVG',
#                    'T6-AVG',
#                    'FZ-AVG',
#                    'CZ-AVG',
#                    'PZ-AVG',
#                    'EKG',
#                    'Photic'],
#  'signal_length_limit': 10000000,
#  'signal_mean': tensor([[[0.0502]]]),
#  'signal_std': tensor([[[30.3874]]]),
#  'stft_params': {'hop_length': 45, 'n_fft': 179},
#  'task': 'dementia',
#  'task_description': 'Classification of [Normal], [MCI], and [Dementia] symptoms.',
#  'task_name': 'CAUEEG-Dementia benchmark',
#  'test_crop_multiple': 8,
#  'total_samples': 10000000.0,
#  'transform': Compose(
#     EegRandomCrop(crop_length=4000, length_limit=10000000, multiple=4, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegChannelDifference(ch1=6, ch2=15)
#     EegToTensor()
# ),
#  'transform_multicrop': Compose(
#     EegRandomCrop(crop_length=4000, length_limit=10000000, multiple=8, latency=2000, segment_simulation=False, return_timing=False, reject_events=False)
#     EegChannelDifference(ch1=6, ch2=15)
#     EegToTensor()
# ),
#  'use_age': 'conv',
#  'use_wandb': True,
#  'warmup_min': 3000,
#  'warmup_ratio': 0.05,
#  'watch_model': False,
#  'weight_decay': 0.012528558998673434}
#
# ********************************************************************************************
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016916666666899498, max=1.0…
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>C:\Users\Minjae\Desktop\EEG_Project\wandb\run-20230602_125216-nx59i5z5</code>
# Syncing run <strong><a href='https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction/runs/nx59i5z5' target="_blank">eager-terrain-211</a></strong> to <a href='https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction</a>
#  View run at <a href='https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction/runs/nx59i5z5' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction/runs/nx59i5z5</a>
# C:\Users\Minjae\anaconda3\envs\eeg\lib\site-packages\wandb\sdk\lib\ipython.py:70: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# C:\Users\Minjae\anaconda3\envs\eeg\lib\site-packages\wandb\sdk\lib\ipython.py:82: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# VBox(children=(Label(value='2.606 MB of 2.685 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.970680…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Learning Rate</td><td>▂▄▆███████▇▇▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>Loss</td><td>██▆▇█▆▆▅▆▆▇▅▅▄▂▃▃▇▄▁▅▄▃▃▁▃▂▁▃▂▃▄▄▅▃▄▂▂▂▂</td></tr><tr><td>Multi-Crop Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Train Accuracy</td><td>▁▁▂▂▂▃▃▃▄▄▄▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇█▇▇▇▇▇█▇███▇▇</td></tr><tr><td>Validation Accuracy</td><td>▂▂▃▂▂▅▅▄▁▇▅▆▅▆▆▇▆▅▅▆▆▇▅▄█▇███▆▅▇▇▆▆▆▆▆▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Loss</td><td>0.56881</td></tr><tr><td>Multi-Crop Test Accuracy</td><td>60.0565</td></tr><tr><td>Test Accuracy</td><td>56.90678</td></tr><tr><td>Train Accuracy</td><td>82.43538</td></tr><tr><td>Validation Accuracy</td><td>58.27731</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-terrain-211</strong> at: <a href='https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction/runs/nx59i5z5' target="_blank">https://wandb.ai/ipis-mjkim/caueeg-dementia-channel-reduction/runs/nx59i5z5</a><br/>Synced 6 W&B file(s), 2 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20230602_125216-nx59i5z5\logs</code>

# %% [markdown]
# ## Parse Results

# %%
import csv
import numpy as np

performance_list = [] 

with open(r"local/wandb_save.csv") as fp:
    rdr = csv.reader(fp)
    for i, line in enumerate(rdr):
        if i == 0:
            continue
        mont1, mont2 = line[13].split(" - ")
        test_acc = line[16]
        multi_test_acc = line[17]
        performance_list.append({
            'Mont1': mont1,
            'Mont2': mont2,
            'Test': test_acc,
            'TTA': multi_test_acc,
        })
        
# print(performance_list)

# %%
idx_to_mont = [mont.split('-')[0] for mont in signal_header if mont.lower() not in ['ekg', 'photic']]
mont_to_idx = {mont: i for i, mont in enumerate(idx_to_mont)}

test = np.zeros((19, 19))
mtest = np.zeros((19, 19))

for perf in performance_list:
    test[mont_to_idx[perf['Mont1']], mont_to_idx[perf['Mont2']]] = perf['Test']
    # test[mont_to_idx[perf['Mont2']], mont_to_idx[perf['Mont1']]] = perf['Test']

    mtest[mont_to_idx[perf['Mont1']], mont_to_idx[perf['Mont2']]] = perf['TTA']
    # mtest[mont_to_idx[perf['Mont2']], mont_to_idx[perf['Mont1']]] = perf['TTA']

# %%
import matplotlib.pyplot as plt
plt.rcParams['image.cmap'] = 'jet' # nipy_spectral, jet

fig, ax = plt.subplots(num=1, clear=True, figsize=(10.0, 10.0))

im = ax.imshow(test)
ax.set_xticks(np.arange(len(idx_to_mont)), labels=idx_to_mont)
ax.set_yticks(np.arange(len(idx_to_mont)), labels=idx_to_mont)
for i in range(len(idx_to_mont)):
    for j in range(len(idx_to_mont)):
        text = ax.text(j, i, round(test[i, j] * 100) / 100,
                       ha="center", va="center", color="w")
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(num=1, clear=True, figsize=(10.0, 10.0))

im = ax.imshow(mtest)
ax.set_xticks(np.arange(len(idx_to_mont)), labels=idx_to_mont)
ax.set_yticks(np.arange(len(idx_to_mont)), labels=idx_to_mont)
for i in range(len(idx_to_mont)):
    for j in range(len(idx_to_mont)):
        text = ax.text(j, i, round(mtest[i, j] * 100) / 100,
                       ha="center", va="center", color="w")
fig.tight_layout()
plt.show()
